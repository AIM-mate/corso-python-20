# %% [markdown]
# # €$£ Homework - Dati Finanziari per Pythoniani

# %% [markdown]
# L'Azienda degli Ingegneri Matematici ti ha assegnato il compito di **analizzare le performance giornaliere** per le ultime 5 settimane del valore di chiusura giornaliero delle azioni di **ENEL, ENI, Ferrari e Intesa San Paolo**. Il tuo capo è molto fiscale, egli pretende che nell'analisi si usino il **minor numero di righe di codice Python** possibile e non si usino librerie.
#
# _Fonte: mercati.ilsole24ore.com_

# %%
Dates = ["31/08/2020","1/9/2020","2/9/2020","3/9/2020","4/9/2020","7/9/2020","8/9/2020",
         "9/9/2020","10/9/2020","11/9/2020","14/09/2020","15/09/2020","16/09/2020","17/09/2020",
         "18/09/2020","21/09/2020","22/09/2020","23/09/2020","24/09/2020","25/09/2020",
         "28/09/2020","29/09/2020","30/09/2020","1/10/2020","2/10/2020"]

Stocks_Name = ["Enel","ENI","Ferrari","Intesa San Paolo"]

Stocks_Value = [[7.558,7.809,163.05,1.8012],
[7.518,7.774,162.85,1.804],
[7.61,7.666,165.4,1.7892],
[7.55,7.696,161.85,1.7758],
[7.392,7.623,160.7,1.7706],
[7.555,7.75,162.6,1.7938],
[7.495,7.542,161.25,1.7604],
[7.663,7.654,160.8,1.7934],
[7.612,7.609,160.05,1.8004],
[7.671,7.597,162.1,1.776],
[7.59,7.475,161.65,1.7768],
[7.627,7.607,162.35,1.7706],
[7.575,7.674,160.7,1.7546],
[7.401,7.633,160.55,1.7404],
[7.42,7.413,159.9,1.72],
[7.25,6.97,154.8,1.632],
[7.362,7.083,156.35,1.6424],
[7.431,6.969,156.45,1.6132],
[7.363,6.82,157.05,1.608],
[7.32,6.677,154.9,1.5806],
[7.465,6.855,157.2,1.6242],
[7.488,6.687,156.25,1.6124],
[7.431,6.685,157.05,1.6054],
[7.442,6.484,157,1.5854],
[7.459,6.472,155,1.5858]]

# %%
Stocks_Value = list(map(list, zip(*Stocks_Value)))
print(Stocks_Value)
# Out:
# [[7.558, 7.518, 7.61, 7.55, 7.392, 7.555, 7.495, 7.663, 7.612, 7.671, 7.59, 7.627, 7.575, 7.401, 7.42, 7.25, 7.362, 7.431, 7.363, 7.32, 7.465, 7.488, 7.431, 7.442, 7.459], [7.809, 7.774, 7.666, 7.696, 7.623, 7.75, 7.542, 7.654, 7.609, 7.597, 7.475, 7.607, 7.674, 7.633, 7.413, 6.97, 7.083, 6.969, 6.82, 6.677, 6.855, 6.687, 6.685, 6.484, 6.472], [163.05, 162.85, 165.4, 161.85, 160.7, 162.6, 161.25, 160.8, 160.05, 162.1, 161.65, 162.35, 160.7, 160.55, 159.9, 154.8, 156.35, 156.45, 157.05, 154.9, 157.2, 156.25, 157.05, 157, 155], [1.8012, 1.804, 1.7892, 1.7758, 1.7706, 1.7938, 1.7604, 1.7934, 1.8004, 1.776, 1.7768, 1.7706, 1.7546, 1.7404, 1.72, 1.632, 1.6424, 1.6132, 1.608, 1.5806, 1.6242, 1.6124, 1.6054, 1.5854, 1.5858]]

# %%
print([(sum(row))/len(row) for row in Stocks_Value])
# Out:
# [7.489920000000001, 7.288959999999999, 159.514, 1.7086640000000002]

# %%
print([((sum((Stocks_Value[k][i]-(sum(Stocks_Value[k])/len(Stocks_Value[k])))**2 for i in range(len(Stocks_Value[k]))))/len(Stocks_Value[k]))**(1/2) for k in range(len(Stocks_Value))])
# Out:
# [0.1083549426652979, 0.4481886638459299, 2.9617400291045115, 0.08426847989610349]

# %%
print([[sum((Stocks_Value[i][k]-[sum(w)/len(w) for w in Stocks_Value][i])*(Stocks_Value[j][k]-[sum(w)/len(w) for w in Stocks_Value][j]) for k in range(len(Stocks_Value[1])))/sum(( ((Stocks_Value[i][k]-[sum(w)/len(w) for w in Stocks_Value][i])**2) * ((Stocks_Value[j][k]-[sum(w)/len(w) for w in Stocks_Value][j])**2) )**(1/2) for k in range(len(Stocks_Value[1]))) for i in range(len(Stocks_Value))] for j in range(len(Stocks_Value))])
# Out:
# [[1.0, 0.8348539910336549, 0.9261206864474817, 0.8927798825473245], [0.8348539910336549, 1.0, 0.9999999999999998, 1.0], [0.9261206864474817, 0.9999999999999998, 1.0, 1.0], [0.8927798825473245, 1.0, 1.0, 1.0]]

# %%
nomi = list(range(len(Stocks_Value[0])-1));
for i in range(len(Stocks_Value[0])-1):
    max=None
    maxn=0
    for j in range(len(Stocks_Value)):
            if max is None or ((Stocks_Value[j][len(Stocks_Value[0])-1]-Stocks_Value[j][i])/Stocks_Value[j][i])>max:
                max=(Stocks_Value[j][len(Stocks_Value[0])-1]-Stocks_Value[j][i])/Stocks_Value[j][i]
                maxn=j
    nomi[i]=print (['Compro il',Dates[i],Stocks_Name[maxn]])
# Out:
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Enel']
# ['Compro il', '10/9/2020', 'Enel']
# ['Compro il', '11/9/2020', 'Enel']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Enel']
# ['Compro il', '24/09/2020', 'Enel']
# ['Compro il', '25/09/2020', 'Enel']
# ['Compro il', '28/09/2020', 'Enel']
# ['Compro il', '29/09/2020', 'Enel']
# ['Compro il', '30/09/2020', 'Enel']
# ['Compro il', '1/10/2020', 'Enel']

# %%
for h in range(len(Stocks_Value[0])-1):
    print (['Vendo il',Dates[len(Dates)-h-1]])
    for i in range(len(Stocks_Value[0])-1):
        max=None
        maxn=0
        for j in range(len(Stocks_Value)):
            if max is None or ((Stocks_Value[j][len(Stocks_Value[0])-1-h]-Stocks_Value[j][i])/Stocks_Value[j][i])>max:
                max=(Stocks_Value[j][len(Stocks_Value[0])-1-h]-Stocks_Value[j][i])/Stocks_Value[j][i]
                maxn=j
        print (['Compro il',Dates[i],Stocks_Name[maxn]])
# Out:
# ['Vendo il', '2/10/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Enel']
# ['Compro il', '10/9/2020', 'Enel']
# ['Compro il', '11/9/2020', 'Enel']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Enel']
# ['Compro il', '24/09/2020', 'Enel']
# ['Compro il', '25/09/2020', 'Enel']
# ['Compro il', '28/09/2020', 'Enel']
# ['Compro il', '29/09/2020', 'Enel']
# ['Compro il', '30/09/2020', 'Enel']
# ['Compro il', '1/10/2020', 'Enel']
# ['Vendo il', '1/10/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Enel']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Ferrari']
# ['Compro il', '24/09/2020', 'Enel']
# ['Compro il', '25/09/2020', 'Enel']
# ['Compro il', '28/09/2020', 'Ferrari']
# ['Compro il', '29/09/2020', 'Ferrari']
# ['Compro il', '30/09/2020', 'Enel']
# ['Compro il', '1/10/2020', 'Enel']
# ['Vendo il', '30/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Ferrari']
# ['Compro il', '24/09/2020', 'Enel']
# ['Compro il', '25/09/2020', 'Intesa San Paolo']
# ['Compro il', '28/09/2020', 'Ferrari']
# ['Compro il', '29/09/2020', 'Ferrari']
# ['Compro il', '30/09/2020', 'Enel']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '29/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Enel']
# ['Compro il', '10/9/2020', 'Enel']
# ['Compro il', '11/9/2020', 'Enel']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Enel']
# ['Compro il', '24/09/2020', 'Enel']
# ['Compro il', '25/09/2020', 'Enel']
# ['Compro il', '28/09/2020', 'Enel']
# ['Compro il', '29/09/2020', 'Enel']
# ['Compro il', '30/09/2020', 'Enel']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '28/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Enel']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'Enel']
# ['Compro il', '25/09/2020', 'Intesa San Paolo']
# ['Compro il', '28/09/2020', 'Enel']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '25/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Ferrari']
# ['Compro il', '24/09/2020', 'Enel']
# ['Compro il', '25/09/2020', 'Enel']
# ['Compro il', '28/09/2020', 'Ferrari']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '24/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'Ferrari']
# ['Compro il', '15/09/2020', 'Ferrari']
# ['Compro il', '16/09/2020', 'Ferrari']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Ferrari']
# ['Compro il', '23/09/2020', 'Ferrari']
# ['Compro il', '24/09/2020', 'Enel']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'Ferrari']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '23/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Enel']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Enel']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '22/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Ferrari']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'Enel']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '21/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'Ferrari']
# ['Compro il', '15/09/2020', 'Ferrari']
# ['Compro il', '16/09/2020', 'Ferrari']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'Enel']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '18/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Ferrari']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Ferrari']
# ['Compro il', '8/9/2020', 'Ferrari']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'Ferrari']
# ['Compro il', '16/09/2020', 'Ferrari']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '17/09/2020']
# ['Compro il', '31/08/2020', 'Ferrari']
# ['Compro il', '1/9/2020', 'Ferrari']
# ['Compro il', '2/9/2020', 'ENI']
# ['Compro il', '3/9/2020', 'Ferrari']
# ['Compro il', '4/9/2020', 'ENI']
# ['Compro il', '7/9/2020', 'Ferrari']
# ['Compro il', '8/9/2020', 'ENI']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'ENI']
# ['Compro il', '11/9/2020', 'ENI']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'ENI']
# ['Compro il', '16/09/2020', 'Ferrari']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'ENI']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'ENI']
# ['Compro il', '23/09/2020', 'ENI']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '16/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'ENI']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'ENI']
# ['Compro il', '9/9/2020', 'ENI']
# ['Compro il', '10/9/2020', 'ENI']
# ['Compro il', '11/9/2020', 'ENI']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'ENI']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'ENI']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'ENI']
# ['Compro il', '23/09/2020', 'ENI']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '15/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Ferrari']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Intesa San Paolo']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '14/09/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Intesa San Paolo']
# ['Compro il', '14/09/2020', 'Enel']
# ['Compro il', '15/09/2020', 'Intesa San Paolo']
# ['Compro il', '16/09/2020', 'Intesa San Paolo']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Intesa San Paolo']
# ['Compro il', '21/09/2020', 'Intesa San Paolo']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'Intesa San Paolo']
# ['Compro il', '25/09/2020', 'Intesa San Paolo']
# ['Compro il', '28/09/2020', 'Intesa San Paolo']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '11/9/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Enel']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'Enel']
# ['Compro il', '16/09/2020', 'Enel']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Enel']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '10/9/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Intesa San Paolo']
# ['Compro il', '3/9/2020', 'Intesa San Paolo']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Intesa San Paolo']
# ['Compro il', '9/9/2020', 'Intesa San Paolo']
# ['Compro il', '10/9/2020', 'Enel']
# ['Compro il', '11/9/2020', 'Intesa San Paolo']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'Intesa San Paolo']
# ['Compro il', '16/09/2020', 'Intesa San Paolo']
# ['Compro il', '17/09/2020', 'Intesa San Paolo']
# ['Compro il', '18/09/2020', 'Intesa San Paolo']
# ['Compro il', '21/09/2020', 'Intesa San Paolo']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'Intesa San Paolo']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '9/9/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Enel']
# ['Compro il', '10/9/2020', 'Enel']
# ['Compro il', '11/9/2020', 'Intesa San Paolo']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'Intesa San Paolo']
# ['Compro il', '16/09/2020', 'Intesa San Paolo']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Intesa San Paolo']
# ['Compro il', '21/09/2020', 'Intesa San Paolo']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '8/9/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Ferrari']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'Enel']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'Intesa San Paolo']
# ['Compro il', '16/09/2020', 'Ferrari']
# ['Compro il', '17/09/2020', 'Enel']
# ['Compro il', '18/09/2020', 'Intesa San Paolo']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '7/9/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'ENI']
# ['Compro il', '3/9/2020', 'Intesa San Paolo']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'ENI']
# ['Compro il', '9/9/2020', 'ENI']
# ['Compro il', '10/9/2020', 'ENI']
# ['Compro il', '11/9/2020', 'ENI']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'ENI']
# ['Compro il', '16/09/2020', 'Intesa San Paolo']
# ['Compro il', '17/09/2020', 'Intesa San Paolo']
# ['Compro il', '18/09/2020', 'ENI']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'ENI']
# ['Compro il', '23/09/2020', 'ENI']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '4/9/2020']
# ['Compro il', '31/08/2020', 'Ferrari']
# ['Compro il', '1/9/2020', 'Ferrari']
# ['Compro il', '2/9/2020', 'ENI']
# ['Compro il', '3/9/2020', 'Intesa San Paolo']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Ferrari']
# ['Compro il', '8/9/2020', 'ENI']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'ENI']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'ENI']
# ['Compro il', '16/09/2020', 'Intesa San Paolo']
# ['Compro il', '17/09/2020', 'Intesa San Paolo']
# ['Compro il', '18/09/2020', 'Intesa San Paolo']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '3/9/2020']
# ['Compro il', '31/08/2020', 'Enel']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'ENI']
# ['Compro il', '3/9/2020', 'Enel']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Enel']
# ['Compro il', '8/9/2020', 'ENI']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'ENI']
# ['Compro il', '11/9/2020', 'ENI']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'ENI']
# ['Compro il', '16/09/2020', 'Intesa San Paolo']
# ['Compro il', '17/09/2020', 'Intesa San Paolo']
# ['Compro il', '18/09/2020', 'ENI']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'ENI']
# ['Compro il', '23/09/2020', 'ENI']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '2/9/2020']
# ['Compro il', '31/08/2020', 'Ferrari']
# ['Compro il', '1/9/2020', 'Ferrari']
# ['Compro il', '2/9/2020', 'Enel']
# ['Compro il', '3/9/2020', 'Ferrari']
# ['Compro il', '4/9/2020', 'Enel']
# ['Compro il', '7/9/2020', 'Ferrari']
# ['Compro il', '8/9/2020', 'Ferrari']
# ['Compro il', '9/9/2020', 'Ferrari']
# ['Compro il', '10/9/2020', 'Ferrari']
# ['Compro il', '11/9/2020', 'Ferrari']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'Ferrari']
# ['Compro il', '16/09/2020', 'Ferrari']
# ['Compro il', '17/09/2020', 'Ferrari']
# ['Compro il', '18/09/2020', 'Intesa San Paolo']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']
# ['Vendo il', '1/9/2020']
# ['Compro il', '31/08/2020', 'Intesa San Paolo']
# ['Compro il', '1/9/2020', 'Enel']
# ['Compro il', '2/9/2020', 'ENI']
# ['Compro il', '3/9/2020', 'Intesa San Paolo']
# ['Compro il', '4/9/2020', 'ENI']
# ['Compro il', '7/9/2020', 'Intesa San Paolo']
# ['Compro il', '8/9/2020', 'ENI']
# ['Compro il', '9/9/2020', 'ENI']
# ['Compro il', '10/9/2020', 'ENI']
# ['Compro il', '11/9/2020', 'ENI']
# ['Compro il', '14/09/2020', 'ENI']
# ['Compro il', '15/09/2020', 'ENI']
# ['Compro il', '16/09/2020', 'Intesa San Paolo']
# ['Compro il', '17/09/2020', 'Intesa San Paolo']
# ['Compro il', '18/09/2020', 'Intesa San Paolo']
# ['Compro il', '21/09/2020', 'ENI']
# ['Compro il', '22/09/2020', 'Intesa San Paolo']
# ['Compro il', '23/09/2020', 'Intesa San Paolo']
# ['Compro il', '24/09/2020', 'ENI']
# ['Compro il', '25/09/2020', 'ENI']
# ['Compro il', '28/09/2020', 'ENI']
# ['Compro il', '29/09/2020', 'ENI']
# ['Compro il', '30/09/2020', 'ENI']
# ['Compro il', '1/10/2020', 'ENI']

# %% [markdown]
# **1.** Trasponi la lista di liste delle azioni (invertendo righe e colonne) - _1 riga di codice_
#
# **2.** Trova i valori attesi (media) dei prezzi di ognuna delle 4 azioni - _1 riga di codice_
#
# **3.** Trova le deviazioni standard dei prezzi di ognuna delle 4 azioni - _1 riga di codice_
#
# **4.** Salva in una lista di liste tutte le possibili correlazioni tra i prezzi di ognuna delle 4 azioni - _1 riga di codice_
#
# **5.** Trova e salva per ogni giorno il nome dell'azienda la cui azione porterebbe ad un profitto maggiore o una perdita minore (in termini percentuali) se acquistata quel giorno e rivenduta il 2 Ottobre - _1 riga di codice_
#
# **6.** Generalizza il punto 5 anche per giorni precedenti al 2 Ottobre - _1 riga di codice_
#
# **7.** Ripeti il punto 5 nel caso in cui ti interessi identificare il profitto minore o la perdita maggiore - _1 riga di codice_
#
# **FACOLTATIVO** Implementa un CRR (albero binomiale) in grado di prezzare un'opzione call con scadenza 01 / 11 / 2020 per ognuna di queste 4 azioni, stimando ove possibile i parametri necessari. - _tante righe di codice_
#
# Usa le List Comprehension in Python: [expression for item in list]
#
# Per ogni esigenza scrivere a Jean Paul Guglielmo Baroni +393315969286
