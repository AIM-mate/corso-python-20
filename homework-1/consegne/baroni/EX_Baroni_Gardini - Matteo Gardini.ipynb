# %%
Dates = ["31/08/2020","1/9/2020","2/9/2020","3/9/2020","4/9/2020","7/9/2020","8/9/2020",
         "9/9/2020","10/9/2020","11/9/2020","14/09/2020","15/09/2020","16/09/2020","17/09/2020",
         "18/09/2020","21/09/2020","22/09/2020","23/09/2020","24/09/2020","25/09/2020",
         "28/09/2020","29/09/2020","30/09/2020","1/10/2020","2/10/2020"]

Stocks_Name = ["Enel","ENI","Ferrari","Intesa San Paolo"]

Stocks_Value = [[7.558,7.809,163.05,1.8012],
[7.518,7.774,162.85,1.804],
[7.61,7.666,165.4,1.7892],
[7.55,7.696,161.85,1.7758],
[7.392,7.623,160.7,1.7706],
[7.555,7.75,162.6,1.7938],
[7.495,7.542,161.25,1.7604],
[7.663,7.654,160.8,1.7934],
[7.612,7.609,160.05,1.8004],
[7.671,7.597,162.1,1.776],
[7.59,7.475,161.65,1.7768],
[7.627,7.607,162.35,1.7706],
[7.575,7.674,160.7,1.7546],
[7.401,7.633,160.55,1.7404],
[7.42,7.413,159.9,1.72],
[7.25,6.97,154.8,1.632],
[7.362,7.083,156.35,1.6424],
[7.431,6.969,156.45,1.6132],
[7.363,6.82,157.05,1.608],
[7.32,6.677,154.9,1.5806],
[7.465,6.855,157.2,1.6242],
[7.488,6.687,156.25,1.6124],
[7.431,6.685,157.05,1.6054],
[7.442,6.484,157,1.5854],
[7.459,6.472,155,1.5858]]




# Transpose
Stocks_Value_t = [list(x) for x in zip(*Stocks_Value)]
# print(Stocks_Value_t)

# Get the expected Value
# Media dei valori
print("medie")
medie = [sum(x)/len(x) for x in zip(*Stocks_Value)]
#print("media 0 ",medie[0])
#print("media 1 ",medie[1])
#print("media 2",medie[2])
#print("media 3 ",medie[3])

#print(type(medie))

# Get the standard deviation
sds = [sum((x-medie[i])**2/len(Stocks_Value_t[i]) for x in Stocks_Value_t[i])**0.5 for i in range(4)]

#sds0 = [sum((x-medie[0])**2/len(Stocks_Value_t[0]) for x in Stocks_Value_t[0])**0.5]
#sds1 = [sum((x-medie[1])**2/len(Stocks_Value_t[1]) for x in Stocks_Value_t[1])**0.5]
#sds2 = [sum((x-medie[2])**2/len(Stocks_Value_t[2]) for x in Stocks_Value_t[2])**0.5]
#sds3 = [sum((x-medie[3])**2/len(Stocks_Value_t[3]) for x in Stocks_Value_t[3])**0.5]

print("Deviazioni standard")
print(sds)


# Correlation
rho = [[(sum(x*y for x,y in zip(Stocks_Value_t[i],Stocks_Value_t[j]))/len(Stocks_Value_t[i])- 
      medie[i]*medie[j])/(sds[i]*sds[j])] for i in range(4) for j in range(4) if i<j]

print("Correlazioni")
print(rho)
# Out:
# medie
# Deviazioni standard
# [0.1083549426652979, 0.44818866384593, 2.9617400291045124, 0.08426847989610349]
# Correlazioni
# [[0.5993757160949537], [0.7351169431013495], [0.7061394458301924], [0.8969716285710744], [0.9736195146995325], [0.9260913222444812]]

# %%
#Stocks_Value[0][2]
#Stocks_Value[0][:2]
L = len(Stocks_Value)
V = [Stocks_Name[[Stocks_Value[L-1][i]/Stocks_Value[k][i] for i in range(4)].index(max([Stocks_Value[L-1][i]/Stocks_Value[k][i] for i in range(4)]))] for k in range(len(Stocks_Value))] 
print(V)

#idx = L-19
#Values = [Stocks_Value[L-1][i]/Stocks_Value[idx][i] for i in range(4)]
#print(Values)
#print(Stocks_Value[24][:])
#idx = 1
#Values = [[Stocks_Value[L-1][i]/Stocks_Value[idx][i] for i in range(4)] for idx in range(L-2)]
#print(Values)
#id = [Stocks_Value[L-1][i]/Stocks_Value[idx][i] for i in range(4)].index(max([Stocks_Value[L-1][i]/Stocks_Value[idx][i] for i in range(4)]))
#print(id)
# Out:
# ['Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel']

# %%
#Stocks_Value[0][2]
#Stocks_Value[0][:2]
Data_idx = Dates.index("25/09/2020")
print(Data_idx)
L = len(Stocks_Value)
V = [Stocks_Name[[Stocks_Value[Data_idx][i]/Stocks_Value[k][i] for i in range(4)].index(max([Stocks_Value[Data_idx][i]/Stocks_Value[k][i] for i in range(4)]))]
     for k in range(Data_idx)] 
print(V)
# Out:
# 19
# ['Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Ferrari', 'Ferrari', 'Ferrari', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Enel', 'Ferrari', 'Enel']

# %%
L = len(Stocks_Value)
V = [Stocks_Name[[Stocks_Value[L-1][i]/Stocks_Value[k][i] for i in range(4)].index(min([Stocks_Value[L-1][i]/Stocks_Value[k][i] for i in range(4)]))] for k in range(len(Stocks_Value))] 
print(V)
# Out:
# ['ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'ENI', 'Ferrari', 'Enel']
