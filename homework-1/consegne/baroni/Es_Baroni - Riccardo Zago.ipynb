# %%
Dates = ["31/08/2020","1/9/2020","2/9/2020","3/9/2020","4/9/2020","7/9/2020","8/9/2020",
         "9/9/2020","10/9/2020","11/9/2020","14/09/2020","15/09/2020","16/09/2020","17/09/2020",
         "18/09/2020","21/09/2020","22/09/2020","23/09/2020","24/09/2020","25/09/2020",
         "28/09/2020","29/09/2020","30/09/2020","1/10/2020","2/10/2020"]

Names = ["Enel","ENI","Ferrari","Intesa San Paolo"]

Values = [[7.558,7.809,163.05,1.8012],
[7.518,7.774,162.85,1.804],
[7.61,7.666,165.4,1.7892],
[7.55,7.696,161.85,1.7758],
[7.392,7.623,160.7,1.7706],
[7.555,7.75,162.6,1.7938],
[7.495,7.542,161.25,1.7604],
[7.663,7.654,160.8,1.7934],
[7.612,7.609,160.05,1.8004],
[7.671,7.597,162.1,1.776],
[7.59,7.475,161.65,1.7768],
[7.627,7.607,162.35,1.7706],
[7.575,7.674,160.7,1.7546],
[7.401,7.633,160.55,1.7404],
[7.42,7.413,159.9,1.72],
[7.25,6.97,154.8,1.632],
[7.362,7.083,156.35,1.6424],
[7.431,6.969,156.45,1.6132],
[7.363,6.82,157.05,1.608],
[7.32,6.677,154.9,1.5806],
[7.465,6.855,157.2,1.6242],
[7.488,6.687,156.25,1.6124],
[7.431,6.685,157.05,1.6054],
[7.442,6.484,157,1.5854],
[7.459,6.472,155,1.5858]]

# %%
list(map(list, zip(*Values))) #Trasponi la lista di liste delle azioni (invertendo righe e colonne)
# Out:
# [[7.558,
#   7.518,
#   7.61,
#   7.55,
#   7.392,
#   7.555,
#   7.495,
#   7.663,
#   7.612,
#   7.671,
#   7.59,
#   7.627,
#   7.575,
#   7.401,
#   7.42,
#   7.25,
#   7.362,
#   7.431,
#   7.363,
#   7.32,
#   7.465,
#   7.488,
#   7.431,
#   7.442,
#   7.459],
#  [7.809,
#   7.774,
#   7.666,
#   7.696,
#   7.623,
#   7.75,
#   7.542,
#   7.654,
#   7.609,
#   7.597,
#   7.475,
#   7.607,
#   7.674,
#   7.633,
#   7.413,
#   6.97,
#   7.083,
#   6.969,
#   6.82,
#   6.677,
#   6.855,
#   6.687,
#   6.685,
#   6.484,
#   6.472],
#  [163.05,
#   162.85,
#   165.4,
#   161.85,
#   160.7,
#   162.6,
#   161.25,
#   160.8,
#   160.05,
#   162.1,
#   161.65,
#   162.35,
#   160.7,
#   160.55,
#   159.9,
#   154.8,
#   156.35,
#   156.45,
#   157.05,
#   154.9,
#   157.2,
#   156.25,
#   157.05,
#   157,
#   155],
#  [1.8012,
#   1.804,
#   1.7892,
#   1.7758,
#   1.7706,
#   1.7938,
#   1.7604,
#   1.7934,
#   1.8004,
#   1.776,
#   1.7768,
#   1.7706,
#   1.7546,
#   1.7404,
#   1.72,
#   1.632,
#   1.6424,
#   1.6132,
#   1.608,
#   1.5806,
#   1.6242,
#   1.6124,
#   1.6054,
#   1.5854,
#   1.5858]]

# %%
means = [num/len(Values) for num in [sum(i) for i in zip(*Values)]]
#Trova i valori attesi (media) dei prezzi di ognuna delle 4 azioni 
print(means)
# Out:
# [7.489920000000001, 7.288959999999999, 159.514, 1.7086640000000002]

# %%
#sd = [(num/len(Values))**1/2 for num in [sum((i-means[x for x in Range(4)]) for i in zip(*Values))]]
# Out:
#   File "<ipython-input-5-21976741c699>", line 1
#     sd = [(num/len(Values))**1/2 for num in [sum((i-means[x for x in Range(4)]) for i in zip(*Values))]]
#                                                               ^
# SyntaxError: invalid syntax

# %%
#Trova e salva per ogni giorno il nome dell'azienda la cui azione 
#porterebbe ad un profitto maggiore o una perdita minore (in termini percentuali) 
#se acquistata quel giorno e rivenduta il 2 Ottobre

# %%
#Dates , Names, Values

last = max(azienda for azienda in zip(Values,Dates,Names)
print(x)
# Out:
#   File "<ipython-input-52-3fb5173bc760>", line 4
#     print(x)
#     ^
# SyntaxError: invalid syntax

# %%
x = zip(Values,Names)

# %%
print(x)
# Out:
# <zip object at 0x0000020D91B7C1C0>
