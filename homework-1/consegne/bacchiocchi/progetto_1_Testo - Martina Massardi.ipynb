# %%
###PART 1
key=[1,0,1,0,2,2,2,1,1,2,9,9,9,9,6,4,2,7,2,1,4,5,7,8,9,7,3,1,0,0,1,0,3,4,4,5,6,8,9,7,6,5,4,3,2,2,2,2,2,3,3,4,5,6,6,7,8,9,6,4,2,1,4,5]
x0=0

##your code goes here
for indice in range(len(key)):
    key[indice]=key[indice]/(2**(indice+1))
x0=sum(key)

#print(x0)
# Out:
# 1
# 0
# 1
# 0
# 2
# 2
# 2
# 1
# 1
# 2
# 9
# 9
# 9
# 9
# 6
# 4
# 2
# 7
# 2
# 1
# 4
# 5
# 7
# 8
# 9
# 7
# 3
# 1
# 0
# 0
# 1
# 0
# 3
# 4
# 4
# 5
# 6
# 8
# 9
# 7
# 6
# 5
# 4
# 3
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 4
# 5
# 6
# 6
# 7
# 8
# 9
# 6
# 4
# 2
# 1
# 4

# %%
####PART 2
def LogisticMap (x):
    r=3.7
    ##your code goes here
    y=r*x*(1-x)
    return(y)

# %%
###PART 3
def Cryptate (xi,x):
    b=True
    epsilon=1/256
    iterazioni=0
    while b==True:
        ##your code goes here
        c=xi/epsilon
        if (int(c)==ord(x)):
            return iterazioni,xi;
        ##your code goes here   
        else :
            iterazioni+=1
            xi=LogisticMap(xi)

# %%
x="ciao";
it=[];
for i in range(len(x)):
    y=Cryptate(x0,x[i])[1]
    z=Cryptate(x0,x[i])[0]
    it.append(z)
    x0=y
print(it)
# Out:
# [1233, 458, 13, 310]
