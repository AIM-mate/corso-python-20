# %%
###PART 1
key=[1,0,1,0,2,2,2,1,1,2,9,9,9,9,6,4,2,7,2,1,4,5,7,8,9,7,3,1,0,0,1,0,3,4,4,5,6,8,9,7,6,5,4,3,2,2,2,2,2,3,3,4,5,6,6,7,8,9,6,4,2,1,4,5]
x0=0

for i in range(64):
    x0+=(2**(-1-i))*key[i]

print(x0)
# Out:
# 0.7507229274470459

# %%
####PART 2
def LogisticMap (x):
    r=3.7
    y=r*x*(1-x)
    return(y)

# %%
###PART 3
def Cryptate (xi,x):
    b=True
    epsilon=1/256
    iterazioni=0
    while b==True:
        c = xi/epsilon
        if (int(c)==ord(x)):
            return iterazioni,xi;
        else:
            iterazioni=iterazioni+1
            LogisticMap(xi)

# %%
x="ciao";
it=[];
for i in range(len(x)):
    y=Cryptate(x0,x[i])[1]
    z=Cryptate(x0,x[i])[0]
    it.append(z)
    x0=y
print(it)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-45ddeac775f6> in <module>()
#       2 it=[];
#       3 for i in range(len(x)):
# ----> 4     y=Cryptate(x0,x[i])[1]
#       5     z=Cryptate(x0,x[i])[0]
#       6     it.append(z)
#
# <ipython-input-5-995f898a111c> in Cryptate(xi, x)
#       6     while b==True:
#       7         c = xi/epsilon
# ----> 8         if (int(c)==ord(x)):
#       9             return iterazioni,xi;
#      10         else:
#
# KeyboardInterrupt:
