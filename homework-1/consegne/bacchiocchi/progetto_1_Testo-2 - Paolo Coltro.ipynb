# %%
###PART 1
key=[1,0,1,0,2,2,2,1,1,2,9,9,9,9,6,4,2,7,2,1,4,5,7,8,9,7,3,1,0,0,1,0,3,4,4,5,6,8,9,7,6,5,4,3,2,2,2,2,2,3,3,4,5,6,6,7,8,9,6,4,2,1,4,5]
x0=0
for i in range(len(key)):
    x0=x0+key(i)/2**(i+1)   
##your code goes here
print(x0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-3c0751586390> in <module>()
#       3 x0=0
#       4 for i in range(len(key)):
# ----> 5     x0=x0+key(i)/2**(i+1)
#       6 ##your code goes here
#       7 print(x0)
#
# TypeError: 'list' object is not callable

# %%
####PART 2
def LogisticMap (x):
    r=3.7
    y=r*x(1-x)
    ##your code goes here
    return(y)

# %%
###PART 3
def Cryptate (xi,x):
    b=True
    epsilon=1/256
    iterazioni=0
    while b==True:
        c=xi/epsilon
        ##your code goes here
        if (int(c)==ord(x)):
            return iterazioni,xi;
        else
            iterazioni = iterazioni+1
            xi=LogisticMap (xi)
        ##your code goes here

# %%
x="ciao";
it=[];
for i in range(len(x)):
    y=Cryptate(x0,x[i])[1]
    z=Cryptate(x0,x[i])[0]
    it.append(z)
    x0=y
print(it)
