# %%
###PART 1
key=[1,0,1,0,2,2,2,1,1,2,9,9,9,9,6,4,2,7,2,1,4,5,7,8,9,7,3,1,0,0,1,0,3,4,4,5,6,8,9,7,6,5,4,3,2,2,2,2,2,3,3,4,5,6,6,7,8,9,6,4,2,1,4,5]

# Compute x0
x0 = sum(x/2**(i+1) for x,i in zip(key,range(len(key))))

# x0=0
# for i in range(63):
#    x0 = x0 + key[i]/2**(i+1)

print(type(x0))
print(x0)
# Out:
# <class 'float'>
# 0.7507229274470459
# 64

# %%
####PART 2
def LogisticMap (x):
    r=3.7
    y = r*(1-x)*x
    return(y)

# %%
###PART 3
def Cryptate (xi,x):
    b=True
    epsilon=1/256
    iterazioni=0
    while b==True:
        c = xi/epsilon
        if (int(c)==ord(x)):
            return iterazioni,xi;
        iterazioni += 1
        xi = LogisticMap(xi)

# %%
x="ciao";
it=[];
for i in range(len(x)):
    y=Cryptate(x0,x[i])[1]
    z=Cryptate(x0,x[i])[0]
    it.append(z)
    x0=y
print(it)
# Out:
# [244, 382, 347, 463]
