# %% [markdown]
# # Magliette AzIM: ordini, prezzi e consegne

# %% [markdown]
# L'**Azienda degli Ingegneri Matematici** ha bisogno del tuo aiuto: uno stagista chiamato F.B. ha eliminato il database degli ordini delle stupende **magliette ufficiali AzIM**! Tutto quello che rimane sono 420 frammenti di email con le richieste dei clienti, spetta a te recuperarle e determinare che ordini accettare!
#
#
# 0. Nella cartella data trovi tutti i file di testo con i frammenti di email, sono tutti diversi! Contengono la **taglia** delle magliette, la **quantità** di magliette ordinate, la **posizione** in coordinate GCS della consegna, il **nome** del cliente e il **prezzo** a cui vorrebbe acquistare il singolo capo
#
#
# 1. [1pt] Registra gli ordini in una **lista di oggetti** "Order"
#
#
# 2. [1pt] Ogni cliente ha richiesto un prezzo diverso, ma il prezzo di vendita deve essere unico. Considerando 6€ come costo di produzione di una maglietta, determina il **prezzo di vendita** a cui si otterrebbe il maggior  profitto totale (se il prezzo richiesto dal cliente è strettamente inferiore al prezzo di vendita, il cliente non acquisterà)
#
#
# 3. [1pt] Considera i **costi di consegna**: viene applicato un costo di 0.10€/km a capo per per ogni ordine sotto le 100 unità, mentre di 0.05€/km per ogni ordine di almeno 100 unità. Trova il nuovo prezzo di vendita che porti al maggior profitto totale e componi la lista degli ordini da eseguire, riordinata dall'ordine che porterebbe al profitto maggiore fino a quella che porterebbe al profitto minore.
#
#
# 4. [FACOLTATIVO per lode] Considera la curvatura terrestre per il calcolo della distanza per le consegne (riscrivi la funzione "Distance")
#
#
# Utilizza il seguente codice come punto di partenza, riempiendo gli spazi dove manca codice!
#
#
# Per qualsiasi domanda contattare Jean Paul G. Baroni +393315969286

# %%
# 1. Registra gli ordini in una lista di classi Order

GCS_Piazza_Leo = [45.478104, 9.227040] # Coordinate di Piazza Leonardo da Vinci, Milano
production_cost = 6 # Costo fisso di produzione della maglietta
num_orders = 420 # Numero di ordini nella cartella "data"

orders = [] # Lista di oggetti che descrivono gli ordini ricevuti

# Classe che descrive ciascun ordine ricevuto
class Order:
    
    # Costruttore della classe (prende in input il frammento di email salvato nei .txt)
    def __init__(self, email_fragment):
        
        # Separa le righe del frammento e le salva nella lista lines
        lines = email_fragment.split("\n")
        
        # Salva la taglia della maglietta
        self.size = lines[1].split(" ")[-1]
        
        # Salva la quantità di magliette richieste
        l = lines[1].split()
        for i in range(len(l)):
            if l[i].isnumeric():
                m=i
        self.quantity=int(l[m])
        
        # Salva la posizione di consegna dell'ordine come due elementi float di una lista
        self.GCS = [float(lines[2].split(" ")[-1].split(",")[0][1:]),float(lines[2].split(" ")[-1].split(",")[1][:-1])]
        
        # Salva il nome del cliente (ultima riga del txt)
        self.customer = lines[-1]
        
        # Salva il prezzo richiesto dal cliente (bid price)
        self.bid_price = float(lines[3].split()[-1].strip('€'))
    
    # Calcola il pagamento che questo cliente effettuerebbe dato un prezzo di vendita
    def Payment(self, ask_price):
        return self.quantity*ask_price
    
    # Calcola il profitto (ricavi - costi) per un ordine a questo cliente dato un prezzo di vendita
    def Profit(self, ask_price, cost_per_km = 0):
        return Payment(self, ask_price)-production_cost*self.quantity
    
    # Calcola una distanza approssimata in km tra piazza Leonardo da Vinci (punto di partenza delle consegne) e la destinazione
    def Distance(self, starting_GCS = GCS_Piazza_Leo):
        return (((starting_GCS[0] - self.GCS[0])*111)**2+((starting_GCS[1] - self.GCS[1])*78)**2)**0.5
    
    # Stampa i dettagli dell'oggetto
    def Details(self):
        print(self.customer,"ha ordinato",self.quantity,"magliette taglia",self.size,"a "+str(self.bid_price)+"€ all'indirizzo",self.GCS)
    
# Crea gli oggetti Order e li registra nella lista orders
for i in range(num_orders):
    nome=str(num_orders)+'.txt'
    f=open(nome)
    fstr=f.read()
    orders.append(Order(fstr))
    f.close()

# %%
orders
# Out:
# [<__main__.Order at 0x5cf5910>,
#  <__main__.Order at 0x5cf5aa8>,
#  <__main__.Order at 0x5c621f0>,
#  <__main__.Order at 0x5c620e8>,
#  <__main__.Order at 0x5c62658>,
#  <__main__.Order at 0x5c62628>,
#  <__main__.Order at 0x5c62610>,
#  <__main__.Order at 0x5c622b0>,
#  <__main__.Order at 0x57c9328>,
#  <__main__.Order at 0x57c92f8>,
#  <__main__.Order at 0x57c9568>,
#  <__main__.Order at 0x57c9598>,
#  <__main__.Order at 0x57c9cd0>,
#  <__main__.Order at 0x57c9418>,
#  <__main__.Order at 0x57cff58>,
#  <__main__.Order at 0x57cfd30>,
#  <__main__.Order at 0x57cf058>,
#  <__main__.Order at 0x57cff10>,
#  <__main__.Order at 0x57cfe20>,
#  <__main__.Order at 0x57cf460>,
#  <__main__.Order at 0x57cf070>,
#  <__main__.Order at 0x57cf028>,
#  <__main__.Order at 0x57cf538>,
#  <__main__.Order at 0x57cf610>,
#  <__main__.Order at 0x57cf5c8>,
#  <__main__.Order at 0x57cf898>,
#  <__main__.Order at 0x57cfd78>,
#  <__main__.Order at 0x57cffe8>,
#  <__main__.Order at 0x57cfd00>,
#  <__main__.Order at 0x61760d0>,
#  <__main__.Order at 0x6176100>,
#  <__main__.Order at 0x6176130>,
#  <__main__.Order at 0x6176160>,
#  <__main__.Order at 0x6176190>,
#  <__main__.Order at 0x61761c0>,
#  <__main__.Order at 0x61761f0>,
#  <__main__.Order at 0x6176220>,
#  <__main__.Order at 0x6176250>,
#  <__main__.Order at 0x6176280>,
#  <__main__.Order at 0x61762b0>,
#  <__main__.Order at 0x61762e0>,
#  <__main__.Order at 0x6176310>,
#  <__main__.Order at 0x6176340>,
#  <__main__.Order at 0x6176370>,
#  <__main__.Order at 0x61763a0>,
#  <__main__.Order at 0x61763d0>,
#  <__main__.Order at 0x6176400>,
#  <__main__.Order at 0x6176430>,
#  <__main__.Order at 0x6176460>,
#  <__main__.Order at 0x6176490>,
#  <__main__.Order at 0x61764c0>,
#  <__main__.Order at 0x61764f0>,
#  <__main__.Order at 0x6176520>,
#  <__main__.Order at 0x6176550>,
#  <__main__.Order at 0x6176580>,
#  <__main__.Order at 0x61765b0>,
#  <__main__.Order at 0x61765e0>,
#  <__main__.Order at 0x6176610>,
#  <__main__.Order at 0x6176640>,
#  <__main__.Order at 0x6176670>,
#  <__main__.Order at 0x61766a0>,
#  <__main__.Order at 0x61766d0>,
#  <__main__.Order at 0x6176700>,
#  <__main__.Order at 0x6176730>,
#  <__main__.Order at 0x6176760>,
#  <__main__.Order at 0x6176790>,
#  <__main__.Order at 0x61767c0>,
#  <__main__.Order at 0x61767f0>,
#  <__main__.Order at 0x6176820>,
#  <__main__.Order at 0x6176850>,
#  <__main__.Order at 0x6176880>,
#  <__main__.Order at 0x61768b0>,
#  <__main__.Order at 0x61768e0>,
#  <__main__.Order at 0x6176910>,
#  <__main__.Order at 0x6176940>,
#  <__main__.Order at 0x6176970>,
#  <__main__.Order at 0x61769a0>,
#  <__main__.Order at 0x61769d0>,
#  <__main__.Order at 0x6176a00>,
#  <__main__.Order at 0x6176a30>,
#  <__main__.Order at 0x6176a60>,
#  <__main__.Order at 0x6176a90>,
#  <__main__.Order at 0x6176ac0>,
#  <__main__.Order at 0x6176af0>,
#  <__main__.Order at 0x6176b20>,
#  <__main__.Order at 0x6176b50>,
#  <__main__.Order at 0x6176b80>,
#  <__main__.Order at 0x6176bb0>,
#  <__main__.Order at 0x6176be0>,
#  <__main__.Order at 0x6176c10>,
#  <__main__.Order at 0x6176c40>,
#  <__main__.Order at 0x6176c70>,
#  <__main__.Order at 0x6176ca0>,
#  <__main__.Order at 0x6176cd0>,
#  <__main__.Order at 0x6176d00>,
#  <__main__.Order at 0x6176d30>,
#  <__main__.Order at 0x6176d60>,
#  <__main__.Order at 0x6176d90>,
#  <__main__.Order at 0x6176dc0>,
#  <__main__.Order at 0x6176df0>,
#  <__main__.Order at 0x6176e20>,
#  <__main__.Order at 0x6176e50>,
#  <__main__.Order at 0x6176e80>,
#  <__main__.Order at 0x6176eb0>,
#  <__main__.Order at 0x6176ee0>,
#  <__main__.Order at 0x6176f10>,
#  <__main__.Order at 0x6176f40>,
#  <__main__.Order at 0x6176f70>,
#  <__main__.Order at 0x6176fa0>,
#  <__main__.Order at 0x6176fd0>,
#  <__main__.Order at 0x6176fe8>,
#  <__main__.Order at 0x6176058>,
#  <__main__.Order at 0x6170088>,
#  <__main__.Order at 0x61700b8>,
#  <__main__.Order at 0x61700e8>,
#  <__main__.Order at 0x6170118>,
#  <__main__.Order at 0x6170148>,
#  <__main__.Order at 0x6170178>,
#  <__main__.Order at 0x61701a8>,
#  <__main__.Order at 0x61701d8>,
#  <__main__.Order at 0x6170208>,
#  <__main__.Order at 0x6170238>,
#  <__main__.Order at 0x6170268>,
#  <__main__.Order at 0x6170298>,
#  <__main__.Order at 0x61702c8>,
#  <__main__.Order at 0x61702f8>,
#  <__main__.Order at 0x6170328>,
#  <__main__.Order at 0x6170358>,
#  <__main__.Order at 0x6170388>,
#  <__main__.Order at 0x61703b8>,
#  <__main__.Order at 0x61703e8>,
#  <__main__.Order at 0x6170400>,
#  <__main__.Order at 0x6170448>,
#  <__main__.Order at 0x6170490>,
#  <__main__.Order at 0x61704c0>,
#  <__main__.Order at 0x61704f0>,
#  <__main__.Order at 0x6170520>,
#  <__main__.Order at 0x6170550>,
#  <__main__.Order at 0x6170580>,
#  <__main__.Order at 0x61705b0>,
#  <__main__.Order at 0x61705e0>,
#  <__main__.Order at 0x6170610>,
#  <__main__.Order at 0x6170640>,
#  <__main__.Order at 0x6170670>,
#  <__main__.Order at 0x61706a0>,
#  <__main__.Order at 0x61706d0>,
#  <__main__.Order at 0x6170700>,
#  <__main__.Order at 0x6170730>,
#  <__main__.Order at 0x6170760>,
#  <__main__.Order at 0x6170790>,
#  <__main__.Order at 0x61707c0>,
#  <__main__.Order at 0x61707f0>,
#  <__main__.Order at 0x6170820>,
#  <__main__.Order at 0x6170850>,
#  <__main__.Order at 0x6170880>,
#  <__main__.Order at 0x61708b0>,
#  <__main__.Order at 0x61708e0>,
#  <__main__.Order at 0x6170910>,
#  <__main__.Order at 0x6170940>,
#  <__main__.Order at 0x6170970>,
#  <__main__.Order at 0x61709a0>,
#  <__main__.Order at 0x61709d0>,
#  <__main__.Order at 0x6170a00>,
#  <__main__.Order at 0x6170a30>,
#  <__main__.Order at 0x6170a60>,
#  <__main__.Order at 0x6170a90>,
#  <__main__.Order at 0x6170ac0>,
#  <__main__.Order at 0x6170af0>,
#  <__main__.Order at 0x6170b20>,
#  <__main__.Order at 0x6170b50>,
#  <__main__.Order at 0x6170b80>,
#  <__main__.Order at 0x6170bb0>,
#  <__main__.Order at 0x6170be0>,
#  <__main__.Order at 0x6170c10>,
#  <__main__.Order at 0x6170c40>,
#  <__main__.Order at 0x6170c70>,
#  <__main__.Order at 0x6170ca0>,
#  <__main__.Order at 0x6170cd0>,
#  <__main__.Order at 0x6170d00>,
#  <__main__.Order at 0x6170d30>,
#  <__main__.Order at 0x6170d60>,
#  <__main__.Order at 0x6170d90>,
#  <__main__.Order at 0x6170dc0>,
#  <__main__.Order at 0x6170df0>,
#  <__main__.Order at 0x6170e20>,
#  <__main__.Order at 0x6170e50>,
#  <__main__.Order at 0x6170e80>,
#  <__main__.Order at 0x6170eb0>,
#  <__main__.Order at 0x6170ee0>,
#  <__main__.Order at 0x6170f10>,
#  <__main__.Order at 0x6170f40>,
#  <__main__.Order at 0x6170f70>,
#  <__main__.Order at 0x6170fa0>,
#  <__main__.Order at 0x6170fd0>,
#  <__main__.Order at 0x6170fe8>,
#  <__main__.Order at 0x6170460>,
#  <__main__.Order at 0x616f088>,
#  <__main__.Order at 0x616f0b8>,
#  <__main__.Order at 0x616f0e8>,
#  <__main__.Order at 0x616f118>,
#  <__main__.Order at 0x616f148>,
#  <__main__.Order at 0x616f178>,
#  <__main__.Order at 0x616f1a8>,
#  <__main__.Order at 0x616f1d8>,
#  <__main__.Order at 0x616f208>,
#  <__main__.Order at 0x616f238>,
#  <__main__.Order at 0x616f268>,
#  <__main__.Order at 0x616f298>,
#  <__main__.Order at 0x616f2c8>,
#  <__main__.Order at 0x616f2f8>,
#  <__main__.Order at 0x616f328>,
#  <__main__.Order at 0x616f358>,
#  <__main__.Order at 0x616f388>,
#  <__main__.Order at 0x616f3b8>,
#  <__main__.Order at 0x616f3e8>,
#  <__main__.Order at 0x616f418>,
#  <__main__.Order at 0x616f448>,
#  <__main__.Order at 0x616f478>,
#  <__main__.Order at 0x616f4a8>,
#  <__main__.Order at 0x616f4d8>,
#  <__main__.Order at 0x616f508>,
#  <__main__.Order at 0x616f538>,
#  <__main__.Order at 0x616f568>,
#  <__main__.Order at 0x616f598>,
#  <__main__.Order at 0x616f5c8>,
#  <__main__.Order at 0x616f5f8>,
#  <__main__.Order at 0x616f628>,
#  <__main__.Order at 0x616f658>,
#  <__main__.Order at 0x616f688>,
#  <__main__.Order at 0x616f6b8>,
#  <__main__.Order at 0x616f6e8>,
#  <__main__.Order at 0x616f718>,
#  <__main__.Order at 0x616f748>,
#  <__main__.Order at 0x616f778>,
#  <__main__.Order at 0x616f7a8>,
#  <__main__.Order at 0x616f7d8>,
#  <__main__.Order at 0x616f808>,
#  <__main__.Order at 0x616f838>,
#  <__main__.Order at 0x616f868>,
#  <__main__.Order at 0x616f898>,
#  <__main__.Order at 0x616f8c8>,
#  <__main__.Order at 0x616f8f8>,
#  <__main__.Order at 0x616f928>,
#  <__main__.Order at 0x616f958>,
#  <__main__.Order at 0x616f988>,
#  <__main__.Order at 0x616f9b8>,
#  <__main__.Order at 0x616f9e8>,
#  <__main__.Order at 0x616fa18>,
#  <__main__.Order at 0x616fa48>,
#  <__main__.Order at 0x616fa78>,
#  <__main__.Order at 0x616faa8>,
#  <__main__.Order at 0x616fad8>,
#  <__main__.Order at 0x616fb08>,
#  <__main__.Order at 0x616fb38>,
#  <__main__.Order at 0x616fb68>,
#  <__main__.Order at 0x616fb98>,
#  <__main__.Order at 0x616fbc8>,
#  <__main__.Order at 0x616fbf8>,
#  <__main__.Order at 0x616fc28>,
#  <__main__.Order at 0x616fc58>,
#  <__main__.Order at 0x616fc88>,
#  <__main__.Order at 0x616fcb8>,
#  <__main__.Order at 0x616fce8>,
#  <__main__.Order at 0x616fd18>,
#  <__main__.Order at 0x616fd48>,
#  <__main__.Order at 0x616fd78>,
#  <__main__.Order at 0x616fda8>,
#  <__main__.Order at 0x616fdd8>,
#  <__main__.Order at 0x616fe08>,
#  <__main__.Order at 0x616fe38>,
#  <__main__.Order at 0x616fe68>,
#  <__main__.Order at 0x616fe98>,
#  <__main__.Order at 0x616fec8>,
#  <__main__.Order at 0x616fef8>,
#  <__main__.Order at 0x616ff28>,
#  <__main__.Order at 0x616ff58>,
#  <__main__.Order at 0x616ff88>,
#  <__main__.Order at 0x616ffb8>,
#  <__main__.Order at 0x616ffe8>,
#  <__main__.Order at 0x616f040>,
#  <__main__.Order at 0x616f028>,
#  <__main__.Order at 0x61780a0>,
#  <__main__.Order at 0x61780d0>,
#  <__main__.Order at 0x6178100>,
#  <__main__.Order at 0x6178130>,
#  <__main__.Order at 0x6178160>,
#  <__main__.Order at 0x6178190>,
#  <__main__.Order at 0x61781c0>,
#  <__main__.Order at 0x61781f0>,
#  <__main__.Order at 0x6178220>,
#  <__main__.Order at 0x6178250>,
#  <__main__.Order at 0x6178280>,
#  <__main__.Order at 0x61782b0>,
#  <__main__.Order at 0x61782e0>,
#  <__main__.Order at 0x6178310>,
#  <__main__.Order at 0x6178340>,
#  <__main__.Order at 0x6178370>,
#  <__main__.Order at 0x61783a0>,
#  <__main__.Order at 0x61783d0>,
#  <__main__.Order at 0x6178400>,
#  <__main__.Order at 0x6178430>,
#  <__main__.Order at 0x6178460>,
#  <__main__.Order at 0x6178490>,
#  <__main__.Order at 0x61784c0>,
#  <__main__.Order at 0x61784f0>,
#  <__main__.Order at 0x6178520>,
#  <__main__.Order at 0x6178550>,
#  <__main__.Order at 0x6178580>,
#  <__main__.Order at 0x61785b0>,
#  <__main__.Order at 0x61785e0>,
#  <__main__.Order at 0x6178610>,
#  <__main__.Order at 0x6178640>,
#  <__main__.Order at 0x6178670>,
#  <__main__.Order at 0x61786a0>,
#  <__main__.Order at 0x61786d0>,
#  <__main__.Order at 0x6178700>,
#  <__main__.Order at 0x6178730>,
#  <__main__.Order at 0x6178760>,
#  <__main__.Order at 0x6178790>,
#  <__main__.Order at 0x61787c0>,
#  <__main__.Order at 0x61787f0>,
#  <__main__.Order at 0x6178820>,
#  <__main__.Order at 0x6178850>,
#  <__main__.Order at 0x6178880>,
#  <__main__.Order at 0x61788b0>,
#  <__main__.Order at 0x61788e0>,
#  <__main__.Order at 0x6178910>,
#  <__main__.Order at 0x6178940>,
#  <__main__.Order at 0x6178970>,
#  <__main__.Order at 0x61789a0>,
#  <__main__.Order at 0x61789d0>,
#  <__main__.Order at 0x6178a00>,
#  <__main__.Order at 0x6178a30>,
#  <__main__.Order at 0x6178a60>,
#  <__main__.Order at 0x6178a90>,
#  <__main__.Order at 0x6178ac0>,
#  <__main__.Order at 0x6178af0>,
#  <__main__.Order at 0x6178b20>,
#  <__main__.Order at 0x6178b50>,
#  <__main__.Order at 0x6178b80>,
#  <__main__.Order at 0x6178bb0>,
#  <__main__.Order at 0x6178be0>,
#  <__main__.Order at 0x6178c10>,
#  <__main__.Order at 0x6178c40>,
#  <__main__.Order at 0x6178c70>,
#  <__main__.Order at 0x6178ca0>,
#  <__main__.Order at 0x6178cd0>,
#  <__main__.Order at 0x6178d00>,
#  <__main__.Order at 0x6178d30>,
#  <__main__.Order at 0x6178d60>,
#  <__main__.Order at 0x6178d90>,
#  <__main__.Order at 0x6178dc0>,
#  <__main__.Order at 0x6178df0>,
#  <__main__.Order at 0x6178e20>,
#  <__main__.Order at 0x6178e50>,
#  <__main__.Order at 0x6178e80>,
#  <__main__.Order at 0x6178eb0>,
#  <__main__.Order at 0x6178ee0>,
#  <__main__.Order at 0x6178f10>,
#  <__main__.Order at 0x6178f40>,
#  <__main__.Order at 0x6178f70>,
#  <__main__.Order at 0x6178fa0>,
#  <__main__.Order at 0x6178fd0>,
#  <__main__.Order at 0x6178fe8>,
#  <__main__.Order at 0x6178058>,
#  <__main__.Order at 0x617f088>,
#  <__main__.Order at 0x617f0b8>,
#  <__main__.Order at 0x617f0e8>,
#  <__main__.Order at 0x617f118>,
#  <__main__.Order at 0x617f148>,
#  <__main__.Order at 0x617f178>,
#  <__main__.Order at 0x617f1a8>,
#  <__main__.Order at 0x617f1d8>,
#  <__main__.Order at 0x617f208>,
#  <__main__.Order at 0x617f238>,
#  <__main__.Order at 0x617f268>,
#  <__main__.Order at 0x617f298>,
#  <__main__.Order at 0x617f2c8>,
#  <__main__.Order at 0x617f2f8>,
#  <__main__.Order at 0x617f328>,
#  <__main__.Order at 0x617f358>,
#  <__main__.Order at 0x617f388>,
#  <__main__.Order at 0x617f3b8>,
#  <__main__.Order at 0x617f3e8>,
#  <__main__.Order at 0x617f418>,
#  <__main__.Order at 0x617f448>,
#  <__main__.Order at 0x617f478>,
#  <__main__.Order at 0x617f4a8>,
#  <__main__.Order at 0x617f4d8>,
#  <__main__.Order at 0x617f508>,
#  <__main__.Order at 0x617f538>,
#  <__main__.Order at 0x617f568>,
#  <__main__.Order at 0x617f598>,
#  <__main__.Order at 0x617f5c8>,
#  <__main__.Order at 0x617f5f8>,
#  <__main__.Order at 0x617f628>,
#  <__main__.Order at 0x617f658>,
#  <__main__.Order at 0x617f688>,
#  <__main__.Order at 0x617f6b8>,
#  <__main__.Order at 0x617f6e8>,
#  <__main__.Order at 0x617f718>,
#  <__main__.Order at 0x617f748>,
#  <__main__.Order at 0x617f778>,
#  <__main__.Order at 0x617f7a8>,
#  <__main__.Order at 0x617f7d8>,
#  <__main__.Order at 0x617f808>,
#  <__main__.Order at 0x617f838>,
#  <__main__.Order at 0x617f868>,
#  <__main__.Order at 0x617f898>,
#  <__main__.Order at 0x617f8c8>,
#  <__main__.Order at 0x617f8f8>,
#  <__main__.Order at 0x617f928>,
#  <__main__.Order at 0x617f958>,
#  <__main__.Order at 0x617f988>,
#  <__main__.Order at 0x617f9b8>,
#  <__main__.Order at 0x617f9e8>,
#  <__main__.Order at 0x617fa18>,
#  <__main__.Order at 0x617fa48>,
#  <__main__.Order at 0x617fa78>,
#  <__main__.Order at 0x617faa8>]

# %%
# 2. [1pt] Ogni cliente ha richiesto un prezzo diverso, ma il prezzo di vendita deve essere unico. Considerando 6€ come costo di produzione di una maglietta, determina il **prezzo di vendita** a cui si otterrebbe il maggior  profitto totale (se il prezzo richiesto dal cliente è strettamente inferiore al prezzo di vendita, il cliente non acquisterà)

# Determina i profitti per tutti i possibili prezzi di vendita, riferendosi ai prezzi richiesti dai clienti 
possible_profits = _######## SCRIVI CODICE ########
#_ = [print(pp) for pp in possible_profits]

# Determina il profitto maggiore
max_profit = _######## SCRIVI CODICE ########

# Determina il prezzo migliore
best_price = _######## SCRIVI CODICE ########
print("Il miglior prezzo è €"+str(best_price))

# Trova gli ordini da eseguire dato il miglior prezzo
orders_to_go = [ord1 for ord1 in orders if ord1.Profit(best_price) > 0]
print("Si eseguiranno", len(orders_to_go),"ordini")
# Out:
# Il miglior prezzo è €
# Si eseguiranno 0 ordini

# %%
# 3. [1pt] Considera i **costi di consegna**: viene applicato un costo di 0.10€/km a capo per per ogni ordine sotto le 100 unità, mentre di 0.05€/km per ogni ordine di almeno 100 unità. Trova il nuovo prezzo di vendita che porti al maggior profitto totale e componi la lista degli ordini da eseguire, riordinata dall'ordine che porterebbe al profitto maggiore fino a quella che porterebbe al profitto minore.

cost_less_100 = 0.10
cost_at_least_100 = 0.05

# Determina i profitti per tutti i possibili prezzi di vendita, riferendosi ai prezzi richiesti dai clienti 
possible_profits = _######## SCRIVI CODICE ########
#_ = [print(pp) for pp in possible_profits]

# Determina il profitto maggiore
max_profit = _######## SCRIVI CODICE ########

# Determina il prezzo migliore
best_price = _######## SCRIVI CODICE ########
print("Il miglior prezzo è €"+str(best_price))

# Trova gli ordini da eseguire dato il miglior prezzo
orders_to_go = _######## SCRIVI CODICE ########
print("Si eseguiranno", len(orders_to_go),"ordini")

######## SCRIVI CODICE ########
# ... assembla la lista degli ordini che devono che si possono soddisfare, dando precedenza a quelli che portano maggiore profitto
######## SCRIVI CODICE ########

_ = [otg.Details() for otg in orders_to_go]
# Out:
# Il miglior prezzo è €
# Si eseguiranno 0 ordini
