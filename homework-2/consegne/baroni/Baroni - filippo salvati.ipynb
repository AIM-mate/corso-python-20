# %% [markdown]
# Baroni

# %%
# 1. Registra gli ordini in una lista di classi Order

GCS_Piazza_Leo = [45.478104, 9.227040] # Coordinate di Piazza Leonardo da Vinci, Milano
production_cost = 6 # Costo fisso di produzione della maglietta
num_orders = 420 # Numero di ordini nella cartella "data"

orders = [] # Lista di oggetti che descrivono gli ordini ricevuti

# Classe che descrive ciascun ordine ricevuto
class Order:
    
    # Costruttore della classe (prende in input il frammento di email salvato nei .txt)
    def __init__(self, email_fragment):
        
        # Separa le righe del frammento e le salva nella lista lines
        lines = email_fragment.split("\n")
        
        # Salva la taglia della maglietta
        self.size = lines[1].split(" ")[-1]
        
        # Salva la quantità di magliette richieste
        self.quantity = float(lines[1].split(" ")[-5])
        
        # Salva la posizione di consegna dell'ordine come due elementi float di una lista
        self.GCS = [float(lines[2].split(" ")[-1].split(",")[0][1:]),float(lines[2].split(" ")[-1].split(",")[1][:-1])]
        
        # Salva il nome del cliente (ultima riga del txt)
        self.customer = [str(lines[5].split(" "))]
        
        # Salva il prezzo richiesto dal cliente (bid price)
        self.bid_price = float(lines[3].split(" ")[-1][:-1])
    
    # Calcola il pagamento che questo cliente effettuerebbe dato un prezzo di vendita
    def Payment(self, ask_price):
         return self.quantiity*ask_price
    
    # Calcola il profitto (ricavi - costi) per un ordine a questo cliente dato un prezzo di vendita
    def Profit(self, ask_price, cost_per_km = 0):
        return self.quantity*(ask_price-cost_per_km-production_cost)
    
    # Calcola una distanza approssimata in km tra piazza Leonardo da Vinci (punto di partenza delle consegne) e la destinazione
    def Distance(self, starting_GCS = GCS_Piazza_Leo):
        return (((starting_GCS[0] - self.GCS[0])*111)**2+((starting_GCS[1] - self.GCS[1])*78)**2)**0.5
    
    # Stampa i dettagli dell'oggetto
    def Details(self):
        print(self.customer,"ha ordinato",self.quantity,"magliette taglia",self.size,"a "+str(self.bid_price)+"€ all'indirizzo",self.GCS)
    
# Crea gli oggetti Order e li registra nella lista orders

for i in range(num_orders):
    file = open("data/"+str(i+1)+".txt","r",encoding="latin1")
    testo = file.read()
    orders.append(Order(testo))
    file.close()

# %%
# 2. [1pt] Ogni cliente ha richiesto un prezzo diverso, ma il prezzo di vendita deve essere unico. Considerando 6€ come costo di produzione di una maglietta, 
#determina il **prezzo di vendita** a cui si otterrebbe il maggior  profitto totale (se il prezzo richiesto dal cliente è strettamente inferiore al prezzo di 
#vendita, il cliente non acquisterà)


# Determina i profitti per tutti i possibili prezzi di vendita, riferendosi ai prezzi richiesti dai clienti 

possible_profits=[]
prezzo_min=6
for i in range(num_orders):
    Sum_Profit=0;
    for j in range(num_orders):
        if (orders[j].bid_price>=orders[i].bid_price ):
            Sum_Profit+=(orders[j].Profit(orders[i].bid_price,0))
    possible_profits.append(Sum_Profit)
            
# Determina il profitto maggiore

max_profit = max(possible_profits)


# Determina il prezzo migliore
#cerco l'indice relativo al profitto maggiore
for i in range(num_orders):
    if max_profit==possible_profits[i]:
        best_price = orders[i].bid_price
        
print("Il miglior prezzo è €"+str(best_price))

# Trova gli ordini da eseguire dato il miglior prezzo
orders_to_go = [ord1 for ord1 in orders if ord1.Profit(best_price) > 0]
print("Si eseguiranno", len(orders_to_go),"ordini")
# Out:
# Il miglior prezzo è €13.22
# Si eseguiranno 420 ordini

# %%
3. #[1pt] Considera i **costi di consegna**: viene applicato un costo di 0.10€/km a capo per per ogni ordine sotto le 100 unità,
#mentre di 0.05€/km per ogni ordine di almeno 100 unità. Trova il nuovo prezzo di vendita che porti al maggior profitto totale e 
#componi la lista degli ordini da eseguire, riordinata dall'ordine che porterebbe al profitto maggiore fino a quella che porterebbe 
#al profitto minore.

cost_less_100 = 0.10
cost_at_least_100 = 0.05
possible_profits=[]
for i in range(num_orders):
    Sum_Profit=0
    for j in range(num_orders):
        if (orders[j].bid_price>=orders[i].bid_price ):
            if (orders[i].quantity>=100):
                Sum_Profit+=(orders[j].Profit(orders[i].bid_price,cost_at_least_100*orders[i].Distance(orders[i].GCS)))
            else: 
                Sum_Profit+=(orders[j].Profit(orders[i].bid_price,cost_less_100*orders[i].Distance(orders[i].GCS)))
    possible_profits.append(Sum_Profit)


#_ = [print(pp) for pp in possible_profit]
# Determina il profitto maggiore
max_profit = max(possible_profits)


# Determina il prezzo migliore
for i in range(num_orders):
    if max_profit==possible_profits[i]:
        j=i
best_price = orders[j].bid_price
print("Il miglior prezzo è €"+str(best_price))
      

# Trova gli ordini da eseguire dato il miglior prezzo
orders_to_go = [ord1 for ord1 in orders if ord1.Profit(best_price) > 0]
print("Si eseguiranno", len(orders_to_go),"ordini")

######## SCRIVI CODICE ########
# ... assembla la lista degli ordini che devono che si possono soddisfare, dando precedenza a quelli che portano maggiore profitto
Profitti=[]
for i in range(num_orders):
    if orders[i].Profit(best_price)>0:
        Profitti.append(orders[i].Profit(best_price))
      
Profitti.sort()


nuovalista=[]
for i in range(num_orders):
    for j in range (num_orders):
        if (Profitti[i]==orders[j].Profit(best_price) and Profitti[i]!=Profitti[i-1] and Profitti[i]!=Profitti[i+1]):
            nuovalista.append(orders[i])

    
nuovalista= [otg.Details() for otg in orders_to_go]
# Out:
# Il miglior prezzo è €13.22
# Si eseguiranno 420 ordini
# ["['Maurizio', 'Genalti', 'Racing']"] ha ordinato 383.0 magliette taglia L a 13.35€ all'indirizzo [44.730801, 10.411061]
# ["['Enrico', 'Zacchei', 'IB']"] ha ordinato 33.0 magliette taglia S a 19.16€ all'indirizzo [45.386683, 8.176936]
# ["['Luca', 'Bressan', 'e', 'Fratelli']"] ha ordinato 316.0 magliette taglia L a 19.58€ all'indirizzo [46.389283, 11.742332]
# ["['Angelica', 'Fedeli', 'e', 'Sorelle']"] ha ordinato 255.0 magliette taglia M a 16.6€ all'indirizzo [44.983867, 9.346757]
# ["['Angelica', 'Cerisola', 'Azienda', 'Agricola']"] ha ordinato 389.0 magliette taglia M a 11.37€ all'indirizzo [45.219274, 10.508013]
# ["['Valentina', 'Calcaterra', 'Franchising']"] ha ordinato 398.0 magliette taglia S a 6.98€ all'indirizzo [46.078556, 10.47238]
# ["['JP', 'Iacovelli', 'SPA']"] ha ordinato 29.0 magliette taglia XXL a 19.96€ all'indirizzo [46.035413, 6.990662]
# ["['Angelica', 'Calcaterra', 'Strumenti', 'Musicali']"] ha ordinato 307.0 magliette taglia M a 15.22€ all'indirizzo [45.900417, 11.562795]
# ["['JP', 'Bacchiocchi', 'INC.']"] ha ordinato 384.0 magliette taglia M a 7.42€ all'indirizzo [45.952838, 8.110702]
# ["['Gianmarco', 'Sosta', 'Giocattoli']"] ha ordinato 357.0 magliette taglia XS a 15.86€ all'indirizzo [45.804997, 8.586271]
# ["['Gianmarco', 'Carrara', 'Grissini']"] ha ordinato 293.0 magliette taglia M a 10.9€ all'indirizzo [44.489075, 8.228872]
# ["['MC', 'Sosta', 'SRL']"] ha ordinato 290.0 magliette taglia M a 16.02€ all'indirizzo [45.288814, 7.365348]
# ["['Carlo', 'Augusto', 'Bressan', 'Franchising']"] ha ordinato 332.0 magliette taglia M a 10.14€ all'indirizzo [45.009923, 7.999855]
# ["['Gianmarco', 'Moneta', 'Franchising']"] ha ordinato 14.0 magliette taglia XXL a 11.01€ all'indirizzo [46.134554, 8.462378]
# ["['MC', 'Iacovelli', 'e', 'Sorelle']"] ha ordinato 142.0 magliette taglia XS a 18.21€ all'indirizzo [45.835345, 7.52385]
# ["['Angelica', 'Fedeli', 'Frutta', 'e', 'Verdura']"] ha ordinato 28.0 magliette taglia XXL a 9.93€ all'indirizzo [45.79175, 8.469861]
# ["['Luca', 'Zacchei', 'Giocattoli']"] ha ordinato 68.0 magliette taglia XXL a 6.76€ all'indirizzo [44.409662, 9.031251]
# ["['Enrico', 'Moneta', 'Automotive']"] ha ordinato 128.0 magliette taglia XL a 13.74€ all'indirizzo [45.563787, 7.149919]
# ["['Carlo', 'Augusto', 'Bacchiocchi', 'Latte']"] ha ordinato 287.0 magliette taglia L a 19.81€ all'indirizzo [45.507751, 6.527303]
# ["['Mirko', 'Fedeli', 'Tentazioni']"] ha ordinato 346.0 magliette taglia XL a 6.43€ all'indirizzo [45.53303, 10.609156]
# ["['Francesco', 'Sartor', 'Mascherine']"] ha ordinato 318.0 magliette taglia L a 16.02€ all'indirizzo [45.760935, 9.123703]
# ["['Angelica', 'Sosta', 'Servizi', 'Finanziari']"] ha ordinato 162.0 magliette taglia L a 8.82€ all'indirizzo [45.887112, 11.544101]
# ['[\'Luca\', \'Moneta\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 377.0 magliette taglia L a 16.8€ all'indirizzo [46.067706, 6.750235]
# ["['Maurizio', 'Sartor', 'Frumento']"] ha ordinato 471.0 magliette taglia M a 13.26€ all'indirizzo [45.144346, 9.944353]
# ["['Giulia', 'Cerisola', 'Strumenti', 'Musicali']"] ha ordinato 81.0 magliette taglia S a 10.42€ all'indirizzo [44.40202, 7.343031]
# ["['MC', 'Vitellio', 'SRL']"] ha ordinato 321.0 magliette taglia M a 6.79€ all'indirizzo [46.499945, 8.878639]
# ["['Gianmarco', 'Moneta', 'Ingranaggi']"] ha ordinato 344.0 magliette taglia XXL a 15.2€ all'indirizzo [44.645446, 11.774198]
# ["['Giulia', 'Vitellio', 'Grissini']"] ha ordinato 150.0 magliette taglia XXL a 7.98€ all'indirizzo [45.473989, 9.9247]
# ["['Filippo', 'Iacovelli', 'IB']"] ha ordinato 467.0 magliette taglia L a 18.25€ all'indirizzo [46.042605, 11.075677]
# ["['Alessandro', 'Zacchei', 'Trasporti']"] ha ordinato 21.0 magliette taglia S a 11.1€ all'indirizzo [46.016915, 8.937018]
# ["['Davide', 'Calcaterra', 'Frutta', 'e', 'Verdura']"] ha ordinato 304.0 magliette taglia M a 17.36€ all'indirizzo [45.358661, 10.98252]
# ["['Filippo', 'Iacovelli', 'Mascherine']"] ha ordinato 120.0 magliette taglia XXL a 17.13€ all'indirizzo [46.159635, 9.856807]
# ["['Francesco', 'Bressan', 'INC.']"] ha ordinato 277.0 magliette taglia XS a 19.51€ all'indirizzo [44.827737, 10.648823]
# ["['Manuel', 'Moneta', 'Trasporti']"] ha ordinato 238.0 magliette taglia XS a 6.52€ all'indirizzo [44.731015, 7.286118]
# ["['Filippo', 'Bacchiocchi', 'Ingranaggi']"] ha ordinato 425.0 magliette taglia M a 6.6€ all'indirizzo [46.419172, 11.179651]
# ["['Angelica', 'Moneta', 'Frutta', 'e', 'Verdura']"] ha ordinato 32.0 magliette taglia M a 18.95€ all'indirizzo [45.273024, 10.134945]
# ["['Valentina', 'Fedeli', 'Servizi', 'Finanziari']"] ha ordinato 425.0 magliette taglia XL a 13.73€ all'indirizzo [45.629606, 9.662371]
# ["['Francesco', 'Genalti', 'Co.']"] ha ordinato 272.0 magliette taglia L a 12.56€ all'indirizzo [46.346911, 11.284011]
# ["['Maurizio', 'Moneta', 'Azienda', 'Agricola']"] ha ordinato 344.0 magliette taglia S a 15.29€ all'indirizzo [44.764578, 10.322331]
# ["['Maurizio', 'Genalti', 'Racing']"] ha ordinato 159.0 magliette taglia M a 8.84€ all'indirizzo [44.592882, 9.60751]
# ["['Davide', 'Cerisola', 'Co.']"] ha ordinato 493.0 magliette taglia XL a 6.32€ all'indirizzo [45.771298, 7.518309]
# ["['Filippo', 'Cerisola', 'Formaggi']"] ha ordinato 451.0 magliette taglia L a 19.75€ all'indirizzo [46.430318, 8.170284]
# ["['Alessandro', 'Genalti', 'e', 'Sorelle']"] ha ordinato 377.0 magliette taglia L a 13.9€ all'indirizzo [45.860871, 7.417076]
# ['[\'Davide\', \'Cerisola\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 181.0 magliette taglia S a 14.33€ all'indirizzo [46.345313, 10.474108]
# ["['Enrico', 'Iacovelli', 'Latte']"] ha ordinato 460.0 magliette taglia XL a 5.1€ all'indirizzo [44.959459, 9.934886]
# ["['Mirko', 'Vitellio', 'IB']"] ha ordinato 274.0 magliette taglia XXL a 14.25€ all'indirizzo [45.347228, 12.149067]
# ["['Maurizio', 'Baroni', 'Azienda', 'Agricola']"] ha ordinato 360.0 magliette taglia M a 17.72€ all'indirizzo [45.069648, 9.03768]
# ["['Enrico', 'Iacovelli', 'e', 'Fratelli']"] ha ordinato 274.0 magliette taglia M a 11.42€ all'indirizzo [45.960063, 10.152785]
# ["['Francesco', 'Moneta', 'Formaggi']"] ha ordinato 193.0 magliette taglia S a 8.0€ all'indirizzo [46.018942, 6.997048]
# ["['Gianmarco', 'Mescolini', 'IB']"] ha ordinato 15.0 magliette taglia XL a 10.15€ all'indirizzo [44.876913, 8.309221]
# ["['MC', 'Vitellio', 'Tentazioni']"] ha ordinato 28.0 magliette taglia M a 18.83€ all'indirizzo [44.727278, 8.353823]
# ["['Filippo', 'Calcaterra', 'Formaggi']"] ha ordinato 267.0 magliette taglia M a 7.61€ all'indirizzo [45.269254, 6.503263]
# ["['Enrico', 'Sosta', 'Giocattoli']"] ha ordinato 304.0 magliette taglia L a 8.12€ all'indirizzo [45.888022, 11.428231]
# ["['Alessandro', 'Baroni', 'INC.']"] ha ordinato 217.0 magliette taglia M a 8.95€ all'indirizzo [44.603634, 7.458123]
# ["['Valentina', 'Bressan', 'e', 'Fratelli']"] ha ordinato 271.0 magliette taglia XL a 16.51€ all'indirizzo [45.384287, 6.751064]
# ["['Filippo', 'Bacchiocchi', 'e', 'Fratelli']"] ha ordinato 479.0 magliette taglia S a 7.69€ all'indirizzo [46.37435, 11.665691]
# ["['Valentina', 'Genalti', 'Automotive']"] ha ordinato 287.0 magliette taglia XS a 9.49€ all'indirizzo [44.414104, 9.005882]
# ["['Filippo', 'Vitellio', 'Racing']"] ha ordinato 102.0 magliette taglia L a 9.96€ all'indirizzo [45.280389, 7.992829]
# ["['Gianmarco', 'Sgarbossa', 'Azienda', 'Agricola']"] ha ordinato 69.0 magliette taglia XS a 5.24€ all'indirizzo [46.362928, 9.216934]
# ["['Carlo', 'Augusto', 'Moneta', 'Formaggi']"] ha ordinato 13.0 magliette taglia XXL a 15.69€ all'indirizzo [46.046634, 10.463574]
# ["['JP', 'Carrara', 'IB']"] ha ordinato 350.0 magliette taglia XL a 13.55€ all'indirizzo [45.459595, 6.461555]
# ["['Giulia', 'Bacchiocchi', 'Azienda', 'Agricola']"] ha ordinato 311.0 magliette taglia XS a 7.71€ all'indirizzo [45.570293, 10.560759]
# ["['Mirko', 'Vitellio', 'Latte']"] ha ordinato 116.0 magliette taglia XL a 7.58€ all'indirizzo [44.859483, 11.265689]
# ["['Filippo', 'Sgarbossa', 'INC.']"] ha ordinato 131.0 magliette taglia S a 17.99€ all'indirizzo [44.991219, 7.331487]
# ["['Valentina', 'Sartor', 'Grissini']"] ha ordinato 69.0 magliette taglia L a 17.56€ all'indirizzo [45.694427, 11.603784]
# ["['Francesco', 'Genalti', 'SRL']"] ha ordinato 141.0 magliette taglia XS a 16.38€ all'indirizzo [45.581672, 8.188537]
# ["['Angelica', 'Mescolini', 'Franchising']"] ha ordinato 228.0 magliette taglia L a 12.13€ all'indirizzo [46.081679, 7.057057]
# ["['Maurizio', 'Bacchiocchi', 'Tentazioni']"] ha ordinato 253.0 magliette taglia XXL a 8.08€ all'indirizzo [46.375028, 10.979098]
# ["['Enrico', 'Calcaterra', 'SRL']"] ha ordinato 438.0 magliette taglia XS a 14.53€ all'indirizzo [46.16169, 7.658148]
# ["['Valentina', 'Mescolini', 'Automotive']"] ha ordinato 153.0 magliette taglia XS a 19.69€ all'indirizzo [44.485797, 7.627326]
# ["['Filippo', 'Baroni', 'Frutta', 'e', 'Verdura']"] ha ordinato 399.0 magliette taglia XS a 14.88€ all'indirizzo [44.679291, 10.342392]
# ["['MC', 'Baroni', 'Co.']"] ha ordinato 435.0 magliette taglia XL a 14.14€ all'indirizzo [46.646765, 11.645491]
# ["['Angelica', 'Calcaterra', 'Azienda', 'Agricola']"] ha ordinato 486.0 magliette taglia XS a 12.88€ all'indirizzo [45.420593, 8.805503]
# ["['Valentina', 'Mescolini', 'Tentazioni']"] ha ordinato 259.0 magliette taglia L a 15.11€ all'indirizzo [45.614209, 7.809756]
# ["['Alessandro', 'Baroni', 'Frumento']"] ha ordinato 477.0 magliette taglia S a 7.07€ all'indirizzo [45.405947, 8.556387]
# ["['Enrico', 'Cerisola', 'Giocattoli']"] ha ordinato 46.0 magliette taglia XS a 9.96€ all'indirizzo [45.034209, 7.417165]
# ["['Mirko', 'Sosta', 'e', 'Fratelli']"] ha ordinato 380.0 magliette taglia M a 7.69€ all'indirizzo [46.202755, 9.779329]
# ["['Filippo', 'Iacovelli', 'Frumento']"] ha ordinato 428.0 magliette taglia S a 18.41€ all'indirizzo [45.406647, 10.68733]
# ["['Angelica', 'Iacovelli', 'Giocattoli']"] ha ordinato 339.0 magliette taglia XS a 15.67€ all'indirizzo [46.504628, 7.672028]
# ["['Filippo', 'Iacovelli', 'Strumenti', 'Musicali']"] ha ordinato 222.0 magliette taglia M a 19.05€ all'indirizzo [45.339915, 6.812426]
# ["['Maurizio', 'Bressan', 'e', 'Sorelle']"] ha ordinato 338.0 magliette taglia XL a 7.72€ all'indirizzo [46.616596, 8.733071]
# ["['Gianmarco', 'Sartor', 'Componentistiche']"] ha ordinato 275.0 magliette taglia M a 16.68€ all'indirizzo [46.396994, 12.229419]
# ["['Carlo', 'Augusto', 'Mescolini', 'Tentazioni']"] ha ordinato 340.0 magliette taglia XXL a 16.49€ all'indirizzo [46.385237, 11.280217]
# ["['Mirko', 'Iacovelli', 'Automotive']"] ha ordinato 282.0 magliette taglia M a 10.72€ all'indirizzo [46.491345, 8.656534]
# ["['JP', 'Genalti', 'Mascherine']"] ha ordinato 72.0 magliette taglia S a 15.82€ all'indirizzo [45.730671, 11.698629]
# ["['Alessandro', 'Moneta', 'Ingranaggi']"] ha ordinato 184.0 magliette taglia L a 19.47€ all'indirizzo [44.703475, 9.736538]
# ["['Carlo', 'Augusto', 'Sartor', 'Ingranaggi']"] ha ordinato 253.0 magliette taglia L a 17.22€ all'indirizzo [45.749084, 11.770167]
# ["['Angelica', 'Iacovelli', 'INC.']"] ha ordinato 19.0 magliette taglia XL a 8.0€ all'indirizzo [44.753345, 8.300317]
# ["['JP', 'Moneta', 'e', 'Sorelle']"] ha ordinato 55.0 magliette taglia L a 19.93€ all'indirizzo [45.677897, 7.120169]
# ["['Giulia', 'Iacovelli', 'Ingranaggi']"] ha ordinato 239.0 magliette taglia XXL a 13.31€ all'indirizzo [45.824062, 8.276641]
# ["['Luca', 'Zacchei', 'e', 'Sorelle']"] ha ordinato 294.0 magliette taglia S a 14.62€ all'indirizzo [44.562334, 10.118565]
# ["['Valentina', 'Vitellio', 'Azienda', 'Agricola']"] ha ordinato 270.0 magliette taglia XXL a 8.97€ all'indirizzo [44.977718, 8.638279]
# ["['Angelica', 'Sartor', 'Frutta', 'e', 'Verdura']"] ha ordinato 314.0 magliette taglia XXL a 8.61€ all'indirizzo [45.069462, 6.942543]
# ["['Carlo', 'Augusto', 'Fedeli', 'Latte']"] ha ordinato 226.0 magliette taglia XS a 5.38€ all'indirizzo [46.609277, 11.483217]
# ["['Manuel', 'Bacchiocchi', 'Formaggi']"] ha ordinato 126.0 magliette taglia L a 8.91€ all'indirizzo [46.653024, 7.189664]
# ["['Angelica', 'Sgarbossa', 'Company']"] ha ordinato 187.0 magliette taglia XXL a 6.71€ all'indirizzo [44.603494, 8.832301]
# ["['Manuel', 'Carrara', 'Strumenti', 'Musicali']"] ha ordinato 220.0 magliette taglia S a 10.35€ all'indirizzo [46.375881, 11.67407]
# ["['Alessandro', 'Bressan', 'Ingranaggi']"] ha ordinato 225.0 magliette taglia S a 18.09€ all'indirizzo [44.462696, 8.818987]
# ["['Enrico', 'Bressan', 'e', 'Sorelle']"] ha ordinato 477.0 magliette taglia XXL a 6.36€ all'indirizzo [46.082036, 8.249885]
# ['[\'Valentina\', \'Sgarbossa\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 172.0 magliette taglia S a 17.51€ all'indirizzo [45.028921, 6.801111]
# ["['Manuel', 'Iacovelli', 'INC.']"] ha ordinato 166.0 magliette taglia XS a 6.24€ all'indirizzo [44.606886, 10.956388]
# ["['Enrico', 'Mescolini', 'Servizi', 'Finanziari']"] ha ordinato 223.0 magliette taglia XXL a 16.11€ all'indirizzo [46.250162, 7.744354]
# ["['Angelica', 'Zacchei', 'INC.']"] ha ordinato 112.0 magliette taglia M a 16.41€ all'indirizzo [45.906026, 12.148476]
# ["['Francesco', 'Iacovelli', 'SPA']"] ha ordinato 245.0 magliette taglia L a 19.87€ all'indirizzo [46.633524, 12.232977]
# ["['Francesco', 'Carrara', 'e', 'Fratelli']"] ha ordinato 475.0 magliette taglia XL a 16.62€ all'indirizzo [44.617157, 11.309934]
# ["['Carlo', 'Augusto', 'Bressan', 'e', 'Fratelli']"] ha ordinato 279.0 magliette taglia S a 10.32€ all'indirizzo [45.886689, 7.03336]
# ["['Angelica', 'Bacchiocchi', 'Strumenti', 'Musicali']"] ha ordinato 95.0 magliette taglia M a 13.87€ all'indirizzo [45.794128, 8.917028]
# ["['Gianmarco', 'Carrara', 'Frutta', 'e', 'Verdura']"] ha ordinato 70.0 magliette taglia XL a 16.75€ all'indirizzo [44.831715, 7.603881]
# ["['Francesco', 'Sgarbossa', 'Racing']"] ha ordinato 223.0 magliette taglia M a 11.05€ all'indirizzo [46.473475, 12.166272]
# ["['Gianmarco', 'Moneta', 'Frumento']"] ha ordinato 227.0 magliette taglia M a 14.42€ all'indirizzo [45.121825, 10.002931]
# ["['Maurizio', 'Fedeli', 'Trasporti']"] ha ordinato 475.0 magliette taglia XL a 16.9€ all'indirizzo [46.141592, 11.350406]
# ['[\'Enrico\', \'Bacchiocchi\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 455.0 magliette taglia XXL a 12.41€ all'indirizzo [46.520216, 7.292619]
# ['[\'MC\', \'Bressan\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 365.0 magliette taglia M a 19.59€ all'indirizzo [45.410533, 7.184282]
# ["['Angelica', 'Cerisola', 'Frumento']"] ha ordinato 211.0 magliette taglia XS a 9.04€ all'indirizzo [46.297218, 12.212059]
# ["['Maurizio', 'Bressan', 'Latte']"] ha ordinato 291.0 magliette taglia L a 13.82€ all'indirizzo [44.703945, 12.034479]
# ["['Alessandro', 'Sartor', 'Mascherine']"] ha ordinato 15.0 magliette taglia XL a 10.18€ all'indirizzo [46.107554, 10.863507]
# ["['JP', 'Genalti', 'Servizi', 'Finanziari']"] ha ordinato 206.0 magliette taglia XS a 8.96€ all'indirizzo [45.200488, 10.898501]
# ["['Davide', 'Sosta', 'Mascherine']"] ha ordinato 418.0 magliette taglia L a 13.74€ all'indirizzo [45.831319, 11.731695]
# ["['MC', 'Bressan', 'INC.']"] ha ordinato 172.0 magliette taglia XXL a 14.55€ all'indirizzo [46.263073, 8.774522]
# ["['Maurizio', 'Sosta', 'IB']"] ha ordinato 308.0 magliette taglia S a 6.03€ all'indirizzo [46.131793, 10.541194]
# ["['Filippo', 'Fedeli', 'Tentazioni']"] ha ordinato 363.0 magliette taglia XXL a 19.2€ all'indirizzo [45.318257, 9.186061]
# ["['Alessandro', 'Carrara', 'e', 'Sorelle']"] ha ordinato 368.0 magliette taglia M a 5.99€ all'indirizzo [46.536574, 8.333333]
# ["['Maurizio', 'Iacovelli', 'Grissini']"] ha ordinato 180.0 magliette taglia XL a 11.91€ all'indirizzo [46.200596, 11.877196]
# ["['Angelica', 'Sartor', 'Azienda', 'Agricola']"] ha ordinato 343.0 magliette taglia L a 18.99€ all'indirizzo [46.060128, 11.799358]
# ["['Davide', 'Bressan', 'Componentistiche']"] ha ordinato 359.0 magliette taglia S a 16.0€ all'indirizzo [44.455055, 7.827646]
# ["['Carlo', 'Augusto', 'Fedeli', 'Mascherine']"] ha ordinato 300.0 magliette taglia L a 13.58€ all'indirizzo [46.674732, 10.013196]
# ["['Angelica', 'Cerisola', 'SPA']"] ha ordinato 45.0 magliette taglia XL a 19.64€ all'indirizzo [46.610924, 9.703793]
# ["['Enrico', 'Baroni', 'INC.']"] ha ordinato 29.0 magliette taglia S a 19.19€ all'indirizzo [46.461167, 11.752772]
# ["['Angelica', 'Sgarbossa', 'Racing']"] ha ordinato 306.0 magliette taglia XXL a 6.76€ all'indirizzo [46.574787, 9.36507]
# ['[\'Valentina\', \'Bacchiocchi\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 199.0 magliette taglia S a 16.87€ all'indirizzo [45.658579, 8.425556]
# ["['Giulia', 'Mescolini', 'Azienda', 'Agricola']"] ha ordinato 146.0 magliette taglia M a 17.73€ all'indirizzo [45.621286, 6.720958]
# ["['Valentina', 'Baroni', 'INC.']"] ha ordinato 33.0 magliette taglia S a 10.05€ all'indirizzo [45.489984, 6.41303]
# ['[\'JP\', \'Cerisola\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 156.0 magliette taglia L a 19.86€ all'indirizzo [45.337628, 9.235005]
# ["['Carlo', 'Augusto', 'Vitellio', 'Giocattoli']"] ha ordinato 16.0 magliette taglia L a 11.03€ all'indirizzo [45.774366, 6.446387]
# ["['Mirko', 'Zacchei', 'Mascherine']"] ha ordinato 176.0 magliette taglia XS a 6.45€ all'indirizzo [46.488766, 8.225467]
# ["['Valentina', 'Sgarbossa', 'Ingranaggi']"] ha ordinato 216.0 magliette taglia M a 12.52€ all'indirizzo [44.861821, 11.378369]
# ["['Davide', 'Fedeli', 'SRL']"] ha ordinato 487.0 magliette taglia L a 6.86€ all'indirizzo [45.450606, 6.916576]
# ["['Francesco', 'Iacovelli', 'SRL']"] ha ordinato 140.0 magliette taglia L a 10.92€ all'indirizzo [45.009472, 7.289826]
# ["['Carlo', 'Augusto', 'Vitellio', 'Giocattoli']"] ha ordinato 255.0 magliette taglia L a 9.24€ all'indirizzo [45.36048, 10.810474]
# ["['Luca', 'Sartor', 'Grissini']"] ha ordinato 291.0 magliette taglia M a 16.47€ all'indirizzo [46.328157, 6.60567]
# ['[\'Davide\', \'Iacovelli\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 255.0 magliette taglia M a 7.98€ all'indirizzo [45.080873, 12.151732]
# ["['Valentina', 'Genalti', 'Grissini']"] ha ordinato 275.0 magliette taglia M a 16.88€ all'indirizzo [44.972102, 8.159992]
# ["['MC', 'Baroni', 'e', 'Sorelle']"] ha ordinato 129.0 magliette taglia XS a 15.04€ all'indirizzo [44.998576, 8.002632]
# ['[\'Carlo\', \'Augusto\', \'Carrara\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 175.0 magliette taglia L a 9.3€ all'indirizzo [44.475864, 8.738362]
# ["['Maurizio', 'Calcaterra', 'Frutta', 'e', 'Verdura']"] ha ordinato 435.0 magliette taglia XL a 7.85€ all'indirizzo [45.404632, 10.560763]
# ["['Gianmarco', 'Baroni', 'Ingranaggi']"] ha ordinato 243.0 magliette taglia XXL a 13.22€ all'indirizzo [46.664931, 7.453308]
# ["['Francesco', 'Fedeli', 'Frumento']"] ha ordinato 96.0 magliette taglia L a 17.44€ all'indirizzo [46.547132, 6.943494]
# ["['Carlo', 'Augusto', 'Sgarbossa', 'Franchising']"] ha ordinato 72.0 magliette taglia XXL a 13.5€ all'indirizzo [45.248003, 9.682098]
# ["['Angelica', 'Zacchei', 'Tentazioni']"] ha ordinato 7.0 magliette taglia XXL a 15.96€ all'indirizzo [45.845516, 7.56794]
# ["['Alessandro', 'Bressan', 'Componentistiche']"] ha ordinato 346.0 magliette taglia M a 12.43€ all'indirizzo [45.018948, 6.682144]
# ["['Luca', 'Bacchiocchi', 'e', 'Fratelli']"] ha ordinato 338.0 magliette taglia XS a 7.3€ all'indirizzo [45.578003, 8.200128]
# ["['Davide', 'Moneta', 'Servizi', 'Finanziari']"] ha ordinato 125.0 magliette taglia XXL a 12.17€ all'indirizzo [45.167235, 7.591165]
# ["['Manuel', 'Zacchei', 'Frutta', 'e', 'Verdura']"] ha ordinato 140.0 magliette taglia XXL a 8.01€ all'indirizzo [44.542376, 9.368889]
# ['[\'Francesco\', \'Carrara\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 465.0 magliette taglia L a 12.67€ all'indirizzo [46.507253, 8.291301]
# ["['Carlo', 'Augusto', 'Fedeli', 'INC.']"] ha ordinato 270.0 magliette taglia S a 11.18€ all'indirizzo [45.326567, 7.738032]
# ["['Angelica', 'Carrara', 'Franchising']"] ha ordinato 150.0 magliette taglia XXL a 9.25€ all'indirizzo [46.05271, 10.398746]
# ['[\'Manuel\', \'Sartor\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 26.0 magliette taglia M a 10.98€ all'indirizzo [45.424542, 7.152396]
# ["['Mirko', 'Genalti', 'Trasporti']"] ha ordinato 125.0 magliette taglia XS a 11.57€ all'indirizzo [44.666498, 9.392403]
# ["['Angelica', 'Calcaterra', 'Automotive']"] ha ordinato 157.0 magliette taglia XL a 12.52€ all'indirizzo [44.632037, 9.130843]
# ["['Valentina', 'Bacchiocchi', 'Strumenti', 'Musicali']"] ha ordinato 331.0 magliette taglia M a 15.25€ all'indirizzo [46.039545, 7.863041]
# ["['Mirko', 'Bressan', 'Ingranaggi']"] ha ordinato 196.0 magliette taglia XS a 9.88€ all'indirizzo [45.233756, 8.880092]
# ["['Valentina', 'Mescolini', 'Frumento']"] ha ordinato 252.0 magliette taglia S a 13.34€ all'indirizzo [46.295324, 8.771488]
# ["['Mirko', 'Vitellio', 'Tentazioni']"] ha ordinato 187.0 magliette taglia XS a 8.32€ all'indirizzo [45.509886, 6.496841]
# ["['Davide', 'Fedeli', 'SRL']"] ha ordinato 339.0 magliette taglia S a 11.02€ all'indirizzo [45.695081, 7.024014]
# ["['Carlo', 'Augusto', 'Baroni', 'e', 'Fratelli']"] ha ordinato 436.0 magliette taglia L a 15.63€ all'indirizzo [45.751854, 6.517282]
# ["['Giulia', 'Zacchei', 'Trasporti']"] ha ordinato 6.0 magliette taglia XL a 15.35€ all'indirizzo [44.917987, 8.393744]
# ["['Valentina', 'Genalti', 'Racing']"] ha ordinato 383.0 magliette taglia XS a 19.14€ all'indirizzo [46.393485, 11.191038]
# ["['Angelica', 'Carrara', 'Formaggi']"] ha ordinato 472.0 magliette taglia XS a 10.65€ all'indirizzo [44.875213, 10.530282]
# ["['Davide', 'Bacchiocchi', 'Frumento']"] ha ordinato 235.0 magliette taglia M a 5.19€ all'indirizzo [44.499277, 11.925849]
# ['[\'Maurizio\', \'Moneta\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 304.0 magliette taglia S a 11.1€ all'indirizzo [44.524767, 8.209124]
# ["['JP', 'Cerisola', 'Servizi', 'Finanziari']"] ha ordinato 430.0 magliette taglia S a 14.71€ all'indirizzo [46.320969, 10.122712]
# ["['Luca', 'Carrara', 'Racing']"] ha ordinato 11.0 magliette taglia XXL a 10.16€ all'indirizzo [46.082696, 6.57702]
# ["['MC', 'Moneta', 'e', 'Sorelle']"] ha ordinato 121.0 magliette taglia XL a 19.16€ all'indirizzo [44.408946, 11.713756]
# ["['Manuel', 'Carrara', 'Franchising']"] ha ordinato 492.0 magliette taglia XS a 19.85€ all'indirizzo [44.811402, 11.070849]
# ["['JP', 'Vitellio', 'Ingranaggi']"] ha ordinato 395.0 magliette taglia M a 17.68€ all'indirizzo [45.443587, 11.121478]
# ["['Enrico', 'Mescolini', 'Servizi', 'Finanziari']"] ha ordinato 387.0 magliette taglia XL a 17.58€ all'indirizzo [46.488038, 9.932118]
# ["['Giulia', 'Carrara', 'Giocattoli']"] ha ordinato 257.0 magliette taglia L a 7.53€ all'indirizzo [44.546207, 7.473757]
# ["['Luca', 'Genalti', 'Mascherine']"] ha ordinato 173.0 magliette taglia XL a 18.31€ all'indirizzo [45.131002, 10.353471]
# ["['Filippo', 'Moneta', 'INC.']"] ha ordinato 86.0 magliette taglia XL a 16.45€ all'indirizzo [45.652833, 9.288692]
# ["['Filippo', 'Carrara', 'Franchising']"] ha ordinato 259.0 magliette taglia XXL a 6.88€ all'indirizzo [44.68621, 10.290011]
# ["['Giulia', 'Bressan', 'e', 'Sorelle']"] ha ordinato 466.0 magliette taglia XS a 14.51€ all'indirizzo [46.237336, 8.53143]
# ["['Maurizio', 'Calcaterra', 'Company']"] ha ordinato 341.0 magliette taglia L a 6.79€ all'indirizzo [45.244452, 8.328244]
# ["['Valentina', 'Zacchei', 'Formaggi']"] ha ordinato 174.0 magliette taglia L a 16.17€ all'indirizzo [44.856611, 11.140003]
# ["['Francesco', 'Sgarbossa', 'e', 'Fratelli']"] ha ordinato 176.0 magliette taglia XL a 15.39€ all'indirizzo [45.460174, 10.501418]
# ["['Maurizio', 'Fedeli', 'Formaggi']"] ha ordinato 197.0 magliette taglia XL a 19.45€ all'indirizzo [46.435533, 8.212229]
# ["['Francesco', 'Calcaterra', 'Franchising']"] ha ordinato 237.0 magliette taglia M a 12.19€ all'indirizzo [44.733457, 11.867654]
# ["['Giulia', 'Moneta', 'Frutta', 'e', 'Verdura']"] ha ordinato 191.0 magliette taglia XXL a 15.08€ all'indirizzo [44.972737, 11.149641]
# ["['Manuel', 'Sosta', 'Servizi', 'Finanziari']"] ha ordinato 72.0 magliette taglia L a 7.9€ all'indirizzo [46.266475, 11.47221]
# ["['Filippo', 'Baroni', 'Trasporti']"] ha ordinato 194.0 magliette taglia XS a 10.48€ all'indirizzo [46.50558, 9.349746]
# ["['Carlo', 'Augusto', 'Mescolini', 'Company']"] ha ordinato 297.0 magliette taglia L a 17.24€ all'indirizzo [46.017351, 7.527521]
# ["['Giulia', 'Mescolini', 'Frutta', 'e', 'Verdura']"] ha ordinato 81.0 magliette taglia M a 7.18€ all'indirizzo [44.715191, 6.571921]
# ["['Alessandro', 'Moneta', 'Frumento']"] ha ordinato 81.0 magliette taglia XS a 7.84€ all'indirizzo [45.965173, 11.865412]
# ["['Giulia', 'Baroni', 'Company']"] ha ordinato 299.0 magliette taglia M a 7.63€ all'indirizzo [45.298182, 6.608378]
# ["['Giulia', 'Mescolini', 'INC.']"] ha ordinato 99.0 magliette taglia S a 15.7€ all'indirizzo [44.380584, 8.54086]
# ["['Angelica', 'Moneta', 'e', 'Sorelle']"] ha ordinato 399.0 magliette taglia M a 19.42€ all'indirizzo [45.265113, 11.041044]
# ["['Mirko', 'Iacovelli', 'e', 'Sorelle']"] ha ordinato 89.0 magliette taglia S a 18.99€ all'indirizzo [44.94402, 9.421879]
# ["['MC', 'Baroni', 'IB']"] ha ordinato 243.0 magliette taglia L a 9.4€ all'indirizzo [45.479364, 7.406341]
# ["['MC', 'Bacchiocchi', 'Trasporti']"] ha ordinato 190.0 magliette taglia XL a 17.36€ all'indirizzo [44.616765, 9.082761]
# ["['MC', 'Zacchei', 'Latte']"] ha ordinato 351.0 magliette taglia XS a 19.88€ all'indirizzo [45.498935, 8.319235]
# ['[\'Mirko\', \'Baroni\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 150.0 magliette taglia XXL a 8.1€ all'indirizzo [45.959108, 11.573275]
# ["['JP', 'Iacovelli', 'Co.']"] ha ordinato 410.0 magliette taglia XXL a 8.81€ all'indirizzo [45.523926, 7.930447]
# ["['Alessandro', 'Zacchei', 'Giocattoli']"] ha ordinato 10.0 magliette taglia XS a 6.93€ all'indirizzo [45.071378, 8.191105]
# ["['Luca', 'Mescolini', 'Strumenti', 'Musicali']"] ha ordinato 410.0 magliette taglia XS a 17.54€ all'indirizzo [46.337571, 6.477615]
# ["['Gianmarco', 'Sosta', 'SPA']"] ha ordinato 150.0 magliette taglia L a 9.37€ all'indirizzo [46.034015, 11.995773]
# ["['Valentina', 'Sosta', 'Frutta', 'e', 'Verdura']"] ha ordinato 144.0 magliette taglia S a 14.63€ all'indirizzo [45.426824, 10.319778]
# ["['Angelica', 'Sartor', 'IB']"] ha ordinato 464.0 magliette taglia XXL a 17.69€ all'indirizzo [44.921135, 11.10902]
# ["['Luca', 'Genalti', 'Formaggi']"] ha ordinato 322.0 magliette taglia XS a 6.31€ all'indirizzo [45.580304, 11.208366]
# ["['MC', 'Carrara', 'Ingranaggi']"] ha ordinato 286.0 magliette taglia M a 11.8€ all'indirizzo [46.228417, 9.538016]
# ["['Mirko', 'Zacchei', 'Trasporti']"] ha ordinato 210.0 magliette taglia S a 10.81€ all'indirizzo [46.311531, 7.218673]
# ["['Valentina', 'Bressan', 'Co.']"] ha ordinato 411.0 magliette taglia XL a 5.38€ all'indirizzo [44.67431, 8.070857]
# ["['Mirko', 'Mescolini', 'Automotive']"] ha ordinato 51.0 magliette taglia M a 8.76€ all'indirizzo [45.909891, 11.304663]
# ["['Enrico', 'Bressan', 'e', 'Fratelli']"] ha ordinato 318.0 magliette taglia XXL a 17.97€ all'indirizzo [45.434194, 8.030439]
# ["['JP', 'Fedeli', 'Co.']"] ha ordinato 35.0 magliette taglia M a 14.68€ all'indirizzo [45.818552, 10.604108]
# ["['Manuel', 'Calcaterra', 'Automotive']"] ha ordinato 43.0 magliette taglia XXL a 6.37€ all'indirizzo [45.383853, 11.645055]
# ["['Francesco', 'Baroni', 'INC.']"] ha ordinato 52.0 magliette taglia XS a 10.57€ all'indirizzo [45.101491, 9.361921]
# ["['MC', 'Carrara', 'Trasporti']"] ha ordinato 235.0 magliette taglia XL a 9.9€ all'indirizzo [46.316984, 7.2826]
# ["['Enrico', 'Sartor', 'Strumenti', 'Musicali']"] ha ordinato 289.0 magliette taglia L a 14.19€ all'indirizzo [45.895956, 6.644199]
# ["['Alessandro', 'Sartor', 'Co.']"] ha ordinato 53.0 magliette taglia XXL a 7.9€ all'indirizzo [45.193414, 10.601173]
# ["['Manuel', 'Bressan', 'Grissini']"] ha ordinato 351.0 magliette taglia M a 8.46€ all'indirizzo [46.393007, 10.853974]
# ["['Davide', 'Sosta', 'Frumento']"] ha ordinato 333.0 magliette taglia XL a 11.81€ all'indirizzo [44.534782, 9.489222]
# ["['Mirko', 'Bacchiocchi', 'Company']"] ha ordinato 307.0 magliette taglia XS a 15.83€ all'indirizzo [46.323737, 10.584971]
# ["['Angelica', 'Iacovelli', 'e', 'Sorelle']"] ha ordinato 108.0 magliette taglia XXL a 12.23€ all'indirizzo [45.325776, 8.33967]
# ["['Gianmarco', 'Sgarbossa', 'Trasporti']"] ha ordinato 494.0 magliette taglia XL a 5.54€ all'indirizzo [44.773254, 7.165038]
# ["['Enrico', 'Sgarbossa', 'Giocattoli']"] ha ordinato 14.0 magliette taglia XL a 15.63€ all'indirizzo [45.065032, 6.556252]
# ["['Maurizio', 'Baroni', 'INC.']"] ha ordinato 467.0 magliette taglia XS a 15.28€ all'indirizzo [44.989011, 11.117416]
# ["['JP', 'Iacovelli', 'Azienda', 'Agricola']"] ha ordinato 497.0 magliette taglia S a 17.92€ all'indirizzo [45.058065, 6.422715]
# ["['Luca', 'Baroni', 'Frumento']"] ha ordinato 383.0 magliette taglia XL a 6.5€ all'indirizzo [45.935365, 9.925589]
# ["['Davide', 'Zacchei', 'Racing']"] ha ordinato 19.0 magliette taglia M a 7.92€ all'indirizzo [45.054392, 8.653437]
# ["['Alessandro', 'Genalti', 'Latte']"] ha ordinato 230.0 magliette taglia XXL a 16.29€ all'indirizzo [45.190932, 10.15473]
# ['[\'Angelica\', \'Vitellio\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 149.0 magliette taglia M a 10.89€ all'indirizzo [45.383702, 8.412917]
# ["['Maurizio', 'Vitellio', 'Franchising']"] ha ordinato 310.0 magliette taglia M a 6.78€ all'indirizzo [45.312632, 9.100723]
# ["['Gianmarco', 'Calcaterra', 'Tentazioni']"] ha ordinato 436.0 magliette taglia S a 12.86€ all'indirizzo [45.554086, 8.853124]
# ['[\'Valentina\', \'Carrara\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 386.0 magliette taglia M a 15.05€ all'indirizzo [46.640755, 7.389144]
# ["['Valentina', 'Vitellio', 'Tentazioni']"] ha ordinato 439.0 magliette taglia XL a 19.22€ all'indirizzo [44.723003, 11.118845]
# ["['Alessandro', 'Bressan', 'Formaggi']"] ha ordinato 460.0 magliette taglia XS a 6.75€ all'indirizzo [45.995927, 10.516504]
# ["['Gianmarco', 'Bressan', 'INC.']"] ha ordinato 186.0 magliette taglia L a 7.68€ all'indirizzo [45.509329, 7.227809]
# ["['Carlo', 'Augusto', 'Carrara', 'Grissini']"] ha ordinato 478.0 magliette taglia S a 14.22€ all'indirizzo [45.482738, 12.006968]
# ["['Gianmarco', 'Bressan', 'Company']"] ha ordinato 491.0 magliette taglia XS a 19.79€ all'indirizzo [45.661732, 10.428504]
# ["['Davide', 'Sosta', 'Mascherine']"] ha ordinato 14.0 magliette taglia M a 15.77€ all'indirizzo [45.597936, 6.672514]
# ["['Valentina', 'Fedeli', 'Racing']"] ha ordinato 266.0 magliette taglia M a 18.96€ all'indirizzo [45.395681, 8.384508]
# ["['Enrico', 'Calcaterra', 'Componentistiche']"] ha ordinato 16.0 magliette taglia XL a 14.51€ all'indirizzo [46.594147, 7.243441]
# ["['Valentina', 'Sgarbossa', 'Company']"] ha ordinato 431.0 magliette taglia L a 10.52€ all'indirizzo [46.226469, 7.605922]
# ["['Davide', 'Baroni', 'Frumento']"] ha ordinato 431.0 magliette taglia S a 19.62€ all'indirizzo [45.755771, 8.645121]
# ["['Luca', 'Bacchiocchi', 'Servizi', 'Finanziari']"] ha ordinato 94.0 magliette taglia S a 16.13€ all'indirizzo [44.598262, 7.289589]
# ["['Davide', 'Moneta', 'Latte']"] ha ordinato 368.0 magliette taglia XL a 6.74€ all'indirizzo [44.669888, 8.000619]
# ["['Enrico', 'Sosta', 'Servizi', 'Finanziari']"] ha ordinato 435.0 magliette taglia M a 5.76€ all'indirizzo [45.084592, 11.03828]
# ["['MC', 'Carrara', 'e', 'Fratelli']"] ha ordinato 58.0 magliette taglia XS a 17.66€ all'indirizzo [45.689201, 9.891178]
# ["['Francesco', 'Moneta', 'Ingranaggi']"] ha ordinato 35.0 magliette taglia XL a 15.45€ all'indirizzo [45.069355, 8.376941]
# ["['Filippo', 'Iacovelli', 'e', 'Sorelle']"] ha ordinato 336.0 magliette taglia M a 10.15€ all'indirizzo [45.149886, 11.354569]
# ["['Angelica', 'Calcaterra', 'IB']"] ha ordinato 251.0 magliette taglia XS a 15.27€ all'indirizzo [44.395547, 8.236262]
# ["['Francesco', 'Sartor', 'Company']"] ha ordinato 379.0 magliette taglia S a 8.56€ all'indirizzo [46.070072, 8.943784]
# ["['Gianmarco', 'Baroni', 'e', 'Fratelli']"] ha ordinato 278.0 magliette taglia L a 12.6€ all'indirizzo [46.573963, 7.443191]
# ["['Francesco', 'Iacovelli', 'Frutta', 'e', 'Verdura']"] ha ordinato 100.0 magliette taglia S a 14.39€ all'indirizzo [44.569882, 12.043969]
# ["['Davide', 'Baroni', 'IB']"] ha ordinato 137.0 magliette taglia S a 15.36€ all'indirizzo [45.603979, 9.332943]
# ["['Alessandro', 'Sgarbossa', 'Automotive']"] ha ordinato 181.0 magliette taglia L a 6.56€ all'indirizzo [44.575824, 11.195886]
# ["['JP', 'Calcaterra', 'Frumento']"] ha ordinato 142.0 magliette taglia S a 15.32€ all'indirizzo [45.987218, 8.92958]
# ["['Filippo', 'Carrara', 'Racing']"] ha ordinato 187.0 magliette taglia XXL a 17.7€ all'indirizzo [45.946048, 11.894065]
# ["['Enrico', 'Sgarbossa', 'Ingranaggi']"] ha ordinato 337.0 magliette taglia XL a 7.23€ all'indirizzo [44.403991, 7.701918]
# ["['Alessandro', 'Bressan', 'IB']"] ha ordinato 242.0 magliette taglia XS a 19.99€ all'indirizzo [45.152525, 8.134165]
# ["['Luca', 'Bacchiocchi', 'Formaggi']"] ha ordinato 320.0 magliette taglia XS a 10.32€ all'indirizzo [45.950367, 8.493355]
# ["['Davide', 'Baroni', 'INC.']"] ha ordinato 428.0 magliette taglia XS a 6.15€ all'indirizzo [44.563738, 11.021192]
# ["['Mirko', 'Sgarbossa', 'Frutta', 'e', 'Verdura']"] ha ordinato 9.0 magliette taglia M a 17.03€ all'indirizzo [45.576819, 9.796091]
# ["['Francesco', 'Cerisola', 'INC.']"] ha ordinato 412.0 magliette taglia XS a 10.99€ all'indirizzo [45.691742, 10.051885]
# ['[\'Manuel\', \'Sosta\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 155.0 magliette taglia XS a 11.23€ all'indirizzo [46.033333, 10.237615]
# ['[\'Manuel\', \'Zacchei\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 236.0 magliette taglia L a 17.51€ all'indirizzo [44.931719, 10.901902]
# ["['Enrico', 'Cerisola', 'Frumento']"] ha ordinato 283.0 magliette taglia L a 9.33€ all'indirizzo [45.783726, 6.569141]
# ["['JP', 'Bacchiocchi', 'Frutta', 'e', 'Verdura']"] ha ordinato 393.0 magliette taglia S a 10.6€ all'indirizzo [46.272922, 10.53863]
# ["['Maurizio', 'Vitellio', 'Strumenti', 'Musicali']"] ha ordinato 246.0 magliette taglia XL a 10.23€ all'indirizzo [46.629578, 11.54044]
# ["['Angelica', 'Bressan', 'e', 'Fratelli']"] ha ordinato 277.0 magliette taglia XS a 11.87€ all'indirizzo [44.51498, 9.57488]
# ["['Maurizio', 'Fedeli', 'Giocattoli']"] ha ordinato 351.0 magliette taglia XS a 15.25€ all'indirizzo [45.194455, 7.483713]
# ["['Manuel', 'Bacchiocchi', 'Formaggi']"] ha ordinato 280.0 magliette taglia XL a 5.35€ all'indirizzo [45.906227, 9.680257]
# ["['Alessandro', 'Baroni', 'Franchising']"] ha ordinato 377.0 magliette taglia S a 6.01€ all'indirizzo [45.989839, 11.972613]
# ["['MC', 'Vitellio', 'Mascherine']"] ha ordinato 70.0 magliette taglia L a 11.77€ all'indirizzo [44.782554, 8.911041]
# ["['MC', 'Sgarbossa', 'e', 'Sorelle']"] ha ordinato 455.0 magliette taglia M a 8.04€ all'indirizzo [46.109764, 8.626903]
# ["['Luca', 'Fedeli', 'Mascherine']"] ha ordinato 368.0 magliette taglia XXL a 5.13€ all'indirizzo [45.705954, 9.841363]
# ["['Mirko', 'Sosta', 'Componentistiche']"] ha ordinato 64.0 magliette taglia S a 12.97€ all'indirizzo [45.44997, 12.043682]
# ["['Alessandro', 'Vitellio', 'Automotive']"] ha ordinato 426.0 magliette taglia XS a 17.82€ all'indirizzo [46.601355, 10.070089]
# ["['Francesco', 'Sosta', 'IB']"] ha ordinato 494.0 magliette taglia L a 15.6€ all'indirizzo [44.958786, 10.107809]
# ["['Davide', 'Moneta', 'Trasporti']"] ha ordinato 393.0 magliette taglia S a 7.13€ all'indirizzo [46.074384, 9.567616]
# ["['Angelica', 'Bressan', 'Strumenti', 'Musicali']"] ha ordinato 428.0 magliette taglia XL a 18.18€ all'indirizzo [46.203289, 9.683224]
# ["['Gianmarco', 'Baroni', 'Azienda', 'Agricola']"] ha ordinato 229.0 magliette taglia S a 14.65€ all'indirizzo [46.002357, 10.304807]
# ["['Filippo', 'Carrara', 'Frutta', 'e', 'Verdura']"] ha ordinato 35.0 magliette taglia XS a 5.06€ all'indirizzo [45.774384, 8.077039]
# ["['Carlo', 'Augusto', 'Bacchiocchi', 'Frutta', 'e', 'Verdura']"] ha ordinato 57.0 magliette taglia S a 14.44€ all'indirizzo [45.723848, 10.827164]
# ["['MC', 'Carrara', 'Strumenti', 'Musicali']"] ha ordinato 256.0 magliette taglia XXL a 12.17€ all'indirizzo [44.721813, 10.836338]
# ["['Alessandro', 'Vitellio', 'Trasporti']"] ha ordinato 438.0 magliette taglia XXL a 8.77€ all'indirizzo [46.101869, 8.912694]
# ["['Francesco', 'Mescolini', 'e', 'Fratelli']"] ha ordinato 402.0 magliette taglia S a 13.06€ all'indirizzo [44.829503, 11.93368]
# ["['Davide', 'Zacchei', 'SPA']"] ha ordinato 477.0 magliette taglia XS a 17.66€ all'indirizzo [44.478028, 7.044747]
# ["['Alessandro', 'Sartor', 'IB']"] ha ordinato 194.0 magliette taglia S a 13.22€ all'indirizzo [45.777217, 11.317981]
# ["['Filippo', 'Bacchiocchi', 'Frutta', 'e', 'Verdura']"] ha ordinato 133.0 magliette taglia M a 12.76€ all'indirizzo [44.543346, 7.798911]
# ["['Gianmarco', 'Moneta', 'Grissini']"] ha ordinato 368.0 magliette taglia XS a 13.62€ all'indirizzo [44.532206, 11.41108]
# ["['JP', 'Bressan', 'e', 'Sorelle']"] ha ordinato 401.0 magliette taglia XS a 11.15€ all'indirizzo [46.341109, 9.61142]
# ["['Alessandro', 'Sosta', 'INC.']"] ha ordinato 434.0 magliette taglia XL a 11.89€ all'indirizzo [45.925558, 9.727535]
# ["['Francesco', 'Fedeli', 'Azienda', 'Agricola']"] ha ordinato 313.0 magliette taglia L a 11.98€ all'indirizzo [45.886014, 9.102999]
# ["['Giulia', 'Bacchiocchi', 'Strumenti', 'Musicali']"] ha ordinato 4.0 magliette taglia XS a 6.95€ all'indirizzo [45.180774, 10.852879]
# ["['Alessandro', 'Cerisola', 'Grissini']"] ha ordinato 268.0 magliette taglia M a 7.73€ all'indirizzo [45.095231, 7.757387]
# ["['Angelica', 'Cerisola', 'INC.']"] ha ordinato 255.0 magliette taglia XL a 10.49€ all'indirizzo [44.832383, 9.808927]
# ["['Filippo', 'Vitellio', 'Automotive']"] ha ordinato 72.0 magliette taglia XXL a 18.52€ all'indirizzo [44.753242, 9.615282]
# ['[\'Enrico\', \'Carrara\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 17.0 magliette taglia XL a 12.09€ all'indirizzo [45.575321, 7.48117]
# ["['Manuel', 'Baroni', 'Azienda', 'Agricola']"] ha ordinato 432.0 magliette taglia L a 13.07€ all'indirizzo [44.579999, 10.942335]
# ["['Carlo', 'Augusto', 'Genalti', 'Tentazioni']"] ha ordinato 72.0 magliette taglia XXL a 16.77€ all'indirizzo [46.138661, 10.232275]
# ["['JP', 'Iacovelli', 'Latte']"] ha ordinato 119.0 magliette taglia XL a 10.23€ all'indirizzo [44.675557, 7.542077]
# ["['Filippo', 'Mescolini', 'Ingranaggi']"] ha ordinato 253.0 magliette taglia L a 12.34€ all'indirizzo [45.805734, 9.732641]
# ["['Angelica', 'Zacchei', 'Componentistiche']"] ha ordinato 153.0 magliette taglia XS a 19.85€ all'indirizzo [45.662599, 11.126587]
# ["['Luca', 'Calcaterra', 'Tentazioni']"] ha ordinato 155.0 magliette taglia XL a 16.66€ all'indirizzo [44.542568, 9.210092]
# ["['Gianmarco', 'Mescolini', 'Azienda', 'Agricola']"] ha ordinato 272.0 magliette taglia XXL a 15.33€ all'indirizzo [44.374026, 10.760497]
# ["['Gianmarco', 'Iacovelli', 'INC.']"] ha ordinato 93.0 magliette taglia XXL a 8.91€ all'indirizzo [44.698388, 12.154865]
# ["['Gianmarco', 'Fedeli', 'Grissini']"] ha ordinato 441.0 magliette taglia M a 16.77€ all'indirizzo [45.196751, 9.768684]
# ["['Valentina', 'Iacovelli', 'Giocattoli']"] ha ordinato 29.0 magliette taglia S a 10.19€ all'indirizzo [45.30762, 7.266381]
# ["['Valentina', 'Bressan', 'SPA']"] ha ordinato 344.0 magliette taglia XL a 9.09€ all'indirizzo [45.878834, 9.398438]
# ["['Giulia', 'Zacchei', 'Strumenti', 'Musicali']"] ha ordinato 458.0 magliette taglia L a 17.42€ all'indirizzo [44.386767, 6.492457]
# ["['Valentina', 'Calcaterra', 'e', 'Fratelli']"] ha ordinato 476.0 magliette taglia L a 8.8€ all'indirizzo [46.671188, 6.5815]
# ["['Mirko', 'Carrara', 'Ingranaggi']"] ha ordinato 66.0 magliette taglia M a 13.98€ all'indirizzo [44.567106, 6.70212]
# ["['Filippo', 'Bacchiocchi', 'Automotive']"] ha ordinato 479.0 magliette taglia XL a 7.47€ all'indirizzo [45.186817, 8.815703]
# ["['Giulia', 'Genalti', 'Company']"] ha ordinato 216.0 magliette taglia XL a 19.36€ all'indirizzo [45.322668, 10.433776]
# ["['Francesco', 'Mescolini', 'Frutta', 'e', 'Verdura']"] ha ordinato 353.0 magliette taglia S a 16.05€ all'indirizzo [44.818701, 11.166107]
# ["['Mirko', 'Genalti', 'Trasporti']"] ha ordinato 366.0 magliette taglia XS a 6.37€ all'indirizzo [46.477647, 9.589753]
# ["['Alessandro', 'Carrara', 'e', 'Sorelle']"] ha ordinato 53.0 magliette taglia XL a 5.71€ all'indirizzo [45.228974, 8.109557]
# ["['Giulia', 'Baroni', 'Frutta', 'e', 'Verdura']"] ha ordinato 39.0 magliette taglia XL a 19.31€ all'indirizzo [46.194269, 10.256644]
# ["['Gianmarco', 'Genalti', 'Ingranaggi']"] ha ordinato 172.0 magliette taglia XS a 16.55€ all'indirizzo [45.07399, 7.530061]
# ["['Davide', 'Fedeli', 'Giocattoli']"] ha ordinato 348.0 magliette taglia M a 10.44€ all'indirizzo [45.742284, 8.065]
# ["['Giulia', 'Calcaterra', 'Strumenti', 'Musicali']"] ha ordinato 472.0 magliette taglia S a 14.46€ all'indirizzo [46.027222, 11.996612]
# ["['Davide', 'Bressan', 'Franchising']"] ha ordinato 200.0 magliette taglia XS a 9.75€ all'indirizzo [45.821931, 11.266702]
# ["['Maurizio', 'Sgarbossa', 'Componentistiche']"] ha ordinato 317.0 magliette taglia L a 17.72€ all'indirizzo [45.367204, 8.151017]
# ["['Alessandro', 'Calcaterra', 'Azienda', 'Agricola']"] ha ordinato 420.0 magliette taglia M a 6.65€ all'indirizzo [44.769548, 9.969949]
# ["['Francesco', 'Zacchei', 'IB']"] ha ordinato 410.0 magliette taglia S a 15.52€ all'indirizzo [45.557211, 10.383967]
# ["['Manuel', 'Sosta', 'Co.']"] ha ordinato 3.0 magliette taglia XXL a 9.31€ all'indirizzo [44.462187, 11.272]
# ['[\'Filippo\', \'Carrara\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 342.0 magliette taglia L a 19.18€ all'indirizzo [46.220461, 8.598891]
# ["['Davide', 'Carrara', 'SPA']"] ha ordinato 477.0 magliette taglia L a 12.37€ all'indirizzo [44.510192, 10.902153]
# ["['Giulia', 'Fedeli', 'SRL']"] ha ordinato 335.0 magliette taglia L a 15.03€ all'indirizzo [44.850889, 11.277868]
# ["['Alessandro', 'Cerisola', 'e', 'Fratelli']"] ha ordinato 366.0 magliette taglia XS a 17.52€ all'indirizzo [46.487746, 9.708342]
# ["['Francesco', 'Cerisola', 'Automotive']"] ha ordinato 272.0 magliette taglia XXL a 7.19€ all'indirizzo [45.999781, 8.600397]
# ["['Luca', 'Bressan', 'Giocattoli']"] ha ordinato 122.0 magliette taglia XXL a 6.03€ all'indirizzo [44.695869, 12.167779]
# ["['Alessandro', 'Zacchei', 'Co.']"] ha ordinato 163.0 magliette taglia XS a 6.72€ all'indirizzo [45.619768, 10.248465]
# ["['Mirko', 'Mescolini', 'SRL']"] ha ordinato 75.0 magliette taglia XXL a 15.03€ all'indirizzo [46.176933, 7.823514]
# ["['Valentina', 'Bressan', 'Tentazioni']"] ha ordinato 406.0 magliette taglia L a 7.75€ all'indirizzo [46.267837, 6.603645]
# ["['Angelica', 'Sartor', 'Company']"] ha ordinato 78.0 magliette taglia M a 10.88€ all'indirizzo [46.660496, 6.786411]
# ["['Gianmarco', 'Cerisola', 'SPA']"] ha ordinato 319.0 magliette taglia M a 19.59€ all'indirizzo [44.918354, 11.037787]
# ["['Filippo', 'Carrara', 'e', 'Sorelle']"] ha ordinato 2.0 magliette taglia M a 15.95€ all'indirizzo [46.455183, 7.59298]
# ["['Alessandro', 'Bacchiocchi', 'Frumento']"] ha ordinato 370.0 magliette taglia S a 10.28€ all'indirizzo [45.804258, 11.762693]
# ["['Mirko', 'Iacovelli', 'Componentistiche']"] ha ordinato 134.0 magliette taglia XS a 13.06€ all'indirizzo [44.453343, 11.226283]
# ["['Francesco', 'Vitellio', 'Co.']"] ha ordinato 249.0 magliette taglia M a 5.91€ all'indirizzo [44.941289, 9.579991]
# ["['Giulia', 'Moneta', 'Frumento']"] ha ordinato 5.0 magliette taglia S a 13.9€ all'indirizzo [45.330281, 11.833231]
# ["['Luca', 'Bressan', 'Componentistiche']"] ha ordinato 403.0 magliette taglia XXL a 5.09€ all'indirizzo [45.341606, 11.574881]
# ["['JP', 'Sgarbossa', 'Franchising']"] ha ordinato 489.0 magliette taglia XXL a 9.37€ all'indirizzo [46.272846, 10.028032]
# ["['JP', 'Zacchei', 'Servizi', 'Finanziari']"] ha ordinato 331.0 magliette taglia M a 13.29€ all'indirizzo [46.414979, 6.631506]
# ["['Giulia', 'Fedeli', 'Grissini']"] ha ordinato 230.0 magliette taglia XL a 19.16€ all'indirizzo [46.365271, 9.160471]
# ["['Gianmarco', 'Calcaterra', 'IB']"] ha ordinato 350.0 magliette taglia S a 13.94€ all'indirizzo [46.205747, 9.805424]
# ["['Maurizio', 'Cerisola', 'Franchising']"] ha ordinato 465.0 magliette taglia XL a 5.2€ all'indirizzo [44.584452, 8.957538]
# ["['Luca', 'Sgarbossa', 'e', 'Sorelle']"] ha ordinato 316.0 magliette taglia L a 6.15€ all'indirizzo [45.482981, 7.786416]
# ["['Gianmarco', 'Zacchei', 'Frutta', 'e', 'Verdura']"] ha ordinato 389.0 magliette taglia M a 16.14€ all'indirizzo [44.886641, 7.151952]
# ["['Filippo', 'Cerisola', 'Franchising']"] ha ordinato 317.0 magliette taglia L a 15.76€ all'indirizzo [46.353249, 9.794377]
# ["['Davide', 'Moneta', 'Company']"] ha ordinato 50.0 magliette taglia M a 6.12€ all'indirizzo [46.561587, 9.064422]
# ["['Francesco', 'Cerisola', 'Giocattoli']"] ha ordinato 224.0 magliette taglia XS a 18.24€ all'indirizzo [44.425749, 8.801334]
# ["['Luca', 'Carrara', 'Ingranaggi']"] ha ordinato 327.0 magliette taglia XL a 7.3€ all'indirizzo [45.31219, 7.671683]
# ["['Carlo', 'Augusto', 'Baroni', 'Latte']"] ha ordinato 431.0 magliette taglia S a 8.96€ all'indirizzo [46.638548, 10.114807]
# ["['Luca', 'Bacchiocchi', 'e', 'Sorelle']"] ha ordinato 114.0 magliette taglia S a 6.14€ all'indirizzo [45.330933, 9.733152]
# ['[\'Alessandro\', \'Bacchiocchi\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 125.0 magliette taglia S a 10.99€ all'indirizzo [45.790945, 9.437917]
# ["['Carlo', 'Augusto', 'Sosta', 'Mascherine']"] ha ordinato 74.0 magliette taglia XXL a 15.89€ all'indirizzo [45.481015, 9.410362]
# ["['Giulia', 'Carrara', 'Giocattoli']"] ha ordinato 487.0 magliette taglia L a 12.46€ all'indirizzo [46.566276, 6.786079]
# ["['Mirko', 'Moneta', 'Azienda', 'Agricola']"] ha ordinato 490.0 magliette taglia L a 11.46€ all'indirizzo [46.521621, 10.474226]
# ["['Gianmarco', 'Vitellio', 'e', 'Fratelli']"] ha ordinato 280.0 magliette taglia XS a 16.99€ all'indirizzo [46.215419, 11.450555]
# ["['Luca', 'Sgarbossa', 'Strumenti', 'Musicali']"] ha ordinato 396.0 magliette taglia M a 12.56€ all'indirizzo [44.479378, 11.26807]
# ["['JP', 'Sgarbossa', 'Franchising']"] ha ordinato 237.0 magliette taglia S a 7.74€ all'indirizzo [45.963189, 12.155281]
# ["['JP', 'Vitellio', 'INC.']"] ha ordinato 231.0 magliette taglia M a 11.82€ all'indirizzo [45.0728, 9.995119]
# ["['Francesco', 'Bressan', 'INC.']"] ha ordinato 431.0 magliette taglia S a 13.45€ all'indirizzo [45.09102, 8.610417]
# ["['Filippo', 'Zacchei', 'SRL']"] ha ordinato 353.0 magliette taglia S a 19.91€ all'indirizzo [45.442417, 11.506261]
# ["['Enrico', 'Zacchei', 'e', 'Fratelli']"] ha ordinato 251.0 magliette taglia XXL a 11.29€ all'indirizzo [45.735395, 6.456831]
# ["['Angelica', 'Fedeli', 'Tentazioni']"] ha ordinato 314.0 magliette taglia L a 16.52€ all'indirizzo [44.581005, 9.085324]
# ["['JP', 'Calcaterra', 'Formaggi']"] ha ordinato 377.0 magliette taglia S a 8.33€ all'indirizzo [44.849998, 6.80192]
# ["['Filippo', 'Zacchei', 'Formaggi']"] ha ordinato 457.0 magliette taglia M a 8.16€ all'indirizzo [45.973944, 8.89959]
# ["['Maurizio', 'Cerisola', 'Frumento']"] ha ordinato 492.0 magliette taglia S a 16.34€ all'indirizzo [45.149412, 12.169453]
# ["['Gianmarco', 'Moneta', 'Ingranaggi']"] ha ordinato 323.0 magliette taglia M a 12.24€ all'indirizzo [44.53398, 11.323193]
# ["['Angelica', 'Vitellio', 'Company']"] ha ordinato 58.0 magliette taglia XL a 11.61€ all'indirizzo [46.040884, 9.678264]
# ["['JP', 'Carrara', 'Formaggi']"] ha ordinato 49.0 magliette taglia M a 10.1€ all'indirizzo [46.381414, 7.667042]
# ["['Davide', 'Carrara', 'e', 'Sorelle']"] ha ordinato 399.0 magliette taglia M a 9.57€ all'indirizzo [46.603439, 11.961958]
# ["['Alessandro', 'Moneta', 'Company']"] ha ordinato 52.0 magliette taglia XL a 11.25€ all'indirizzo [44.916092, 7.685749]
# ["['Valentina', 'Carrara', 'Frutta', 'e', 'Verdura']"] ha ordinato 322.0 magliette taglia XL a 7.91€ all'indirizzo [46.415435, 7.948245]
# ["['Valentina', 'Mescolini', 'Servizi', 'Finanziari']"] ha ordinato 189.0 magliette taglia XL a 18.86€ all'indirizzo [46.65957, 8.348547]
# ["['Manuel', 'Iacovelli', 'Company']"] ha ordinato 436.0 magliette taglia XS a 12.89€ all'indirizzo [45.864907, 11.562738]
# ["['Gianmarco', 'Carrara', 'Tentazioni']"] ha ordinato 216.0 magliette taglia S a 19.14€ all'indirizzo [46.206842, 10.051039]
# ["['Francesco', 'Calcaterra', 'Frumento']"] ha ordinato 377.0 magliette taglia L a 9.23€ all'indirizzo [46.495117, 8.963244]
# ["['Luca', 'Genalti', 'Company']"] ha ordinato 283.0 magliette taglia S a 15.62€ all'indirizzo [45.433222, 11.466422]
# ["['Enrico', 'Moneta', 'Ingranaggi']"] ha ordinato 175.0 magliette taglia XXL a 7.57€ all'indirizzo [46.380001, 7.402622]
# ["['Valentina', 'Bacchiocchi', 'Latte']"] ha ordinato 132.0 magliette taglia M a 8.71€ all'indirizzo [44.413231, 8.210041]
# ["['Carlo', 'Augusto', 'Fedeli', 'Mascherine']"] ha ordinato 357.0 magliette taglia XS a 17.5€ all'indirizzo [45.250094, 8.771933]
# ["['Mirko', 'Cerisola', 'Trasporti']"] ha ordinato 298.0 magliette taglia XS a 16.8€ all'indirizzo [44.528207, 8.83529]
# ["['MC', 'Bressan', 'Co.']"] ha ordinato 101.0 magliette taglia XS a 8.8€ all'indirizzo [45.574037, 10.664082]
# ["['Luca', 'Calcaterra', 'Servizi', 'Finanziari']"] ha ordinato 466.0 magliette taglia L a 6.97€ all'indirizzo [45.964823, 6.709614]
# ["['Carlo', 'Augusto', 'Iacovelli', 'IB']"] ha ordinato 440.0 magliette taglia S a 8.97€ all'indirizzo [44.700178, 10.371405]
# ["['Valentina', 'Baroni', 'Latte']"] ha ordinato 437.0 magliette taglia S a 17.34€ all'indirizzo [46.304438, 7.327083]
# ["['JP', 'Calcaterra', 'Strumenti', 'Musicali']"] ha ordinato 360.0 magliette taglia L a 17.15€ all'indirizzo [46.539543, 7.237576]
# ["['Carlo', 'Augusto', 'Vitellio', 'Giocattoli']"] ha ordinato 327.0 magliette taglia XL a 14.26€ all'indirizzo [46.048523, 10.763731]
# ["['Francesco', 'Iacovelli', 'Trasporti']"] ha ordinato 180.0 magliette taglia S a 13.86€ all'indirizzo [46.402325, 10.369838]
# ["['Angelica', 'Sosta', 'Automotive']"] ha ordinato 140.0 magliette taglia XXL a 13.73€ all'indirizzo [44.502061, 11.728325]
# ["['Carlo', 'Augusto', 'Moneta', 'Company']"] ha ordinato 381.0 magliette taglia XS a 16.47€ all'indirizzo [44.771048, 7.180173]
# ["['Giulia', 'Calcaterra', 'Tentazioni']"] ha ordinato 478.0 magliette taglia S a 13.48€ all'indirizzo [44.425229, 11.301004]
# ['[\'Luca\', \'Vitellio\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 421.0 magliette taglia XL a 6.6€ all'indirizzo [44.625169, 8.624003]
# ["['Alessandro', 'Calcaterra', 'e', 'Fratelli']"] ha ordinato 474.0 magliette taglia XXL a 6.07€ all'indirizzo [46.185822, 6.912311]
# ["['Giulia', 'Sartor', 'Strumenti', 'Musicali']"] ha ordinato 64.0 magliette taglia M a 8.79€ all'indirizzo [44.890658, 8.996277]
# ["['MC', 'Cerisola', 'IB']"] ha ordinato 90.0 magliette taglia L a 10.31€ all'indirizzo [46.60587, 7.33759]
# ['[\'Mirko\', \'Bacchiocchi\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 284.0 magliette taglia L a 11.08€ all'indirizzo [44.530199, 10.147441]
# ["['Carlo', 'Augusto', 'Cerisola', 'e', 'Fratelli']"] ha ordinato 135.0 magliette taglia XS a 19.88€ all'indirizzo [46.429483, 11.714962]
# ['[\'Manuel\', \'Bacchiocchi\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 159.0 magliette taglia S a 9.13€ all'indirizzo [46.089257, 11.04213]
# ["['Alessandro', 'Carrara', 'e', 'Fratelli']"] ha ordinato 82.0 magliette taglia XXL a 15.57€ all'indirizzo [46.472705, 7.279097]
# ["['JP', 'Sosta', 'Strumenti', 'Musicali']"] ha ordinato 372.0 magliette taglia L a 10.97€ all'indirizzo [45.924028, 8.184844]
# ["['Enrico', 'Bressan', 'Mascherine']"] ha ordinato 213.0 magliette taglia XXL a 8.21€ all'indirizzo [46.079153, 8.78949]
# ["['Valentina', 'Bressan', 'SPA']"] ha ordinato 419.0 magliette taglia XL a 17.2€ all'indirizzo [45.938525, 8.407709]
# ["['Gianmarco', 'Sartor', 'Ingranaggi']"] ha ordinato 497.0 magliette taglia XL a 9.56€ all'indirizzo [44.771607, 7.915783]
# ["['Carlo', 'Augusto', 'Calcaterra', 'Giocattoli']"] ha ordinato 157.0 magliette taglia L a 9.96€ all'indirizzo [44.636638, 10.924933]
# ["['JP', 'Carrara', 'Servizi', 'Finanziari']"] ha ordinato 486.0 magliette taglia XS a 19.87€ all'indirizzo [46.177794, 8.410633]
# ["['Francesco', 'Baroni', 'Racing']"] ha ordinato 158.0 magliette taglia L a 13.03€ all'indirizzo [44.564887, 10.126763]
# ["['Davide', 'Mescolini', 'Ingranaggi']"] ha ordinato 344.0 magliette taglia S a 11.87€ all'indirizzo [44.877434, 7.569413]
# ['[\'MC\', \'Moneta\', \'Giochi\', "d\'Azzardo"]'] ha ordinato 32.0 magliette taglia XS a 19.59€ all'indirizzo [44.880335, 8.654812]
# ["['Davide', 'Mescolini', 'IB']"] ha ordinato 229.0 magliette taglia XXL a 6.0€ all'indirizzo [45.369927, 10.482076]
# ["['JP', 'Zacchei', 'Frutta', 'e', 'Verdura']"] ha ordinato 182.0 magliette taglia XS a 19.11€ all'indirizzo [45.29682, 7.709197]
# ["['Gianmarco', 'Zacchei', 'INC.']"] ha ordinato 22.0 magliette taglia M a 8.52€ all'indirizzo [46.463394, 8.173962]
# ["['Angelica', 'Moneta', 'Co.']"] ha ordinato 104.0 magliette taglia XS a 16.3€ all'indirizzo [45.101871, 7.06975]
# ["['Gianmarco', 'Carrara', 'IB']"] ha ordinato 3.0 magliette taglia L a 9.05€ all'indirizzo [45.952648, 6.764722]
# ["['Giulia', 'Sgarbossa', 'Giocattoli']"] ha ordinato 384.0 magliette taglia M a 9.06€ all'indirizzo [46.194702, 10.490741]
# ["['Gianmarco', 'Vitellio', 'Grissini']"] ha ordinato 281.0 magliette taglia S a 8.95€ all'indirizzo [44.409965, 8.728726]
