# %% [markdown]
# # Magliette AzIM: ordini, prezzi e consegne

# %% [markdown]
# L'**Azienda degli Ingegneri Matematici** ha bisogno del tuo aiuto: uno stagista chiamato F.B. ha eliminato il database degli ordini delle stupende **magliette ufficiali AzIM**! Tutto quello che rimane sono 420 frammenti di email con le richieste dei clienti, spetta a te recuperarle e determinare che ordini accettare!
#
#
# 0. Nella cartella data trovi tutti i file di testo con i frammenti di email, sono tutti diversi! Contengono la **taglia** delle magliette, la **quantità** di magliette ordinate, la **posizione** in coordinate GCS della consegna, il **nome** del cliente e il **prezzo** a cui vorrebbe acquistare il singolo capo
#
#
# 1. [1pt] Registra gli ordini in una **lista di oggetti** "Order"
#
#
# 2. [1pt] Ogni cliente ha richiesto un prezzo diverso, ma il prezzo di vendita deve essere unico. Considerando 6€ come costo di produzione di una maglietta, determina il **prezzo di vendita** a cui si otterrebbe il maggior  profitto totale (se il prezzo richiesto dal cliente è strettamente inferiore al prezzo di vendita, il cliente non acquisterà)
#
#
# 3. [1pt] Considera i **costi di consegna**: viene applicato un costo di 0.10€/km a capo per per ogni ordine sotto le 100 unità, mentre di 0.05€/km per ogni ordine di almeno 100 unità. Trova il nuovo prezzo di vendita che porti al maggior profitto totale e componi la lista degli ordini da eseguire, riordinata dall'ordine che porterebbe al profitto maggiore fino a quella che porterebbe al profitto minore.
#
#
# 4. [FACOLTATIVO per lode] Considera la curvatura terrestre per il calcolo della distanza per le consegne (riscrivi la funzione "Distance")
#
#
# Utilizza il seguente codice come punto di partenza, riempiendo gli spazi dove manca codice!
#
#
# Per qualsiasi domanda contattare Jean Paul G. Baroni +393315969286

# %%
# 1. Registra gli ordini in una lista di classi Order

GCS_Piazza_Leo = [45.478104, 9.227040] # Coordinate di Piazza Leonardo da Vinci, Milano
production_cost = 6 # Costo fisso di produzione della maglietta
num_orders = 420 # Numero di ordini nella cartella "data"

orders = [] # Lista di oggetti che descrivono gli ordini ricevuti

# Classe che descrive ciascun ordine ricevuto
class Order:
    
    # Costruttore della classe (prende in input il frammento di email salvato nei .txt)
    def __init__(self, email_fragment):
        
        # Separa le righe del frammento e le salva nella lista lines
        lines = email_fragment.split("\n")
        
        # Salva la taglia della maglietta
        self.size = lines[1].split(" ")[-1]
        
        # Salva la quantità di magliette richieste
        self.quantity = float(lines[1].split(" ")[-5])
        
        # Salva la posizione di consegna dell'ordine come due elementi float di una lista
        self.GCS = [float(lines[2].split(" ")[-1].split(",")[0][1:]),float(lines[2].split(" ")[-1].split(",")[1][:-1])]
        
        # Salva il nome del cliente (ultima riga del txt)
        self.customer = lines[-1]
        
        # Salva il prezzo richiesto dal cliente (bid price)
        self.bid_price = float(lines[3].split(" ")[-1][:-1])
    
    # Calcola il pagamento che questo cliente effettuerebbe dato un prezzo di vendita
    def Payment(self, ask_price):
        if (ask_price - self.bid_price) > 0:
            return ask_price - self.bid_price
        else:
            return 0
    
    # Calcola il profitto (ricavi - costi) per un ordine a questo cliente dato un prezzo di vendita
    def Profit(self, ask_price, cost_per_km = 0):
        if (self.Payment(ask_price)>0) & (ask_price - 6 - cost_per_km*self.Distance()>0):
            return ask_price - 6 - cost_per_km*self.Distance()
        else:
            return 0
    
    # Calcola una distanza approssimata in km tra piazza Leonardo da Vinci (punto di partenza delle consegne) e la destinazione
    def Distance(self, starting_GCS = GCS_Piazza_Leo):
        return (((starting_GCS[0] - self.GCS[0])*111)**2+((starting_GCS[1] - self.GCS[1])*78)**2)**0.5
    
    # Stampa i dettagli dell'oggetto
    def Details(self):
        print(self.customer,"ha ordinato",self.quantity,"magliette taglia",self.size,"a "+str(self.bid_price)+"€ all'indirizzo",self.GCS)
    
# Crea gli oggetti Order e li registra nella lista orders
for i in range(num_orders):
    _######## SCRIVI CODICE ########
    # Apri il file ... orders.append( ... Chiudi il file
    nome_file = str(i+1) + '.txt'
    file = open(nome_file, encoding="utf8", errors='ignore')
    testo = file.read()
    orders.append(Order(testo))
    file.close()

# %%
# 2. [1pt] Ogni cliente ha richiesto un prezzo diverso, ma il prezzo di vendita deve essere unico. Considerando 6€ come costo di produzione di una maglietta, determina il **prezzo di vendita** a cui si otterrebbe il maggior  profitto totale (se il prezzo richiesto dal cliente è strettamente inferiore al prezzo di vendita, il cliente non acquisterà)

# Determina i profitti per tutti i possibili prezzi di vendita, riferendosi ai prezzi richiesti dai clienti 
possible_profits = []
for j in range(num_orders):
    somma=0
    for i in range(num_orders):
        somma=somma+orders[i].Profit(orders[j].bid_price)
    possible_profits.append(somma)

for pp in possible_profits:
    print(pp)

# Determina il profitto maggiore
max_profit = max(possible_profits)
max_index=0
for pp in possible_profits:
    if possible_profits==max_profit:
        max_index=pp
    
# Determina il prezzo migliore
best_price = orders[max_index].bid_price
print("Il miglior prezzo è €"+str(best_price))

# Trova gli ordini da eseguire dato il miglior prezzo
orders_to_go = [ord1 for ord1 in orders if ord1.Profit(best_price) > 0]
print("Si eseguiranno", len(orders_to_go),"ordini")
# Out:
# 1693.5999999999933
# 5030.400000000006
# 5373.0
# 3050.0
# 980.4999999999967
# 44.099999999999966
# 5782.399999999975
# 2557.599999999997
# 86.80000000000005
# 2930.20000000001
# 556.0
# 3050.0
# 586.3000000000015
# 860.0
# 4513.999999999969
# 526.4999999999987
# 26.599999999999984
# 1848.0000000000073
# 5630.400000000042
# 13.200000000000012
# 3050.0
# 291.20000000000056
# 3050.0
# 1641.6000000000065
# 686.399999999998
# 26.599999999999984
# 2421.0
# 150.10000000000022
# 4513.999999999969
# 860.0
# 3909.8000000000243
# 3796.199999999979
# 5373.0
# 17.5
# 0
# 4876.199999999998
# 1848.0000000000073
# 1371.5
# 2557.599999999997
# 291.20000000000056
# 8.399999999999995
# 5562.199999999958
# 1547.0
# 2108.1999999999935
# 0
# 2058.2000000000075
# 4223.6999999999725
# 1004.399999999997
# 166.0
# 586.3000000000015
# 4812.800000000034
# 107.19999999999987
# 191.09999999999968
# 310.29999999999995
# 3423.0
# 107.19999999999987
# 441.99999999999903
# 526.4999999999987
# 0
# 2803.199999999985
# 1777.5
# 122.40000000000013
# 653.5999999999995
# 860.0
# 5630.400000000042
# 378.20000000000056
# 2755.0
# 818.2999999999977
# 204.5999999999997
# 3718.0
# 458.5
# 526.4999999999987
# 5630.400000000042
# 1547.0
# 1107.799999999996
# 5373.0
# 0
# 5030.400000000006
# 242.5
# 3050.0
# 345.0
# 345.0
# 310.29999999999995
# Il miglior prezzo è €13.3
# Si eseguiranno 232 ordini

# %%
# 3. [1pt] Considera i **costi di consegna**: viene applicato un costo di 0.10€/km a capo per per ogni ordine sotto le 100 unità, mentre di 0.05€/km per ogni ordine di almeno 100 unità. Trova il nuovo prezzo di vendita che porti al maggior profitto totale e componi la lista degli ordini da eseguire, riordinata dall'ordine che porterebbe al profitto maggiore fino a quella che porterebbe al profitto minore.

def insertionSort(arr): 
  
    for i in range(len(arr)) : 
        
        objectkey=arr[i]
        key=arr[i].Profit(best_price,int(arr[i].quantity>100)*cost_at_least_100+int(arr[i].quantity<100)*cost_less_100)
        j = i-1
        
        while arr[j].Profit(best_price,int(arr[j].quantity>100)*cost_at_least_100+int(arr[j].quantity<100)*cost_less_100) > key and j >=0 : 
            arr[j+1]=arr[j]               #move element one position ahead
            j=j-1                         #update j
                
        arr[j+1] = objectkey
        
    return arr

cost_less_100 = 0.10
cost_at_least_100 = 0.05

# Determina i profitti per tutti i possibili prezzi di vendita, riferendosi ai prezzi richiesti dai clienti 
possible_profits = []
costkm=0;
for j in range(num_orders):
    somma=0
    for i in range(num_orders):
        if orders[i].quantity<100:
            costkm=cost_less_100
        else:
            costkm=cost_at_least_100
        somma=somma+orders[i].Profit(orders[j].bid_price,costkm)
    possible_profits.append(somma)

# Determina il profitto maggiore
max_profit = max(possible_profits)
max_index=0
for pp in possible_profits:
    if possible_profits==max_profit:
        max_index=pp
        
for pp in possible_profits:
    print(pp)

# Determina il prezzo migliore
best_price = orders[max_index].bid_price
print("Il miglior prezzo è €"+str(best_price))

# Trova gli ordini da eseguire dato il miglior prezzo
orders_to_go = [ord1 for ord1 in orders if ((ord1.Profit(best_price,int(ord1.quantity>100)*cost_at_least_100+int(ord1.quantity<100)*cost_less_100)))]
print("Si eseguiranno", len(orders_to_go),"ordini")

######## SCRIVI CODICE ########

orderedlist = insertionSort(orders)
newlist = []

for i in range(num_orders):
    if orders[i].Profit(best_price,int(orders[i].quantity>100)*cost_at_least_100+int(orders[i].quantity<100)*cost_less_100):
        newlist.append(orders[i])

newlist_to_go = [ord1 for ord1 in orderedlist if ((ord1.Profit(best_price,int(ord1.quantity>100)*cost_at_least_100+int(ord1.quantity<100)*cost_less_100)))]

_ = [otg.Details() for otg in newlist_to_go]
# Out:
# 265.5267433869241
# 2057.4485632333417
# 2278.8083322971625
# 836.341157831244
# 66.07017588934362
# 0
# 2537.693276417992
# 608.495137496817
# 0.35784202431595724
# 774.7439773842354
# 19.65988637623752
# 836.341157831244
# 21.756327975274466
# 52.503370924804976
# 1674.3603967519605
# 17.748188611329606
# 0
# 324.96768131472254
# 2448.8424592706365
# 0
# 836.341157831244
# 3.268065150917169
# 0
# 0
# 888.165589619311
# 749.0782925289564
# 0
# 1674.3603967519605
# 0
# 3.8680651509171664
# 0
# 44.48001196146643
# 774.7439773842354
# 155.52023764725877
# 71.07308810816915
# 1154.200725840003
# 164.28475920611194
# 0.6578420243159571
# 95.18081483652365
# 283.8969472085514
# 2537.693276417992
# 61.22567406751182
# 1013.91416383034
# 1.4441721273171078
# 1.0578420243159565
# 947.9934900690693
# 132.74144943249064
# 83.60612196540744
# 19.65988637623752
# 9.9024080554071
# 61.22567406751182
# 0.8578420243159572
# 1907.4751702553503
# 194.1623409335334
# 2057.4485632333417
# 6.950523654234324
# 726.0314584550202
# 0.4578420243159569
# 2.6981445684939285
# 1182.2557774600652
# 836.341157831244
# 0.9578420243159569
# 0
# 3.8680651509171664
# 1301.6164204374304
# 1231.9746812821193
# 404.7370426344246
# 343.42619601339817
# 324.96768131472254
# 978.4661548710262
# 283.8969472085514
# 0
# 0
# 2.6981445684939285
# 26.24110266126749
# 52.503370924804976
# 2448.8424592706365
# 6.050523654234327
# 700.6085526442585
# 44.48001196146643
# 1.2216790152936705
# 1182.2557774600652
# 9.9024080554071
# 17.748188611329606
# 2448.8424592706365
# 225.38808364327008
# 95.18081483652365
# 2278.8083322971625
# 0
# 2057.4485632333417
# 2.044172127317106
# 836.341157831244
# 4.506648482787757
# 4.506648482787757
# 3.8680651509171664
# Il miglior prezzo è €13.3
# Si eseguiranno 113 ordini
# Davide Mescolini Ingranaggi ha ordinato 344.0 magliette taglia S a 11.8€ all'indirizzo [44.877434, 7.569413]
# Valentina Carrara Frutta e Verdura ha ordinato 322.0 magliette taglia XL a 7.9€ all'indirizzo [46.415435, 7.948245]
# Angelica Vitellio Company ha ordinato 58.0 magliette taglia XL a 11.6€ all'indirizzo [46.040884, 9.678264]
# Valentina Bacchiocchi Latte ha ordinato 132.0 magliette taglia M a 8.7€ all'indirizzo [44.413231, 8.210041]
# MC Baroni IB ha ordinato 243.0 magliette taglia L a 9.0€ all'indirizzo [45.479364, 7.406341]
# Davide Cerisola Co. ha ordinato 493.0 magliette taglia XL a 6.3€ all'indirizzo [45.771298, 7.518309]
# Angelica Fedeli Frutta e Verdura ha ordinato 28.0 magliette taglia XXL a 9.9€ all'indirizzo [45.79175, 8.469861]
# Mirko Zacchei Mascherine ha ordinato 176.0 magliette taglia XS a 6.4€ all'indirizzo [46.488766, 8.225467]
# Alessandro Carrara e Sorelle ha ordinato 368.0 magliette taglia M a 5.9€ all'indirizzo [46.536574, 8.333333]
# Francesco Carrara Giochi d'Azzardo ha ordinato 465.0 magliette taglia L a 12.6€ all'indirizzo [46.507253, 8.291301]
# Giulia Sartor Strumenti Musicali ha ordinato 64.0 magliette taglia M a 8.7€ all'indirizzo [44.890658, 8.996277]
# JP Bacchiocchi Frutta e Verdura ha ordinato 393.0 magliette taglia S a 10.0€ all'indirizzo [46.272922, 10.53863]
# Gianmarco Carrara Grissini ha ordinato 293.0 magliette taglia M a 10.0€ all'indirizzo [44.489075, 8.228872]
# Carlo Augusto Fedeli INC. ha ordinato 270.0 magliette taglia S a 11.1€ all'indirizzo [45.326567, 7.738032]
# MC Vitellio SRL ha ordinato 321.0 magliette taglia M a 6.7€ all'indirizzo [46.499945, 8.878639]
# Alessandro Bressan Formaggi ha ordinato 460.0 magliette taglia XS a 6.7€ all'indirizzo [45.995927, 10.516504]
# Francesco Calcaterra Frumento ha ordinato 377.0 magliette taglia L a 9.2€ all'indirizzo [46.495117, 8.963244]
# Mirko Genalti Trasporti ha ordinato 366.0 magliette taglia XS a 6.3€ all'indirizzo [46.477647, 9.589753]
# Filippo Baroni Trasporti ha ordinato 194.0 magliette taglia XS a 10.4€ all'indirizzo [46.50558, 9.349746]
# MC Bressan Co. ha ordinato 101.0 magliette taglia XS a 8.0€ all'indirizzo [45.574037, 10.664082]
# Luca Sgarbossa e Sorelle ha ordinato 316.0 magliette taglia L a 6.1€ all'indirizzo [45.482981, 7.786416]
# Angelica Carrara Franchising ha ordinato 150.0 magliette taglia XXL a 9.2€ all'indirizzo [46.05271, 10.398746]
# Angelica Bressan e Fratelli ha ordinato 277.0 magliette taglia XS a 11.8€ all'indirizzo [44.51498, 9.57488]
# Carlo Augusto Bressan Franchising ha ordinato 332.0 magliette taglia M a 10.1€ all'indirizzo [45.009923, 7.999855]
# JP Sgarbossa Franchising ha ordinato 489.0 magliette taglia XXL a 9.3€ all'indirizzo [46.272846, 10.028032]
# Mirko Fedeli Tentazioni ha ordinato 346.0 magliette taglia XL a 6.4€ all'indirizzo [45.53303, 10.609156]
# Davide Sosta Frumento ha ordinato 333.0 magliette taglia XL a 11.8€ all'indirizzo [44.534782, 9.489222]
# Luca Vitellio Giochi d'Azzardo ha ordinato 421.0 magliette taglia XL a 6.0€ all'indirizzo [44.625169, 8.624003]
# Giulia Bacchiocchi Azienda Agricola ha ordinato 311.0 magliette taglia XS a 7.7€ all'indirizzo [45.570293, 10.560759]
# Manuel Zacchei Frutta e Verdura ha ordinato 140.0 magliette taglia XXL a 8.0€ all'indirizzo [44.542376, 9.368889]
# Maurizio Calcaterra Frutta e Verdura ha ordinato 435.0 magliette taglia XL a 7.8€ all'indirizzo [45.404632, 10.560763]
# Angelica Cerisola Azienda Agricola ha ordinato 389.0 magliette taglia M a 11.3€ all'indirizzo [45.219274, 10.508013]
# Maurizio Genalti Racing ha ordinato 159.0 magliette taglia M a 8.8€ all'indirizzo [44.592882, 9.60751]
# Angelica Sgarbossa Company ha ordinato 187.0 magliette taglia XXL a 6.7€ all'indirizzo [44.603494, 8.832301]
# JP Bacchiocchi INC. ha ordinato 384.0 magliette taglia M a 7.4€ all'indirizzo [45.952838, 8.110702]
# Enrico Bressan e Sorelle ha ordinato 477.0 magliette taglia XXL a 6.3€ all'indirizzo [46.082036, 8.249885]
# Maurizio Cerisola Franchising ha ordinato 465.0 magliette taglia XL a 5.0€ all'indirizzo [44.584452, 8.957538]
# JP Iacovelli Co. ha ordinato 410.0 magliette taglia XXL a 8.8€ all'indirizzo [45.523926, 7.930447]
# JP Bressan e Sorelle ha ordinato 401.0 magliette taglia XS a 11.1€ all'indirizzo [46.341109, 9.61142]
# Manuel Sosta Giochi d'Azzardo ha ordinato 155.0 magliette taglia XS a 11.2€ all'indirizzo [46.033333, 10.237615]
# Filippo Vitellio Racing ha ordinato 102.0 magliette taglia L a 9.9€ all'indirizzo [45.280389, 7.992829]
# Davide Mescolini IB ha ordinato 229.0 magliette taglia XXL a 6.0€ all'indirizzo [45.369927, 10.482076]
# Alessandro Calcaterra Azienda Agricola ha ordinato 420.0 magliette taglia M a 6.6€ all'indirizzo [44.769548, 9.969949]
# Davide Fedeli Giocattoli ha ordinato 348.0 magliette taglia M a 10.4€ all'indirizzo [45.742284, 8.065]
# JP Sosta Strumenti Musicali ha ordinato 372.0 magliette taglia L a 10.9€ all'indirizzo [45.924028, 8.184844]
# Angelica Calcaterra Automotive ha ordinato 157.0 magliette taglia XL a 12.5€ all'indirizzo [44.632037, 9.130843]
# Mirko Sosta e Fratelli ha ordinato 380.0 magliette taglia M a 7.6€ all'indirizzo [46.202755, 9.779329]
# Mirko Genalti Trasporti ha ordinato 125.0 magliette taglia XS a 11.5€ all'indirizzo [44.666498, 9.392403]
# Enrico Iacovelli e Fratelli ha ordinato 274.0 magliette taglia M a 11.4€ all'indirizzo [45.960063, 10.152785]
# Carlo Augusto Sgarbossa Franchising ha ordinato 72.0 magliette taglia XXL a 13.0€ all'indirizzo [45.248003, 9.682098]
# MC Carrara Ingranaggi ha ordinato 286.0 magliette taglia M a 11.0€ all'indirizzo [46.228417, 9.538016]
# Francesco Baroni INC. ha ordinato 52.0 magliette taglia XS a 10.5€ all'indirizzo [45.101491, 9.361921]
# Angelica Cerisola INC. ha ordinato 255.0 magliette taglia XL a 10.4€ all'indirizzo [44.832383, 9.808927]
# MC Sgarbossa e Sorelle ha ordinato 455.0 magliette taglia M a 8.0€ all'indirizzo [46.109764, 8.626903]
# Alessandro Zacchei Co. ha ordinato 163.0 magliette taglia XS a 6.7€ all'indirizzo [45.619768, 10.248465]
# Luca Bacchiocchi e Fratelli ha ordinato 338.0 magliette taglia XS a 7.0€ all'indirizzo [45.578003, 8.200128]
# Enrico Iacovelli Latte ha ordinato 460.0 magliette taglia XL a 5.0€ all'indirizzo [44.959459, 9.934886]
# Luca Bacchiocchi Formaggi ha ordinato 320.0 magliette taglia XS a 10.3€ all'indirizzo [45.950367, 8.493355]
# Francesco Cerisola Automotive ha ordinato 272.0 magliette taglia XXL a 7.1€ all'indirizzo [45.999781, 8.600397]
# Enrico Bressan Mascherine ha ordinato 213.0 magliette taglia XXL a 8.2€ all'indirizzo [46.079153, 8.78949]
# JP Vitellio INC. ha ordinato 231.0 magliette taglia M a 11.8€ all'indirizzo [45.0728, 9.995119]
# Maurizio Calcaterra Company ha ordinato 341.0 magliette taglia L a 6.7€ all'indirizzo [45.244452, 8.328244]
# Luca Baroni Frumento ha ordinato 383.0 magliette taglia XL a 6.0€ all'indirizzo [45.935365, 9.925589]
# Alessandro Vitellio Trasporti ha ordinato 438.0 magliette taglia XXL a 8.7€ all'indirizzo [46.101869, 8.912694]
# Valentina Vitellio Azienda Agricola ha ordinato 270.0 magliette taglia XXL a 8.9€ all'indirizzo [44.977718, 8.638279]
# Davide Moneta Trasporti ha ordinato 393.0 magliette taglia S a 7.1€ all'indirizzo [46.074384, 9.567616]
# Angelica Iacovelli e Sorelle ha ordinato 108.0 magliette taglia XXL a 12.2€ all'indirizzo [45.325776, 8.33967]
# Francesco Sartor Company ha ordinato 379.0 magliette taglia S a 8.5€ all'indirizzo [46.070072, 8.943784]
# Francesco Cerisola INC. ha ordinato 412.0 magliette taglia XS a 10.9€ all'indirizzo [45.691742, 10.051885]
# Maurizio Sartor Frumento ha ordinato 471.0 magliette taglia M a 13.2€ all'indirizzo [45.144346, 9.944353]
# Francesco Vitellio Co. ha ordinato 249.0 magliette taglia M a 5.9€ all'indirizzo [44.941289, 9.579991]
# Angelica Vitellio Giochi d'Azzardo ha ordinato 149.0 magliette taglia M a 10.8€ all'indirizzo [45.383702, 8.412917]
# Alessandro Sosta INC. ha ordinato 434.0 magliette taglia XL a 11.8€ all'indirizzo [45.925558, 9.727535]
# Filippo Zacchei Formaggi ha ordinato 457.0 magliette taglia M a 8.1€ all'indirizzo [45.973944, 8.89959]
# Manuel Bacchiocchi Formaggi ha ordinato 280.0 magliette taglia XL a 5.3€ all'indirizzo [45.906227, 9.680257]
# Giulia Vitellio Grissini ha ordinato 150.0 magliette taglia XXL a 7.9€ all'indirizzo [45.473989, 9.9247]
# Luca Fedeli Mascherine ha ordinato 368.0 magliette taglia XXL a 5.1€ all'indirizzo [45.705954, 9.841363]
# Filippo Mescolini Ingranaggi ha ordinato 253.0 magliette taglia L a 12.3€ all'indirizzo [45.805734, 9.732641]
# Alessandro Baroni Frumento ha ordinato 477.0 magliette taglia S a 7.0€ all'indirizzo [45.405947, 8.556387]
# Valentina Bressan SPA ha ordinato 344.0 magliette taglia XL a 9.0€ all'indirizzo [45.878834, 9.398438]
# Francesco Fedeli Azienda Agricola ha ordinato 313.0 magliette taglia L a 11.9€ all'indirizzo [45.886014, 9.102999]
# Filippo Bacchiocchi Automotive ha ordinato 479.0 magliette taglia XL a 7.4€ all'indirizzo [45.186817, 8.815703]
# Luca Bacchiocchi e Sorelle ha ordinato 114.0 magliette taglia S a 6.1€ all'indirizzo [45.330933, 9.733152]
# Alessandro Bacchiocchi Giochi d'Azzardo ha ordinato 125.0 magliette taglia S a 10.9€ all'indirizzo [45.790945, 9.437917]
# Mirko Bressan Ingranaggi ha ordinato 196.0 magliette taglia XS a 9.8€ all'indirizzo [45.233756, 8.880092]
# Angelica Calcaterra Azienda Agricola ha ordinato 486.0 magliette taglia XS a 12.8€ all'indirizzo [45.420593, 8.805503]
# Gianmarco Calcaterra Tentazioni ha ordinato 436.0 magliette taglia S a 12.8€ all'indirizzo [45.554086, 8.853124]
# Maurizio Vitellio Franchising ha ordinato 310.0 magliette taglia M a 6.7€ all'indirizzo [45.312632, 9.100723]
