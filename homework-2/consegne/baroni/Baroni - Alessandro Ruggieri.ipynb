# %% [markdown]
# # Magliette AzIM: ordini, prezzi e consegne

# %% [markdown]
# L'**Azienda degli Ingegneri Matematici** ha bisogno del tuo aiuto: uno stagista chiamato F.B. ha eliminato il database degli ordini delle stupende **magliette ufficiali AzIM**! Tutto quello che rimane sono 420 frammenti di email con le richieste dei clienti, spetta a te recuperarle e determinare che ordini accettare!
#
#
# 0. Nella cartella data trovi tutti i file di testo con i frammenti di email, sono tutti diversi! Contengono la **taglia** delle magliette, la **quantità** di magliette ordinate, la **posizione** in coordinate GCS della consegna, il **nome** del cliente e il **prezzo** a cui vorrebbe acquistare il singolo capo
#
#
# 1. [1pt] Registra gli ordini in una **lista di oggetti** "Order"
#
#
# 2. [1pt] Ogni cliente ha richiesto un prezzo diverso, ma il prezzo di vendita deve essere unico. Considerando 6€ come costo di produzione di una maglietta, determina il **prezzo di vendita** a cui si otterrebbe il maggior  profitto totale (se il prezzo richiesto dal cliente è strettamente inferiore al prezzo di vendita, il cliente non acquisterà)
#
#
# 3. [1pt] Considera i **costi di consegna**: viene applicato un costo di 0.10€/km a capo per per ogni ordine sotto le 100 unità, mentre di 0.05€/km per ogni ordine di almeno 100 unità. Trova il nuovo prezzo di vendita che porti al maggior profitto totale e componi la lista degli ordini da eseguire, riordinata dall'ordine che porterebbe al profitto maggiore fino a quella che porterebbe al profitto minore.
#
#
# 4. [FACOLTATIVO per lode] Considera la curvatura terrestre per il calcolo della distanza per le consegne (riscrivi la funzione "Distance")
#
#
# Utilizza il seguente codice come punto di partenza, riempiendo gli spazi dove manca codice!
#
#
# Per qualsiasi domanda contattare Jean Paul G. Baroni +393315969286

# %%
# 1. Registra gli ordini in una lista di classi Order

GCS_Piazza_Leo = [45.478104, 9.227040] # Coordinate di Piazza Leonardo da Vinci, Milano
production_cost = 6 # Costo fisso di produzione della maglietta
num_orders = 420 # Numero di ordini nella cartella "data"

orders = [] # Lista di oggetti che descrivono gli ordini ricevuti

# Classe che descrive ciascun ordine ricevuto
class Order:
    
    # Costruttore della classe (prende in input il frammento di email salvato nei .txt)
    def __init__(self, email_fragment):
        
        # Separa le righe del frammento e le salva nella lista lines
        lines = email_fragment.split("\n")
        
        # Salva la taglia della maglietta
        self.size = lines[1].split(" ")[-1]
        
        # Salva la quantità di magliette richieste
        self.quantity = int(lines[1].split(" ")[-5])
        
        # Salva la posizione di consegna dell'ordine come due elementi float di una lista
        self.GCS = [float(lines[2].split(" ")[-1].split(",")[0][1:]),float(lines[2].split(" ")[-1].split(",")[1][:-1])]
        
        # Salva il nome del cliente (ultima riga del txt)
        self.customer = lines[-1].split(" ")[0]
        
        # Salva il prezzo richiesto dal cliente (bid price)
        self.bid_price = float(lines[-3].split(" ")[-1].split("€")[0])
    
    # Calcola il pagamento che questo cliente effettuerebbe dato un prezzo di vendita
    def Payment(self, ask_price):
        if ask_price > self.bid_price:
            return 0
        return ask_price * self.quantity
    
    # Calcola il profitto (ricavi - costi) per un ordine a questo cliente dato un prezzo di vendita
    def Profit(self, ask_price, cost_per_km = 0):
        ricavi = self.Payment(ask_price)
        if ricavi > 0:
            return ricavi - 6 * self.quantity - cost_per_km * self.Distance() * ask_price
        return 0
            
    
    # Calcola una distanza approssimata in km tra piazza Leonardo da Vinci (punto di partenza delle consegne) e la destinazione
    def Distance(self, starting_GCS = GCS_Piazza_Leo):
        return (((starting_GCS[0] - self.GCS[0])*111)**2+((starting_GCS[1] - self.GCS[1])*78)**2)**0.5
    
    # Stampa i dettagli dell'oggetto
    def Details(self):
        print(self.customer,"ha ordinato",self.quantity,"magliette taglia",self.size,"a "+str(self.bid_price)+"€ all'indirizzo",self.GCS)
    
# Crea gli oggetti Order e li registra nella lista orders
for i in range(num_orders):
    file = open(f'data/{i+1}.txt', 'r')
    ordine = Order(file.read())
    orders.append(ordine)

# %%
# 2. [1pt] Ogni cliente ha richiesto un prezzo diverso, ma il prezzo di vendita deve essere unico. Considerando 6€ come costo di produzione di una maglietta, determina il **prezzo di vendita** a cui si otterrebbe il maggior  profitto totale (se il prezzo richiesto dal cliente è strettamente inferiore al prezzo di vendita, il cliente non acquisterà)

# Determina i profitti per tutti i possibili prezzi di vendita, riferendosi ai prezzi richiesti dai clienti 
possible_prices = [ordine.bid_price for ordine in orders]
possible_profits = []
for price in possible_prices:
    possible_profits.append(sum([ordine.Profit(price) for ordine in orders]))

#[print(pp) for pp in possible_profits]

# Determina il profitto maggiore
max_profit = max( possible_profits)

# Determina il prezzo migliore
def index(possible_profits, max_profit):
    for k in range(len(possible_profits)):
        if possible_profits[k] == max_profit:
            return k
best_price = orders[index(possible_profits, max_profit)].bid_price
print("Il miglior prezzo è €"+str(best_price))

# Trova gli ordini da eseguire dato il miglior prezzo
orders_to_go = [ord1 for ord1 in orders if ord1.Profit(best_price) > 0]
print("Si eseguiranno", len(orders_to_go),"ordini")
# Out:
# 354564.00000000023
# 111280.95999999999
# 75871.46
# 264236.80000000005
# 330528.87000000005
# 90644.1200000001
# 3783.1600000000008
# 333773.2199999999
# 127616.81999999996
# 300749.72000000015
# 319720.09999999974
# 297624.0600000001
# 292184.6399999999
# 320043.81000000006
# 145445.52000000002
# 278994.62999999995
# 72250.16
# 350567.8200000002
# 41209.03999999999
# 42498.62
# 297624.0600000001
# 221133.12000000002
# 250398.0
# 359609.5799999998
# 301417.4800000001
# 74561.78000000007
# 336214.0
# 166927.85999999984
# 141438.5
# 321325.50000000023
# 220224.95999999996
# 236757.3599999999
# 79222.64000000003
# 50923.079999999965
# 58505.99999999994
# 131947.55
# 354482.3399999999
# 354646.7199999999
# 320449.26000000024
# 222241.36
# 32068.160000000018
# 53982.5
# 349029.89999999973
# 346361.3999999999
# -96508.80000000012
# 347993.25
# 172987.19999999998
# 331498.0400000001
# 167804.0
# 291512.5999999998
# 133508.98
# 142420.60000000003
# 175307.0399999998
# 229734.19999999984
# 269949.35000000003
# 148226.51999999996
# 254089.45
# 281013.47999999975
# -80335.04000000005
# 303529.5600000002
# 353913.7999999998
# 148511.79000000015
# 139950.08000000007
# 152225.03999999998
# 194173.31999999995
# 280633.6799999998
# 353884.9000000001
# 172837.6000000001
# 341720.32999999996
# 55841.51000000001
# 340272.72
# 353137.62000000005
# 358324.16000000003
# 335284.44000000006
# 98542.72000000002
# 281013.47999999975
# 148226.51999999996
# 135343.46
# 306181.21
# 123439.95000000003
# 148845.3600000001
# 256779.24000000005
# 273002.24999999994
# 311368.9599999999
# 303251.42000000004
# 81466.55999999998
# 228585.05999999997
# 167804.0
# 4541.179999999999
# 356223.61
# 340067.6200000001
# 227920.7700000001
# 209849.2199999999
# -65320.099999999955
# 227256.45000000004
# 68333.23999999995
# 297600.90000000026
# 151910.85
# 35899.200000000004
# 206961.31000000006
# 24168.240000000023
# 290581.62000000005
# 279976.9499999999
# 26297.520000000004
# 262027.26000000015
# 298136.16000000015
# 348452.12
# 255506.0
# 320735.6
# 347737.5800000001
# 240192.3999999999
# 357184.4299999998
# 71632.89
# 231134.24
# 349921.5399999999
# 292106.75999999983
# 229038.88000000003
# 350567.8200000002
# 338776.6499999999
# 3075.3900000000276
# 101653.2
# -1034.8699999999772
# 344198.3999999998
# 128484.08999999998
# 300620.0
# 352667.08
# 56251.36
# 101958.7
# 72250.16
# 244683.7000000001
# 165193.58999999994
# 286164.9
# 28440.719999999994
# 319545.8400000001
# 44319.60000000004
# 354916.2
# 80599.20000000011
# 319583.52000000014
# 241551.71999999997
# 279517.58999999985
# 166927.85999999984
# 242743.6799999999
# 339090.4000000003
# 244688.40000000008
# 157634.80000000002
# 360783.4
# 210884.9600000001
# 352110.0
# 299487.2399999998
# 355373.24000000005
# 117696.80000000009
# 354787.34
# 168216.89999999997
# 354283.72
# 322605.22
# 241468.5
# 320931.11999999994
# 336416.8599999999
# 354916.2
# 332019.5
# 277117.3599999998
# 355931.2800000002
# 189585.76000000007
# 320612.34
# 309248.1899999999
# 315431.6000000002
# 118982.70000000003
# 308945.9999999999
# -86187.23999999995
# 321325.50000000023
# 337503.78999999963
# 290754.88
# 111280.95999999999
# 37353.450000000004
# 184614.08000000007
# 193710.23999999987
# 136182.23999999993
# 136382.49000000005
# 279882.35000000003
# 82045.03999999998
# 345020.9299999998
# 74561.78000000007
# 285126.1200000001
# 315438.2699999999
# 83995.25
# 353578.9900000001
# 335914.5999999999
# 161068.69999999995
# 303587.1999999999
# 226148.79999999993
# 107646.67999999998
# 156931.75999999998
# 143754.59000000003
# 303716.7
# 89162.47999999998
# 128484.08999999998
# 248363.19999999984
# 220224.95999999996
# 16170.199999999997
# 173968.2000000001
# 221501.06000000008
# 86465.81999999999
# 198568.78
# 248325.19
# 337924.90999999986
# 180154.59000000003
# 31165.849999999966
# 348840.9999999998
# 315949.65999999974
# -65320.099999999955
# 220678.56
# 155777.58000000005
# 336645.11999999994
# 36719.91000000001
# 305664.4500000001
# 277781.39999999973
# 351744.12000000005
# 161068.69999999995
# 199638.84000000008
# 347780.78999999986
# 302852.47
# 354387.3199999999
# -48170.28000000001
# 309248.1899999999
# 324438.0800000001
# 161051.12000000008
# 49156.0
# 161905.91999999987
# 286699.9800000002
# 319796.2199999999
# 73859.76000000008
# 360273.4799999999
# 338298.04999999993
# 97008.35999999999
# 71644.5
# 147661.92
# 350656.98000000004
# 47920.25
# 301844.15000000014
# 131634.72000000003
# 345020.9299999998
# 304268.32000000007
# 62039.100000000006
# 288897.46999999986
# 70961.55999999997
# -25001.04000000001
# 190536.06000000003
# 315790.6499999999
# 291512.5999999998
# 326415.24000000005
# 206799.36000000002
# 352400.4000000002
# 347337.61
# 315712.80000000016
# 54706.95999999997
# 318278.00000000006
# 174879.89999999994
# 111773.79000000005
# 3385.58
# 298136.16000000015
# 15216.750000000027
# 234729.43000000002
# 321445.81999999995
# 324307.06999999995
# 206961.31000000006
# 246320.09999999983
# 307431.80000000016
# 295414.73999999993
# 348061.65
# 332019.5
# -68662.7500000001
# 1028.8999999999774
# 347440.5500000001
# 170441.99999999974
# -92891.63999999997
# 356585.2
# 164735.33999999997
# 315744.0000000002
# 103529.47
# 150301.20000000004
# 337462.4499999997
# -101209.80000000003
# 346647.68
# 354787.34
# 221336.85000000012
# 359622.28
# 190536.06000000003
# 360783.4
# 355920.75999999983
# 352242.12000000005
# 322801.99999999977
# 345589.8600000001
# 347198.79999999993
# 88315.79999999992
# 149125.99999999988
# 303393.79000000004
# 131184.56000000003
# 351679.23000000016
# 356342.1399999999
# 255227.46000000008
# 295414.73999999993
# 357912.0200000002
# 37353.450000000004
# 257950.68
# 317294.63999999996
# 227256.45000000004
# 255227.46000000008
# 292742.7300000002
# 233087.9699999999
# 215746.64000000013
# 222328.40000000014
# 346723.01999999984
# 131545.88999999998
# 91649.59999999999
# 292404.75
# 36719.91000000001
# -30224.960000000006
# 91825.68999999999
# 264804.99999999994
# 302421.72000000026
# 346986.89999999956
# 268582.5
# 172987.19999999998
# 62831.600000000064
# 317796.6400000001
# 244850.63
# 106388.95999999999
# 357993.99999999994
# 342417.60000000003
# 202440.96000000008
# 108462.5500000001
# 3075.3900000000276
# 69161.0399999999
# 342417.60000000003
# 149966.25
# 319522.8799999999
# 71632.89
# 299206.45
# 297344.44000000006
# 359622.28
# -9336.239999999983
# 349029.89999999973
# -97947.85000000003
# 248325.19
# 357661.9800000004
# 111280.95999999999
# 347764.06000000006
# -84935.20000000007
# 15216.750000000027
# 288229.49999999994
# 304629.11999999994
# 12193.080000000014
# 144064.79999999993
# 117696.80000000009
# 229038.88000000003
# 14218.259999999964
# 321445.81999999995
# 298134.0499999999
# 354796.1199999996
# 332448.4799999997
# 236955.3899999999
# 354646.7199999999
# 149521.68000000008
# 346441.32
# 356534.65000000014
# 9444.89
# 326932.5800000002
# 267355.28
# 189967.22999999998
# 177958.07999999996
# 284639.52000000014
# 354282.24000000017
# 338131.52999999997
# 289562.5000000002
# 257114.96999999997
# 324733.5
# 161677.68
# 133461.07999999993
# 355496.44000000006
# 118982.70000000003
# 242023.89999999985
# 311649.52000000014
# 139339.07000000004
# 217038.4800000001
# 210887.0
# 250398.0
# 222328.40000000014
# 90171.19999999994
# 227920.7700000001
# 224792.81999999995
# 235844.7999999999
# 346151.81999999983
# 349424.1599999999
# 354482.3399999999
# 279517.58999999985
# 354746.4799999999
# 58505.99999999994
# 7145.810000000035
# 221712.92999999996
# 297833.9299999998
# 321508.1199999998
# 16170.199999999997
# 235028.57000000007
# 315542.04000000004
# 322135.51999999996
# 181067.5100000002
# 232870.4
# 258164.07999999996
# 281013.47999999975
# 26297.520000000004
# 359204.87999999995
# 348061.65
# 71632.89
# 0.0
# 121097.06999999998
# 203623.56000000014
# 284609.6
# 231251.00000000017
# 232000.02000000008
# 229734.19999999984
# Il miglior prezzo è €13.22
# Si eseguiranno 195 ordini

# %%
# 3. [1pt] Considera i **costi di consegna**: viene applicato un costo di 0.10€/km a capo per per ogni ordine sotto le 100 unità, mentre di 0.05€/km per ogni ordine di almeno 100 unità. Trova il nuovo prezzo di vendita che porti al maggior profitto totale e componi la lista degli ordini da eseguire, riordinata dall'ordine che porterebbe al profitto maggiore fino a quella che porterebbe al profitto minore.

cost_less_100 = 0.10
cost_at_least_100 = 0.05

# Determina i profitti per tutti i possibili prezzi di vendita, riferendosi ai prezzi richiesti dai clienti 
possible_profits = []
for price in possible_prices:
    possible_profit = 0
    for ordine in orders:
        if ordine.quantity < 100:
            possible_profit += ordine.Profit(price, cost_less_100)
        else:
            possible_profit += ordine.Profit(price, cost_at_least_100)
    possible_profits.append(possible_profit)
#[print(pp) for pp in possible_profits]

# Determina il profitto maggiore
max_profit = max(possible_profits)

# Determina il prezzo migliore
best_price = orders[index(possible_profits, max_profit)].bid_price
print("Il miglior prezzo è €"+str(best_price))

# Trova gli ordini da eseguire dato il miglior prezzo
orders_to_go = [ord1 for ord1 in orders if ord1.Profit(best_price) > 0]
print("Si eseguiranno", len(orders_to_go),"ordini")

######## SCRIVI CODICE ########
def sort(ord1, best_price):
    n = len(ord1)
    for j in range(n-1):
        for i in range(n-j-1):
            if ord1[i].Profit(best_price) < ord1[i+1].Profit(best_price):
                ord1[i], ord1[i+1] = ord1[i+1], ord1[i]
    return ord1

        
lista_ordinata = sort(orders_to_go, best_price)
# ... assembla la lista degli ordini che devono che si possono soddisfare, dando precedenza a quelli che portano maggiore profitto
######## SCRIVI CODICE ########

_ = [otg.Details() for otg in orders_to_go]
# Out:
# Il miglior prezzo è €13.22
# Si eseguiranno 195 ordini
# JP ha ordinato 497 magliette taglia S a 17.92€ all'indirizzo [45.058065, 6.422715]
# Francesco ha ordinato 494 magliette taglia L a 15.6€ all'indirizzo [44.958786, 10.107809]
# Manuel ha ordinato 492 magliette taglia XS a 19.85€ all'indirizzo [44.811402, 11.070849]
# Maurizio ha ordinato 492 magliette taglia S a 16.34€ all'indirizzo [45.149412, 12.169453]
# Gianmarco ha ordinato 491 magliette taglia XS a 19.79€ all'indirizzo [45.661732, 10.428504]
# JP ha ordinato 486 magliette taglia XS a 19.87€ all'indirizzo [46.177794, 8.410633]
# Carlo ha ordinato 478 magliette taglia S a 14.22€ all'indirizzo [45.482738, 12.006968]
# Giulia ha ordinato 478 magliette taglia S a 13.48€ all'indirizzo [44.425229, 11.301004]
# Davide ha ordinato 477 magliette taglia XS a 17.66€ all'indirizzo [44.478028, 7.044747]
# Francesco ha ordinato 475 magliette taglia XL a 16.62€ all'indirizzo [44.617157, 11.309934]
# Maurizio ha ordinato 475 magliette taglia XL a 16.9€ all'indirizzo [46.141592, 11.350406]
# Giulia ha ordinato 472 magliette taglia S a 14.46€ all'indirizzo [46.027222, 11.996612]
# Maurizio ha ordinato 471 magliette taglia M a 13.26€ all'indirizzo [45.144346, 9.944353]
# Filippo ha ordinato 467 magliette taglia L a 18.25€ all'indirizzo [46.042605, 11.075677]
# Maurizio ha ordinato 467 magliette taglia XS a 15.28€ all'indirizzo [44.989011, 11.117416]
# Giulia ha ordinato 466 magliette taglia XS a 14.51€ all'indirizzo [46.237336, 8.53143]
# Angelica ha ordinato 464 magliette taglia XXL a 17.69€ all'indirizzo [44.921135, 11.10902]
# Giulia ha ordinato 458 magliette taglia L a 17.42€ all'indirizzo [44.386767, 6.492457]
# Filippo ha ordinato 451 magliette taglia L a 19.75€ all'indirizzo [46.430318, 8.170284]
# Gianmarco ha ordinato 441 magliette taglia M a 16.77€ all'indirizzo [45.196751, 9.768684]
# Valentina ha ordinato 439 magliette taglia XL a 19.22€ all'indirizzo [44.723003, 11.118845]
# Enrico ha ordinato 438 magliette taglia XS a 14.53€ all'indirizzo [46.16169, 7.658148]
# Valentina ha ordinato 437 magliette taglia S a 17.34€ all'indirizzo [46.304438, 7.327083]
# Carlo ha ordinato 436 magliette taglia L a 15.63€ all'indirizzo [45.751854, 6.517282]
# MC ha ordinato 435 magliette taglia XL a 14.14€ all'indirizzo [46.646765, 11.645491]
# Davide ha ordinato 431 magliette taglia S a 19.62€ all'indirizzo [45.755771, 8.645121]
# Francesco ha ordinato 431 magliette taglia S a 13.45€ all'indirizzo [45.09102, 8.610417]
# JP ha ordinato 430 magliette taglia S a 14.71€ all'indirizzo [46.320969, 10.122712]
# Filippo ha ordinato 428 magliette taglia S a 18.41€ all'indirizzo [45.406647, 10.68733]
# Angelica ha ordinato 428 magliette taglia XL a 18.18€ all'indirizzo [46.203289, 9.683224]
# Alessandro ha ordinato 426 magliette taglia XS a 17.82€ all'indirizzo [46.601355, 10.070089]
# Valentina ha ordinato 425 magliette taglia XL a 13.73€ all'indirizzo [45.629606, 9.662371]
# Valentina ha ordinato 419 magliette taglia XL a 17.2€ all'indirizzo [45.938525, 8.407709]
# Davide ha ordinato 418 magliette taglia L a 13.74€ all'indirizzo [45.831319, 11.731695]
# Luca ha ordinato 410 magliette taglia XS a 17.54€ all'indirizzo [46.337571, 6.477615]
# Francesco ha ordinato 410 magliette taglia S a 15.52€ all'indirizzo [45.557211, 10.383967]
# Filippo ha ordinato 399 magliette taglia XS a 14.88€ all'indirizzo [44.679291, 10.342392]
# Angelica ha ordinato 399 magliette taglia M a 19.42€ all'indirizzo [45.265113, 11.041044]
# JP ha ordinato 395 magliette taglia M a 17.68€ all'indirizzo [45.443587, 11.121478]
# Gianmarco ha ordinato 389 magliette taglia M a 16.14€ all'indirizzo [44.886641, 7.151952]
# Enrico ha ordinato 387 magliette taglia XL a 17.58€ all'indirizzo [46.488038, 9.932118]
# Valentina ha ordinato 386 magliette taglia M a 15.05€ all'indirizzo [46.640755, 7.389144]
# Maurizio ha ordinato 383 magliette taglia L a 13.35€ all'indirizzo [44.730801, 10.411061]
# Valentina ha ordinato 383 magliette taglia XS a 19.14€ all'indirizzo [46.393485, 11.191038]
# Carlo ha ordinato 381 magliette taglia XS a 16.47€ all'indirizzo [44.771048, 7.180173]
# Luca ha ordinato 377 magliette taglia L a 16.8€ all'indirizzo [46.067706, 6.750235]
# Alessandro ha ordinato 377 magliette taglia L a 13.9€ all'indirizzo [45.860871, 7.417076]
# Gianmarco ha ordinato 368 magliette taglia XS a 13.62€ all'indirizzo [44.532206, 11.41108]
# Alessandro ha ordinato 366 magliette taglia XS a 17.52€ all'indirizzo [46.487746, 9.708342]
# MC ha ordinato 365 magliette taglia M a 19.59€ all'indirizzo [45.410533, 7.184282]
# Filippo ha ordinato 363 magliette taglia XXL a 19.2€ all'indirizzo [45.318257, 9.186061]
# Maurizio ha ordinato 360 magliette taglia M a 17.72€ all'indirizzo [45.069648, 9.03768]
# JP ha ordinato 360 magliette taglia L a 17.15€ all'indirizzo [46.539543, 7.237576]
# Davide ha ordinato 359 magliette taglia S a 16.0€ all'indirizzo [44.455055, 7.827646]
# Gianmarco ha ordinato 357 magliette taglia XS a 15.86€ all'indirizzo [45.804997, 8.586271]
# Carlo ha ordinato 357 magliette taglia XS a 17.5€ all'indirizzo [45.250094, 8.771933]
# Francesco ha ordinato 353 magliette taglia S a 16.05€ all'indirizzo [44.818701, 11.166107]
# Filippo ha ordinato 353 magliette taglia S a 19.91€ all'indirizzo [45.442417, 11.506261]
# MC ha ordinato 351 magliette taglia XS a 19.88€ all'indirizzo [45.498935, 8.319235]
# Maurizio ha ordinato 351 magliette taglia XS a 15.25€ all'indirizzo [45.194455, 7.483713]
# JP ha ordinato 350 magliette taglia XL a 13.55€ all'indirizzo [45.459595, 6.461555]
# Gianmarco ha ordinato 350 magliette taglia S a 13.94€ all'indirizzo [46.205747, 9.805424]
# Gianmarco ha ordinato 344 magliette taglia XXL a 15.2€ all'indirizzo [44.645446, 11.774198]
# Maurizio ha ordinato 344 magliette taglia S a 15.29€ all'indirizzo [44.764578, 10.322331]
# Angelica ha ordinato 343 magliette taglia L a 18.99€ all'indirizzo [46.060128, 11.799358]
# Filippo ha ordinato 342 magliette taglia L a 19.18€ all'indirizzo [46.220461, 8.598891]
# Carlo ha ordinato 340 magliette taglia XXL a 16.49€ all'indirizzo [46.385237, 11.280217]
# Angelica ha ordinato 339 magliette taglia XS a 15.67€ all'indirizzo [46.504628, 7.672028]
# Giulia ha ordinato 335 magliette taglia L a 15.03€ all'indirizzo [44.850889, 11.277868]
# Valentina ha ordinato 331 magliette taglia M a 15.25€ all'indirizzo [46.039545, 7.863041]
# JP ha ordinato 331 magliette taglia M a 13.29€ all'indirizzo [46.414979, 6.631506]
# Carlo ha ordinato 327 magliette taglia XL a 14.26€ all'indirizzo [46.048523, 10.763731]
# Gianmarco ha ordinato 319 magliette taglia M a 19.59€ all'indirizzo [44.918354, 11.037787]
# Francesco ha ordinato 318 magliette taglia L a 16.02€ all'indirizzo [45.760935, 9.123703]
# Enrico ha ordinato 318 magliette taglia XXL a 17.97€ all'indirizzo [45.434194, 8.030439]
# Maurizio ha ordinato 317 magliette taglia L a 17.72€ all'indirizzo [45.367204, 8.151017]
# Filippo ha ordinato 317 magliette taglia L a 15.76€ all'indirizzo [46.353249, 9.794377]
# Luca ha ordinato 316 magliette taglia L a 19.58€ all'indirizzo [46.389283, 11.742332]
# Angelica ha ordinato 314 magliette taglia L a 16.52€ all'indirizzo [44.581005, 9.085324]
# Angelica ha ordinato 307 magliette taglia M a 15.22€ all'indirizzo [45.900417, 11.562795]
# Mirko ha ordinato 307 magliette taglia XS a 15.83€ all'indirizzo [46.323737, 10.584971]
# Davide ha ordinato 304 magliette taglia M a 17.36€ all'indirizzo [45.358661, 10.98252]
# Carlo ha ordinato 300 magliette taglia L a 13.58€ all'indirizzo [46.674732, 10.013196]
# Mirko ha ordinato 298 magliette taglia XS a 16.8€ all'indirizzo [44.528207, 8.83529]
# Carlo ha ordinato 297 magliette taglia L a 17.24€ all'indirizzo [46.017351, 7.527521]
# Luca ha ordinato 294 magliette taglia S a 14.62€ all'indirizzo [44.562334, 10.118565]
# Maurizio ha ordinato 291 magliette taglia L a 13.82€ all'indirizzo [44.703945, 12.034479]
# Luca ha ordinato 291 magliette taglia M a 16.47€ all'indirizzo [46.328157, 6.60567]
# MC ha ordinato 290 magliette taglia M a 16.02€ all'indirizzo [45.288814, 7.365348]
# Enrico ha ordinato 289 magliette taglia L a 14.19€ all'indirizzo [45.895956, 6.644199]
# Carlo ha ordinato 287 magliette taglia L a 19.81€ all'indirizzo [45.507751, 6.527303]
# Luca ha ordinato 283 magliette taglia S a 15.62€ all'indirizzo [45.433222, 11.466422]
# Gianmarco ha ordinato 280 magliette taglia XS a 16.99€ all'indirizzo [46.215419, 11.450555]
# Francesco ha ordinato 277 magliette taglia XS a 19.51€ all'indirizzo [44.827737, 10.648823]
# Gianmarco ha ordinato 275 magliette taglia M a 16.68€ all'indirizzo [46.396994, 12.229419]
# Valentina ha ordinato 275 magliette taglia M a 16.88€ all'indirizzo [44.972102, 8.159992]
# Mirko ha ordinato 274 magliette taglia XXL a 14.25€ all'indirizzo [45.347228, 12.149067]
# Gianmarco ha ordinato 272 magliette taglia XXL a 15.33€ all'indirizzo [44.374026, 10.760497]
# Valentina ha ordinato 271 magliette taglia XL a 16.51€ all'indirizzo [45.384287, 6.751064]
# Valentina ha ordinato 266 magliette taglia M a 18.96€ all'indirizzo [45.395681, 8.384508]
# Valentina ha ordinato 259 magliette taglia L a 15.11€ all'indirizzo [45.614209, 7.809756]
# Angelica ha ordinato 255 magliette taglia M a 16.6€ all'indirizzo [44.983867, 9.346757]
# Carlo ha ordinato 253 magliette taglia L a 17.22€ all'indirizzo [45.749084, 11.770167]
# Valentina ha ordinato 252 magliette taglia S a 13.34€ all'indirizzo [46.295324, 8.771488]
# Angelica ha ordinato 251 magliette taglia XS a 15.27€ all'indirizzo [44.395547, 8.236262]
# Francesco ha ordinato 245 magliette taglia L a 19.87€ all'indirizzo [46.633524, 12.232977]
# Gianmarco ha ordinato 243 magliette taglia XXL a 13.22€ all'indirizzo [46.664931, 7.453308]
# Alessandro ha ordinato 242 magliette taglia XS a 19.99€ all'indirizzo [45.152525, 8.134165]
# Giulia ha ordinato 239 magliette taglia XXL a 13.31€ all'indirizzo [45.824062, 8.276641]
# Manuel ha ordinato 236 magliette taglia L a 17.51€ all'indirizzo [44.931719, 10.901902]
# Alessandro ha ordinato 230 magliette taglia XXL a 16.29€ all'indirizzo [45.190932, 10.15473]
# Giulia ha ordinato 230 magliette taglia XL a 19.16€ all'indirizzo [46.365271, 9.160471]
# Gianmarco ha ordinato 229 magliette taglia S a 14.65€ all'indirizzo [46.002357, 10.304807]
# Gianmarco ha ordinato 227 magliette taglia M a 14.42€ all'indirizzo [45.121825, 10.002931]
# Alessandro ha ordinato 225 magliette taglia S a 18.09€ all'indirizzo [44.462696, 8.818987]
# Francesco ha ordinato 224 magliette taglia XS a 18.24€ all'indirizzo [44.425749, 8.801334]
# Enrico ha ordinato 223 magliette taglia XXL a 16.11€ all'indirizzo [46.250162, 7.744354]
# Filippo ha ordinato 222 magliette taglia M a 19.05€ all'indirizzo [45.339915, 6.812426]
# Giulia ha ordinato 216 magliette taglia XL a 19.36€ all'indirizzo [45.322668, 10.433776]
# Gianmarco ha ordinato 216 magliette taglia S a 19.14€ all'indirizzo [46.206842, 10.051039]
# Valentina ha ordinato 199 magliette taglia S a 16.87€ all'indirizzo [45.658579, 8.425556]
# Maurizio ha ordinato 197 magliette taglia XL a 19.45€ all'indirizzo [46.435533, 8.212229]
# Alessandro ha ordinato 194 magliette taglia S a 13.22€ all'indirizzo [45.777217, 11.317981]
# Giulia ha ordinato 191 magliette taglia XXL a 15.08€ all'indirizzo [44.972737, 11.149641]
# MC ha ordinato 190 magliette taglia XL a 17.36€ all'indirizzo [44.616765, 9.082761]
# Valentina ha ordinato 189 magliette taglia XL a 18.86€ all'indirizzo [46.65957, 8.348547]
# Filippo ha ordinato 187 magliette taglia XXL a 17.7€ all'indirizzo [45.946048, 11.894065]
# Alessandro ha ordinato 184 magliette taglia L a 19.47€ all'indirizzo [44.703475, 9.736538]
# JP ha ordinato 182 magliette taglia XS a 19.11€ all'indirizzo [45.29682, 7.709197]
# Davide ha ordinato 181 magliette taglia S a 14.33€ all'indirizzo [46.345313, 10.474108]
# Francesco ha ordinato 180 magliette taglia S a 13.86€ all'indirizzo [46.402325, 10.369838]
# Francesco ha ordinato 176 magliette taglia XL a 15.39€ all'indirizzo [45.460174, 10.501418]
# Valentina ha ordinato 174 magliette taglia L a 16.17€ all'indirizzo [44.856611, 11.140003]
# Luca ha ordinato 173 magliette taglia XL a 18.31€ all'indirizzo [45.131002, 10.353471]
# Valentina ha ordinato 172 magliette taglia S a 17.51€ all'indirizzo [45.028921, 6.801111]
# MC ha ordinato 172 magliette taglia XXL a 14.55€ all'indirizzo [46.263073, 8.774522]
# Gianmarco ha ordinato 172 magliette taglia XS a 16.55€ all'indirizzo [45.07399, 7.530061]
# JP ha ordinato 156 magliette taglia L a 19.86€ all'indirizzo [45.337628, 9.235005]
# Luca ha ordinato 155 magliette taglia XL a 16.66€ all'indirizzo [44.542568, 9.210092]
# Valentina ha ordinato 153 magliette taglia XS a 19.69€ all'indirizzo [44.485797, 7.627326]
# Angelica ha ordinato 153 magliette taglia XS a 19.85€ all'indirizzo [45.662599, 11.126587]
# Giulia ha ordinato 146 magliette taglia M a 17.73€ all'indirizzo [45.621286, 6.720958]
# Valentina ha ordinato 144 magliette taglia S a 14.63€ all'indirizzo [45.426824, 10.319778]
# MC ha ordinato 142 magliette taglia XS a 18.21€ all'indirizzo [45.835345, 7.52385]
# JP ha ordinato 142 magliette taglia S a 15.32€ all'indirizzo [45.987218, 8.92958]
# Francesco ha ordinato 141 magliette taglia XS a 16.38€ all'indirizzo [45.581672, 8.188537]
# Angelica ha ordinato 140 magliette taglia XXL a 13.73€ all'indirizzo [44.502061, 11.728325]
# Davide ha ordinato 137 magliette taglia S a 15.36€ all'indirizzo [45.603979, 9.332943]
# Carlo ha ordinato 135 magliette taglia XS a 19.88€ all'indirizzo [46.429483, 11.714962]
# Filippo ha ordinato 131 magliette taglia S a 17.99€ all'indirizzo [44.991219, 7.331487]
# MC ha ordinato 129 magliette taglia XS a 15.04€ all'indirizzo [44.998576, 8.002632]
# Enrico ha ordinato 128 magliette taglia XL a 13.74€ all'indirizzo [45.563787, 7.149919]
# MC ha ordinato 121 magliette taglia XL a 19.16€ all'indirizzo [44.408946, 11.713756]
# Filippo ha ordinato 120 magliette taglia XXL a 17.13€ all'indirizzo [46.159635, 9.856807]
# Angelica ha ordinato 112 magliette taglia M a 16.41€ all'indirizzo [45.906026, 12.148476]
# Angelica ha ordinato 104 magliette taglia XS a 16.3€ all'indirizzo [45.101871, 7.06975]
# Francesco ha ordinato 100 magliette taglia S a 14.39€ all'indirizzo [44.569882, 12.043969]
# Giulia ha ordinato 99 magliette taglia S a 15.7€ all'indirizzo [44.380584, 8.54086]
# Francesco ha ordinato 96 magliette taglia L a 17.44€ all'indirizzo [46.547132, 6.943494]
# Angelica ha ordinato 95 magliette taglia M a 13.87€ all'indirizzo [45.794128, 8.917028]
# Luca ha ordinato 94 magliette taglia S a 16.13€ all'indirizzo [44.598262, 7.289589]
# Mirko ha ordinato 89 magliette taglia S a 18.99€ all'indirizzo [44.94402, 9.421879]
# Filippo ha ordinato 86 magliette taglia XL a 16.45€ all'indirizzo [45.652833, 9.288692]
# Alessandro ha ordinato 82 magliette taglia XXL a 15.57€ all'indirizzo [46.472705, 7.279097]
# Mirko ha ordinato 75 magliette taglia XXL a 15.03€ all'indirizzo [46.176933, 7.823514]
# Carlo ha ordinato 74 magliette taglia XXL a 15.89€ all'indirizzo [45.481015, 9.410362]
# JP ha ordinato 72 magliette taglia S a 15.82€ all'indirizzo [45.730671, 11.698629]
# Carlo ha ordinato 72 magliette taglia XXL a 13.5€ all'indirizzo [45.248003, 9.682098]
# Filippo ha ordinato 72 magliette taglia XXL a 18.52€ all'indirizzo [44.753242, 9.615282]
# Carlo ha ordinato 72 magliette taglia XXL a 16.77€ all'indirizzo [46.138661, 10.232275]
# Gianmarco ha ordinato 70 magliette taglia XL a 16.75€ all'indirizzo [44.831715, 7.603881]
# Valentina ha ordinato 69 magliette taglia L a 17.56€ all'indirizzo [45.694427, 11.603784]
# Mirko ha ordinato 66 magliette taglia M a 13.98€ all'indirizzo [44.567106, 6.70212]
# MC ha ordinato 58 magliette taglia XS a 17.66€ all'indirizzo [45.689201, 9.891178]
# Carlo ha ordinato 57 magliette taglia S a 14.44€ all'indirizzo [45.723848, 10.827164]
# JP ha ordinato 55 magliette taglia L a 19.93€ all'indirizzo [45.677897, 7.120169]
# Angelica ha ordinato 45 magliette taglia XL a 19.64€ all'indirizzo [46.610924, 9.703793]
# Giulia ha ordinato 39 magliette taglia XL a 19.31€ all'indirizzo [46.194269, 10.256644]
# JP ha ordinato 35 magliette taglia M a 14.68€ all'indirizzo [45.818552, 10.604108]
# Francesco ha ordinato 35 magliette taglia XL a 15.45€ all'indirizzo [45.069355, 8.376941]
# Enrico ha ordinato 33 magliette taglia S a 19.16€ all'indirizzo [45.386683, 8.176936]
# Angelica ha ordinato 32 magliette taglia M a 18.95€ all'indirizzo [45.273024, 10.134945]
# MC ha ordinato 32 magliette taglia XS a 19.59€ all'indirizzo [44.880335, 8.654812]
# JP ha ordinato 29 magliette taglia XXL a 19.96€ all'indirizzo [46.035413, 6.990662]
# Enrico ha ordinato 29 magliette taglia S a 19.19€ all'indirizzo [46.461167, 11.752772]
# MC ha ordinato 28 magliette taglia M a 18.83€ all'indirizzo [44.727278, 8.353823]
# Enrico ha ordinato 16 magliette taglia XL a 14.51€ all'indirizzo [46.594147, 7.243441]
# Enrico ha ordinato 14 magliette taglia XL a 15.63€ all'indirizzo [45.065032, 6.556252]
# Davide ha ordinato 14 magliette taglia M a 15.77€ all'indirizzo [45.597936, 6.672514]
# Carlo ha ordinato 13 magliette taglia XXL a 15.69€ all'indirizzo [46.046634, 10.463574]
# Mirko ha ordinato 9 magliette taglia M a 17.03€ all'indirizzo [45.576819, 9.796091]
# Angelica ha ordinato 7 magliette taglia XXL a 15.96€ all'indirizzo [45.845516, 7.56794]
# Giulia ha ordinato 6 magliette taglia XL a 15.35€ all'indirizzo [44.917987, 8.393744]
# Giulia ha ordinato 5 magliette taglia S a 13.9€ all'indirizzo [45.330281, 11.833231]
# Filippo ha ordinato 2 magliette taglia M a 15.95€ all'indirizzo [46.455183, 7.59298]

# %%
print(orders_to_go[0].Profit(best_price))
print(orders_to_go[1].Profit(best_price))
print(orders_to_go[2].Profit(best_price))
# Out:
# 3588.34
# 3566.6800000000003
# 3552.2400000000007
