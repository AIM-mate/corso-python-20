# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def logistic(r, x):
    return (r*x*(1-x))

# %%
x = np.linspace(0, 1)
fig, ax = plt.subplots(1, 1)
ax.plot(x, logistic(2, x), 'k')

# %%
def plot_system(r, x0, n, ax=None):
    # Plot the function and the
    # y=x diagonal line.
    t = np.linspace(0, 1)
    ax.plot(t, logistic(r, t), 'k', lw=2)
    ax.plot([0, 1], [0, 1], 'k', lw=2)

    # Recursively apply y=f(x) and plot two lines:
    # (x, x) -> (x, y)
    # (x, y) -> (y, y)
    x = x0
    for i in range(n):
        y = logistic(r, x)
        # Plot the two lines.

        ax.plot((x, x), (x, y), 'k', lw=1)
        ax.plot((x, y), (y, y), 'k', lw=1)
        
        # Plot the positions with increasing
        # opacity.
        ax.plot([x], [y], 'ok', ms=10,
                alpha=(i + 1) / n)
        x = y

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_title(f"$r={r:.1f}, \, x_0={x0:.1f}$")


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6),
                               sharey=True)
plot_system(2.5, .1, 10, ax=ax1)
plot_system(3.5, .1, 10, ax=ax2)

# %%
r = np.linspace(2.5, 4, num = 10000)

# %%
iterations = 1000
last = 100

# %%
x0 = 1e-5 * np.ones(iterations)

# %%
it_da_plottare = []
x = 1e-5
for i in range(0,len(r)):
    it_da_plottare_locale = []
    for it in range(0,iterations):
        y = logistic(r[i],x)
        if it >= iterations-last:
            it_da_plottare_locale.append(y)
        x = y
    it_da_plottare.append(it_da_plottare_locale)
fig, ax = plt.subplots(1, 1)
ax.set_xlim(2.5, 4)
ax.set_ylim(0, 1)
ax.plot(r,it_da_plottare, 'k', lw=1)

# %%
MAX_ITER = 1000

def mandelbrot(c):
    it = 1
    z_old = complex(0,0)
    while (abs(z_old) <= 2) and (it < MAX_ITER):
        z = z_old**2 + c
        z_old = z
        it += 1
    return it

# %%
#non riesco a plottare

# %%
it_da_plottare = []
c = np.linspace(0.25,-2,1000)
z = 0.0
for i in range(0,len(c)):
    it_da_plottare_locale = []
    for it in range(0,200):
        z_new = z**2 + c[i]
        if it >= 100:
            it_da_plottare_locale.append(z_new)
        z = z_new
    it_da_plottare.append(it_da_plottare_locale)
fig, ax = plt.subplots(1, 1)
ax.set_xlim(-2, 0.25)
ax.set_ylim(-2, 2)
ax.plot(c,it_da_plottare, 'k', lw=1)
plt.show
